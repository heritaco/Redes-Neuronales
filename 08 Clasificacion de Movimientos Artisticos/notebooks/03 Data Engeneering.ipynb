# %% [markdown]
# # Hola
#
# En esta notebook se busca maximizar la varianza entre las imagenes cortadas en cuadrantes.
#
# Se entrena una red para cada cuadrante y al final se usa un clasificador RBF con las probabilidades de las 4 redes como entradas.

# %% [markdown]
# # Loading the DataSet

# %%
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, WeightedRandomSampler
import torch, numpy as np

# %%
painter_to_genre = {
    "Joan": "Surrealismo",
    "Salvador": "Surrealismo",
    "Rene": "Surrealismo",
    "Pablo": "Cubismo",
    "Jackson": "Expresionismo abstracto",
    "Rembrandt": "Barroco",
    "Caravaggio": "Barroco",
    "Camille": "Impresionismo",
    "Alfred": "Impresionismo",
    "Claude": "Impresionismo",
    "Vincent": "Impresionismo",  
}

genre_to_label = {
    "Surrealismo": 0,
    "Cubismo": 1,
    "Expresionismo abstracto": 2,
    "Barroco": 3,
    "Impresionismo": 4,
}

# %%
from pathlib import Path
import pandas as pd

root = Path("08 Clasificacion de Movimientos Artisticos/data")

# recoge todos los .jpg (ajusta extensiones si hay .png, etc.)
paths = sorted(root.glob("*.jpg"))

rows = []
for p in paths:
    stem = p.stem  # 'Joan_Miro_001'
    # ejemplo simple: pintor = todo menos la parte final si es número
    painter = stem.split("_")[0]
    genre = painter_to_genre[painter]
    label = genre_to_label[genre]

    rows.append({
        "path": str(p),
        "painter": painter,
        "genre": genre,
        "label": label,
    })

df = pd.DataFrame(rows)

# %%
print(df['genre'].value_counts())
df.head()
# Out:
# genre
# Impresionismo              75
# Surrealismo                50
# Barroco                    30
# Cubismo                    30
# Expresionismo abstracto    15
# Name: count, dtype: int64
#                                                 path painter          genre  \
# 0  08 Clasificacion de Movimientos Artisticos\dat...  Alfred  Impresionismo
# 1  08 Clasificacion de Movimientos Artisticos\dat...  Alfred  Impresionismo
# 2  08 Clasificacion de Movimientos Artisticos\dat...  Alfred  Impresionismo
# 3  08 Clasificacion de Movimientos Artisticos\dat...  Alfred  Impresionismo
# 4  08 Clasificacion de Movimientos Artisticos\dat...  Alfred  Impresionismo
#
#    label
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4

# %%
from torch.utils.data import Dataset
from PIL import Image

class PaintingDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df.reset_index(drop=True)
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img = Image.open(row["path"]).convert("RGB")
        y = int(row["label"])
        if self.transform is not None:
            img = self.transform(img)
        return img, y

# %% [markdown]
# # Data Engineering 😜

# %%
from torchvision.transforms import functional as TF

class QuadrantCrop:
    """
    quadrant ∈ {"ul", "ur", "ll", "lr"}.
    Crops the corresponding quarter of the image.
    """
    def __init__(self, quadrant: str):
        assert quadrant in {"ul", "ur", "ll", "lr"}
        self.quadrant = quadrant

    def __call__(self, img):
        # img is a PIL.Image
        w, h = img.size  # (width, height)

        crop_w = w // 2
        crop_h = h // 2

        if self.quadrant == "ul":
            left, top = 0, 0
        elif self.quadrant == "ur":
            left, top = w - crop_w, 0
        elif self.quadrant == "ll":
            left, top = 0, h - crop_h
        else:  # "lr"
            left, top = w - crop_w, h - crop_h

        # use torchvision.transforms.functional, NOT torch.nn.functional
        return TF.crop(img, top, left, crop_h, crop_w)

# %% [markdown]
# ## maximize variance

# %%
import json
with open('08 Clasificacion de Movimientos Artisticos/info/best_params.json', 'r') as f:
    best_params = json.load(f)

# %%
# read mean_ul, std_ul, mean_ur, std_ur, mean_ll, std_ll, mean_lr, std_lr from json
import json
with open('08 Clasificacion de Movimientos Artisticos/info/mean_std.json', 'r') as f:
    mean_std = json.load(f)
    
mean_ul = np.array(mean_std["mean_ul"])
std_ul = np.array(mean_std["std_ul"])
mean_ur = np.array(mean_std["mean_ur"])
std_ur = np.array(mean_std["std_ur"])
mean_ll = np.array(mean_std["mean_ll"])
std_ll = np.array(mean_std["std_ll"])
mean_lr = np.array(mean_std["mean_lr"])
std_lr = np.array(mean_std["std_lr"])

# %%
transf_ul = transforms.Compose([
    QuadrantCrop("ul"),
    transforms.Resize((128, 128)),
    transforms.ColorJitter(contrast=best_params['ul']['c'], saturation=best_params['ul']['s'], brightness=best_params['ul']['b'], hue=best_params['ul']['h']),
    transforms.ToTensor(),
    # transforms.Normalize(mean=mean_ul.tolist(), std=std_ul.tolist()),
])

transf_ur = transforms.Compose([
    QuadrantCrop("ur"),
    transforms.Resize((128, 128)),
    transforms.ColorJitter(contrast=best_params['ur']['c'], saturation=best_params['ur']['s'], brightness=best_params['ur']['b'], hue=best_params['ur']['h']),
    transforms.ToTensor(),
    # transforms.Normalize(mean=mean_ur.tolist(), std=std_ur.tolist()),
])

transf_ll = transforms.Compose([
    QuadrantCrop("ll"),
    transforms.Resize((128, 128)),
    transforms.ColorJitter(contrast=best_params['ll']['c'], saturation=best_params['ll']['s'], brightness=best_params['ll']['b'], hue=best_params['ll']['h']),
    transforms.ToTensor(),
    # transforms.Normalize(mean=mean_ll.tolist(), std=std_ll.tolist()),
])

transf_lr = transforms.Compose([
    QuadrantCrop("lr"),
    transforms.Resize((128, 128)),
    transforms.ColorJitter(contrast=best_params['lr']['c'], saturation=best_params['lr']['s'], brightness=best_params['lr']['b'], hue=best_params['lr']['h']),
    transforms.ToTensor(),
    # transforms.Normalize(mean=mean_lr.tolist(), std=std_lr.tolist()),
])

# %% [markdown]
# # Transfarmation and split train and validation sets

# %%
from sklearn.model_selection import train_test_split

train_df, val_df = train_test_split(df, test_size=0.1, stratify=df['label'], random_state=863)

# %%
train_ul = PaintingDataset(train_df, transform=transf_ul)
train_ur = PaintingDataset(train_df, transform=transf_ur)
train_ll = PaintingDataset(train_df, transform=transf_ll)
train_lr = PaintingDataset(train_df, transform=transf_lr)

val_ul = PaintingDataset(val_df, transform=transf_ul)
val_ur = PaintingDataset(val_df, transform=transf_ur)
val_ll = PaintingDataset(val_df, transform=transf_ll)
val_lr = PaintingDataset(val_df, transform=transf_lr)

# %%
import torch.utils.data
train_ds = torch.utils.data.ConcatDataset([train_ul, train_ur, train_ll, train_lr])
val_ds = torch.utils.data.ConcatDataset([val_ul, val_ur, val_ll, val_lr])

# %% [markdown]
# # Visualización de imágenes con los mejores parámetros encontrados

# %%
import random
r = random.randint(0, len(train_ul)-1)

img_ul, y = train_ul[r]
img_ur, y = train_ur[r]
img_ll, y = train_ll[r]
img_lr, y = train_lr[r]

print("Label:", y, train_df.iloc[r]["genre"])


import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(8, 8))

axes[0,0].imshow((img_ul).permute(1,2,0).cpu().numpy())
axes[0,0].axis("off")

axes[0,1].imshow((img_ur).permute(1,2,0).cpu().numpy())
axes[0,1].axis("off")

axes[1,0].imshow((img_ll).permute(1,2,0).cpu().numpy())
axes[1,0].axis("off")

axes[1,1].imshow((img_lr).permute(1,2,0).cpu().numpy())
axes[1,1].axis("off")

plt.show()
# Out:
# Label: 3 Barroco

# %% [markdown]
# # ReLU

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
if device.type == "cuda":
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Using device: cuda
# GPU name: NVIDIA GeForce RTX 4060 Laptop GPU

# %%
import numpy as np
import torch

NUM_CLASSES = len(genre_to_label)

# labels must be integers 0..C-1 (you already have that)
labels_train = train_df["label"].values  # shape (N_train,)

# counts per class, ordered by label index
class_counts = np.bincount(labels_train, minlength=NUM_CLASSES).astype(float)
print("class_counts:", class_counts)

# inverse-frequency weights (rarer classes get higher weight)
class_weights = 1.0 / class_counts
# optional: normalize so average weight ~1
class_weights = class_weights * (NUM_CLASSES / class_weights.sum())
print("class_weights:", class_weights)

class_weights_t = torch.tensor(class_weights, dtype=torch.float32).to(device)
# Out:
# class_counts: [45. 27. 13. 27. 68.]
# class_weights: [0.59125162 0.98541936 2.04664021 0.98541936 0.39126945]

# %%
# Dicts to refer to quadrant datasets by name
quadrant_train_ds = {
    "ul": train_ul,
    "ur": train_ur,
    "ll": train_ll,
    "lr": train_lr,
}
quadrant_val_ds = {
    "ul": val_ul,
    "ur": val_ur,
    "ll": val_ll,
    "lr": val_lr,
}

# Also keep transforms in a dict (for later inference/meta features)
transforms_quadrant = {
    "ul": transf_ul,
    "ur": transf_ur,
    "ll": transf_ll,
    "lr": transf_lr,
}

# %%
# ReLU for each quadrant

import torch.nn as nn
import torch.nn.functional as F
import torch.nn.functional as Fnn


NUM_CLASSES = len(genre_to_label)

class SmallCNN(nn.Module):
    def __init__(self, num_classes=NUM_CLASSES):
        super().__init__()
        self.flatten = nn.Flatten()
        self.features = nn.Sequential(
            nn.Linear(3 * 128 * 128, 512),
            nn.ReLU(inplace=True),
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, 128),
            nn.ReLU(inplace=True),
        )
        self.classifier = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.flatten(x)
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
# Training loop for a single model
from torch.utils.data import DataLoader
from torch.optim import Adam
from tqdm import tqdm
from torch.optim import Adam
from tqdm import tqdm

def train_one_model(train_loader, val_loader, num_epochs=10, lr=1e-3,
                    class_weights=None):
    model = SmallCNN().to(device)
    if class_weights is not None:
        criterion = nn.CrossEntropyLoss(weight=class_weights)
    else:
        criterion = nn.CrossEntropyLoss()

    optimizer = Adam(model.parameters(), lr=lr)

    best_val_acc = 0.0
    best_state   = None
    history = {
        "train_loss": [],
        "train_acc":  [],
        "val_loss":   [],
        "val_acc":    [],
    }

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        total = 0
        correct = 0

        for imgs, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}", leave=False):
            imgs   = imgs.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            optimizer.zero_grad()
            logits = model(imgs)
            loss = criterion(logits, labels)   # <- weighted CE
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * imgs.size(0)
            _, preds = logits.max(1)
            total += labels.size(0)
            correct += (preds == labels).sum().item()

        train_loss = running_loss / total
        train_acc  = correct / total

        # ---- validation (unweighted metrics) ----
        model.eval()
        val_loss = 0.0
        val_total = 0
        val_correct = 0

        with torch.no_grad():
            for imgs, labels in val_loader:
                imgs   = imgs.to(device, non_blocking=True)
                labels = labels.to(device, non_blocking=True)

                logits = model(imgs)
                loss = criterion(logits, labels)  # still weighted for loss

                val_loss += loss.item() * imgs.size(0)
                _, preds = logits.max(1)
                val_total   += labels.size(0)
                val_correct += (preds == labels).sum().item()

        val_loss /= val_total
        val_acc   = val_correct / val_total

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)

        print(f"    Epoch {epoch+1:02d} | "
              f"train_loss={train_loss:.4f}, train_acc={train_acc:.3f} | "
              f"val_loss={val_loss:.4f}, val_acc={val_acc:.3f}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_state   = model.state_dict()

    if best_state is not None:
        model.load_state_dict(best_state)

    print("Best val_acc (CNN):", best_val_acc)
    return model, history

# %%
# Train one model per quadrant
BATCH_SIZE = 32

models_quadrant   = {}
histories_quadrant = {}

for qname in ["ul", "ur", "ll", "lr"]:
    print(f"\n===== Training quadrant: {qname} =====")

    train_ld_q = DataLoader(
        quadrant_train_ds[qname],
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=0,
        pin_memory=True,
    )
    val_ld_q = DataLoader(
        quadrant_val_ds[qname],
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=0,
        pin_memory=True,
    )

    model_q, hist_q = train_one_model(
        train_loader=train_ld_q,
        val_loader=val_ld_q,
        num_epochs=20,
        lr=1e-3,
        class_weights=class_weights_t,   # <- HERE
    )

    models_quadrant[qname] = model_q
    histories_quadrant[qname] = hist_q
# Out:
# ===== Training quadrant: ul =====
#     Epoch 01 | train_loss=2.6528, train_acc=0.239 | val_loss=3.2603, val_acc=0.150
#     Epoch 02 | train_loss=2.2898, train_acc=0.317 | val_loss=1.7044, val_acc=0.350
#     Epoch 03 | train_loss=1.3415, train_acc=0.433 | val_loss=1.5926, val_acc=0.350
#     Epoch 04 | train_loss=1.0482, train_acc=0.517 | val_loss=1.7529, val_acc=0.350
#     Epoch 05 | train_loss=0.7365, train_acc=0.739 | val_loss=1.3582, val_acc=0.500
#     Epoch 06 | train_loss=0.5348, train_acc=0.822 | val_loss=1.6414, val_acc=0.350
#     Epoch 07 | train_loss=0.4154, train_acc=0.822 | val_loss=1.5390, val_acc=0.450
#     Epoch 08 | train_loss=0.2743, train_acc=0.894 | val_loss=1.8880, val_acc=0.450
#     Epoch 09 | train_loss=0.1946, train_acc=0.917 | val_loss=2.2146, val_acc=0.500
#     Epoch 10 | train_loss=0.1243, train_acc=0.961 | val_loss=2.3822, val_acc=0.400
#     Epoch 11 | train_loss=0.1265, train_acc=0.944 | val_loss=2.4151, val_acc=0.400
#     Epoch 12 | train_loss=0.0861, train_acc=0.961 | val_loss=2.3996, val_acc=0.300
#     Epoch 13 | train_loss=0.0748, train_acc=0.944 | val_loss=3.7200, val_acc=0.400
#     Epoch 14 | train_loss=0.0558, train_acc=0.978 | val_loss=2.5819, val_acc=0.350
#     Epoch 15 | train_loss=0.0321, train_acc=0.994 | val_loss=3.1234, val_acc=0.400
#     Epoch 16 | train_loss=0.0321, train_acc=0.978 | val_loss=2.7128, val_acc=0.400
#     Epoch 17 | train_loss=0.0127, train_acc=1.000 | val_loss=3.1294, val_acc=0.500
#     Epoch 18 | train_loss=0.0056, train_acc=1.000 | val_loss=3.1397, val_acc=0.400
#     Epoch 19 | train_loss=0.0040, train_acc=1.000 | val_loss=3.3635, val_acc=0.400
#     Epoch 20 | train_loss=0.0026, train_acc=1.000 | val_loss=3.2507, val_acc=0.400
# Best val_acc (CNN): 0.5
#
# ===== Training quadrant: ur =====
#     Epoch 01 | train_loss=2.7207, train_acc=0.244 | val_loss=4.6017, val_acc=0.250
#     Epoch 02 | train_loss=2.1763, train_acc=0.256 | val_loss=1.8688, val_acc=0.200
#     Epoch 03 | train_loss=1.4363, train_acc=0.350 | val_loss=2.2436, val_acc=0.400
#     Epoch 04 | train_loss=1.2290, train_acc=0.417 | val_loss=1.7673, val_acc=0.450
#     Epoch 05 | train_loss=0.9102, train_acc=0.583 | val_loss=2.3373, val_acc=0.250
#     Epoch 06 | train_loss=0.7704, train_acc=0.622 | val_loss=2.1930, val_acc=0.250
#     Epoch 07 | train_loss=0.6117, train_acc=0.661 | val_loss=2.8204, val_acc=0.300
#     Epoch 08 | train_loss=0.4906, train_acc=0.767 | val_loss=2.7799, val_acc=0.300
#     Epoch 09 | train_loss=0.3890, train_acc=0.833 | val_loss=2.8954, val_acc=0.250
#     Epoch 10 | train_loss=0.3824, train_acc=0.800 | val_loss=4.0412, val_acc=0.500
#     Epoch 11 | train_loss=0.2634, train_acc=0.922 | val_loss=3.8665, val_acc=0.400
#     Epoch 12 | train_loss=0.2499, train_acc=0.917 | val_loss=3.5045, val_acc=0.300
#     Epoch 13 | train_loss=0.1768, train_acc=0.933 | val_loss=4.6920, val_acc=0.350
#     Epoch 14 | train_loss=0.1110, train_acc=0.972 | val_loss=4.9569, val_acc=0.300
#     Epoch 15 | train_loss=0.1333, train_acc=0.944 | val_loss=4.5852, val_acc=0.400
#     Epoch 16 | train_loss=0.0653, train_acc=0.972 | val_loss=4.0520, val_acc=0.350
#     Epoch 17 | train_loss=0.0890, train_acc=0.972 | val_loss=4.3713, val_acc=0.400
#     Epoch 18 | train_loss=0.1803, train_acc=0.933 | val_loss=5.8733, val_acc=0.400
#     Epoch 19 | train_loss=0.1029, train_acc=0.961 | val_loss=4.1127, val_acc=0.300
#     Epoch 20 | train_loss=0.0706, train_acc=0.972 | val_loss=4.1122, val_acc=0.400
# Best val_acc (CNN): 0.5
#
# ===== Training quadrant: ll =====
#     Epoch 01 | train_loss=3.0954, train_acc=0.194 | val_loss=1.7956, val_acc=0.150
#     Epoch 02 | train_loss=1.9959, train_acc=0.222 | val_loss=2.0892, val_acc=0.050
#     Epoch 03 | train_loss=1.9010, train_acc=0.300 | val_loss=1.7003, val_acc=0.200
#     Epoch 04 | train_loss=1.8334, train_acc=0.200 | val_loss=1.7116, val_acc=0.200
#     Epoch 05 | train_loss=1.6661, train_acc=0.228 | val_loss=1.6238, val_acc=0.200
#     Epoch 06 | train_loss=1.5840, train_acc=0.317 | val_loss=1.6860, val_acc=0.250
#     Epoch 07 | train_loss=1.5876, train_acc=0.250 | val_loss=1.5336, val_acc=0.150
#     Epoch 08 | train_loss=1.6082, train_acc=0.228 | val_loss=1.7492, val_acc=0.250
#     Epoch 09 | train_loss=1.5929, train_acc=0.306 | val_loss=1.5790, val_acc=0.250
#     Epoch 10 | train_loss=1.4916, train_acc=0.394 | val_loss=1.6715, val_acc=0.300
#     Epoch 11 | train_loss=1.5249, train_acc=0.383 | val_loss=1.8091, val_acc=0.150
#     Epoch 12 | train_loss=1.4575, train_acc=0.289 | val_loss=1.6448, val_acc=0.350
#     Epoch 13 | train_loss=1.4258, train_acc=0.394 | val_loss=1.7623, val_acc=0.250
#     Epoch 14 | train_loss=1.3801, train_acc=0.450 | val_loss=1.7174, val_acc=0.200
#     Epoch 15 | train_loss=1.3988, train_acc=0.406 | val_loss=1.7671, val_acc=0.250
#     Epoch 16 | train_loss=1.4334, train_acc=0.456 | val_loss=1.6376, val_acc=0.250
#     Epoch 17 | train_loss=1.4610, train_acc=0.322 | val_loss=1.5901, val_acc=0.400
#     Epoch 18 | train_loss=1.3047, train_acc=0.522 | val_loss=1.5138, val_acc=0.350
#     Epoch 19 | train_loss=1.2141, train_acc=0.450 | val_loss=1.8766, val_acc=0.400
#     Epoch 20 | train_loss=1.3503, train_acc=0.494 | val_loss=1.8171, val_acc=0.150
# Best val_acc (CNN): 0.4
#
# ===== Training quadrant: lr =====
#     Epoch 01 | train_loss=2.8656, train_acc=0.156 | val_loss=1.6967, val_acc=0.150
#     Epoch 02 | train_loss=1.7225, train_acc=0.256 | val_loss=2.1405, val_acc=0.100
#     Epoch 03 | train_loss=1.6195, train_acc=0.222 | val_loss=1.8696, val_acc=0.200
#     Epoch 04 | train_loss=1.4207, train_acc=0.350 | val_loss=1.8029, val_acc=0.200
#     Epoch 05 | train_loss=1.2436, train_acc=0.461 | val_loss=1.5948, val_acc=0.250
#     Epoch 06 | train_loss=1.0797, train_acc=0.467 | val_loss=2.1574, val_acc=0.250
#     Epoch 07 | train_loss=0.9686, train_acc=0.617 | val_loss=2.1082, val_acc=0.250
#     Epoch 08 | train_loss=0.7940, train_acc=0.644 | val_loss=1.8607, val_acc=0.350
#     Epoch 09 | train_loss=0.7170, train_acc=0.694 | val_loss=2.5065, val_acc=0.200
#     Epoch 10 | train_loss=0.6379, train_acc=0.750 | val_loss=2.5097, val_acc=0.200
#     Epoch 11 | train_loss=0.6425, train_acc=0.683 | val_loss=2.4852, val_acc=0.300
#     Epoch 12 | train_loss=0.5567, train_acc=0.794 | val_loss=2.3959, val_acc=0.300
#     Epoch 13 | train_loss=0.4899, train_acc=0.794 | val_loss=2.5552, val_acc=0.300
#     Epoch 14 | train_loss=0.3848, train_acc=0.828 | val_loss=2.6550, val_acc=0.300
#     Epoch 15 | train_loss=0.3728, train_acc=0.833 | val_loss=2.6412, val_acc=0.350
#     Epoch 16 | train_loss=0.3580, train_acc=0.856 | val_loss=2.1749, val_acc=0.300
#     Epoch 17 | train_loss=0.4038, train_acc=0.839 | val_loss=2.4652, val_acc=0.400
#     Epoch 18 | train_loss=0.2618, train_acc=0.900 | val_loss=2.1871, val_acc=0.250
#     Epoch 19 | train_loss=0.2154, train_acc=0.911 | val_loss=2.9481, val_acc=0.300
#     Epoch 20 | train_loss=0.2335, train_acc=0.928 | val_loss=2.6764, val_acc=0.350
# Best val_acc (CNN): 0.4

# %%
# Build meta-dataset: stacked probabilities from the 4 models
import numpy as np

def build_meta_dataset(df_subset, models_quadrant, transforms_quadrant,
                       batch_size=32):
    quadrant_names = list(models_quadrant.keys())

    # create one dataset / loader per quadrant on this subset
    datasets_q = {
        q: PaintingDataset(df_subset, transform=transforms_quadrant[q])
        for q in quadrant_names
    }
    loaders_q = {
        q: DataLoader(
            datasets_q[q],
            batch_size=batch_size,
            shuffle=False,    # must preserve order
            num_workers=0,
            pin_memory=True,
        )
        for q in quadrant_names
    }

    probs_q = {q: [] for q in quadrant_names}
    labels_all = []

    with torch.no_grad():
        for qi, q in enumerate(quadrant_names):
            model_q = models_quadrant[q].to(device)
            model_q.eval()

            first_q = (qi == 0)

            for imgs, labels in loaders_q[q]:
                imgs = imgs.to(device, non_blocking=True)
                logits = model_q(imgs)                # (B, C)
                probs = torch.softmax(logits, dim=1)  # (B, C)

                probs_q[q].append(probs.cpu())
                if first_q:
                    labels_all.append(labels.clone())

    probs_q_cat = [torch.cat(probs_q[q], dim=0) for q in quadrant_names]  # each (N,C)
    X_meta = torch.cat(probs_q_cat, dim=1).numpy()  # (N, Q*C)
    y_meta = torch.cat(labels_all, dim=0).numpy()   # (N,)

    return X_meta, y_meta

X_train_meta, y_train_meta = build_meta_dataset(
    train_df, models_quadrant, transforms_quadrant, batch_size=BATCH_SIZE
)
X_val_meta,   y_val_meta   = build_meta_dataset(
    val_df, models_quadrant, transforms_quadrant, batch_size=BATCH_SIZE
)

print("X_train_meta shape:", X_train_meta.shape)  # (N_train, 4 * NUM_CLASSES)
print("X_val_meta   shape:", X_val_meta.shape)
# Out:
# X_train_meta shape: (180, 20)
# X_val_meta   shape: (20, 20)

# %% [markdown]
# # Meta RBF

# %%
# RBF meta-classifier on top of stacked probabilities
from sklearn.cluster import KMeans

def init_rbf_centers(X_train_meta, n_centers=20, random_state=42):
    kmeans = KMeans(
        n_clusters=n_centers,
        random_state=random_state,
        n_init="auto"
    )
    kmeans.fit(X_train_meta)
    return kmeans.cluster_centers_

class RBFMeta(nn.Module):
    def __init__(self, in_dim, num_classes, centers, gamma=None, train_gamma=False):
        super().__init__()
        centers = torch.tensor(centers, dtype=torch.float32)
        self.register_buffer("centers", centers)  # (K, D)
        self.K, self.in_dim = centers.shape

        if gamma is None:
            with torch.no_grad():
                c = centers
                dist2 = torch.cdist(c, c, p=2.0) ** 2  # (K,K)
                median_dist2 = torch.median(dist2)
                gamma_val = 1.0 / (2.0 * median_dist2.clamp(min=1e-6))
        else:
            gamma_val = float(gamma)

        if train_gamma:
            self.gamma = nn.Parameter(torch.tensor(gamma_val))
        else:
            self.register_buffer("gamma", torch.tensor(gamma_val))

        self.linear = nn.Linear(self.K, num_classes)

    def forward(self, x):
        # x: (N, D)
        x_expanded = x.unsqueeze(1)           # N x 1 x D
        c_expanded = self.centers.unsqueeze(0)  # 1 x K x D
        dist2 = torch.sum((x_expanded - c_expanded) ** 2, dim=2)  # N x K
        phi = torch.exp(-self.gamma * dist2)  # N x K
        logits = self.linear(phi)             # N x num_classes
        return logits

def train_rbf_meta(X_train, y_train, X_val, y_val,
                   n_centers=20, num_epochs=100, lr=1e-3,
                   class_weights=None):

    X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train_t = torch.tensor(y_train, dtype=torch.long).to(device)
    X_val_t   = torch.tensor(X_val,   dtype=torch.float32).to(device)
    y_val_t   = torch.tensor(y_val,   dtype=torch.long).to(device)

    centers = init_rbf_centers(X_train, n_centers=n_centers)
    model = RBFMeta(
        in_dim=X_train.shape[1],
        num_classes=NUM_CLASSES,
        centers=centers,
        gamma=None,
        train_gamma=False,
    ).to(device)

    if class_weights is not None:
        criterion = nn.CrossEntropyLoss(weight=class_weights)
    else:
        criterion = nn.CrossEntropyLoss()

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    best_val_acc = 0.0
    best_state = None

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()
        logits = model(X_train_t)
        loss = criterion(logits, y_train_t)
        loss.backward()
        optimizer.step()

        with torch.no_grad():
            _, pred_train = logits.max(1)
            train_acc = (pred_train == y_train_t).float().mean().item()

            model.eval()
            logits_val = model(X_val_t)
            val_loss = criterion(logits_val, y_val_t).item()
            _, pred_val = logits_val.max(1)
            val_acc = (pred_val == y_val_t).float().mean().item()

        print(f"[RBF] Epoch {epoch+1:03d} | "
              f"train_loss={loss.item():.4f}, train_acc={train_acc:.3f} | "
              f"val_loss={val_loss:.4f}, val_acc={val_acc:.3f}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_state = model.state_dict()

    if best_state is not None:
        model.load_state_dict(best_state)
    print("Best val_acc (RBF meta):", best_val_acc)

    return model

# %%
def predict_weighted_probs(img, models_quadrant, transforms_quadrant, alpha):
    # alpha: dict {"ul": α_ul, ...}
    probs_total = None

    with torch.no_grad():
        for q, model_q in models_quadrant.items():
            x_q = transforms_quadrant[q](img).unsqueeze(0).to(device)
            logits_q = model_q.to(device)(x_q)
            p_q = torch.softmax(logits_q, dim=1).cpu()  # 1×C

            w = alpha[q]
            if probs_total is None:
                probs_total = w * p_q
            else:
                probs_total += w * p_q

    probs_total = probs_total / probs_total.sum(dim=1, keepdim=True)
    pred = probs_total.argmax(dim=1).item()
    return pred, probs_total.numpy()[0]

# get best val accuracy per quadrant
acc_quadrant = {}
for q in ["ul", "ur", "ll", "lr"]:
    hist = histories_quadrant[q]
    best_val = max(hist["val_acc"])
    acc_quadrant[q] = best_val

print(acc_quadrant)

# e.g. α_q = best_val_acc / sum(best_val_acc)
sum_acc = sum(acc_quadrant.values())
alpha = {q: acc_quadrant[q] / sum_acc for q in acc_quadrant}
print("alpha (weights):", alpha)

def build_meta_dataset_weighted(df_subset, models_quadrant, transforms_quadrant,
                                alpha, batch_size=32):
    quadrant_names = list(models_quadrant.keys())

    datasets_q = {
        q: PaintingDataset(df_subset, transform=transforms_quadrant[q])
        for q in quadrant_names
    }
    loaders_q = {
        q: DataLoader(
            datasets_q[q],
            batch_size=batch_size,
            shuffle=False,
            num_workers=0,
            pin_memory=True,
        )
        for q in quadrant_names
    }

    probs_q = {q: [] for q in quadrant_names}
    labels_all = []

    with torch.no_grad():
        for qi, q in enumerate(quadrant_names):
            model_q = models_quadrant[q].to(device)
            model_q.eval()
            first_q = (qi == 0)

            for imgs, labels in loaders_q[q]:
                imgs = imgs.to(device, non_blocking=True)
                logits = model_q(imgs)
                probs = torch.softmax(logits, dim=1).cpu()  # (B, C)

                # multiply by quadrant weight α_q
                probs_q[q].append(alpha[q] * probs)

                if first_q:
                    labels_all.append(labels.clone())

    probs_q_cat = [torch.cat(probs_q[q], dim=0) for q in quadrant_names]  # each (N, C)
    X_meta = torch.cat(probs_q_cat, dim=1).numpy()  # (N, Q*C)
    y_meta = torch.cat(labels_all, dim=0).numpy()

    return X_meta, y_meta

X_train_meta, y_train_meta = build_meta_dataset_weighted(
    train_df, models_quadrant, transforms_quadrant, alpha, batch_size=BATCH_SIZE
)
X_val_meta,   y_val_meta   = build_meta_dataset_weighted(
    val_df,   models_quadrant, transforms_quadrant, alpha, batch_size=BATCH_SIZE
)

# then train RBF meta as before
rbf_meta_model = train_rbf_meta(
    X_train_meta, y_train_meta,
    X_val_meta,   y_val_meta,
    n_centers=20,
    num_epochs=1000,
    lr=1e-3,
    class_weights=class_weights_t,  # if you are using imbalance correction
)
# Out:
# {'ul': 0.5, 'ur': 0.5, 'll': 0.4, 'lr': 0.4}
# alpha (weights): {'ul': 0.2777777777777778, 'ur': 0.2777777777777778, 'll': 0.22222222222222224, 'lr': 0.22222222222222224}
# c:\Users\herie\miniconda3\envs\dl\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\herie\AppData\Local\Temp\ipykernel_21024\3513866009.py:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer("gamma", torch.tensor(gamma_val))
# [RBF] Epoch 001 | train_loss=1.5861, train_acc=0.222 | val_loss=1.6272, val_acc=0.150
# [RBF] Epoch 002 | train_loss=1.5824, train_acc=0.222 | val_loss=1.6257, val_acc=0.150
# [RBF] Epoch 003 | train_loss=1.5789, train_acc=0.222 | val_loss=1.6244, val_acc=0.150
# [RBF] Epoch 004 | train_loss=1.5755, train_acc=0.222 | val_loss=1.6232, val_acc=0.150
# [RBF] Epoch 005 | train_loss=1.5722, train_acc=0.222 | val_loss=1.6221, val_acc=0.150
# [RBF] Epoch 006 | train_loss=1.5690, train_acc=0.222 | val_loss=1.6212, val_acc=0.150
# [RBF] Epoch 007 | train_loss=1.5659, train_acc=0.222 | val_loss=1.6205, val_acc=0.150
# [RBF] Epoch 008 | train_loss=1.5629, train_acc=0.239 | val_loss=1.6198, val_acc=0.150
# [RBF] Epoch 009 | train_loss=1.5600, train_acc=0.272 | val_loss=1.6193, val_acc=0.200
# [RBF] Epoch 010 | train_loss=1.5572, train_acc=0.333 | val_loss=1.6189, val_acc=0.250
# [RBF] Epoch 011 | train_loss=1.5545, train_acc=0.533 | val_loss=1.6186, val_acc=0.400
# [RBF] Epoch 012 | train_loss=1.5518, train_acc=0.600 | val_loss=1.6183, val_acc=0.400
# [RBF] Epoch 013 | train_loss=1.5493, train_acc=0.600 | val_loss=1.6182, val_acc=0.400
# [RBF] Epoch 014 | train_loss=1.5468, train_acc=0.600 | val_loss=1.6181, val_acc=0.450
# [RBF] Epoch 015 | train_loss=1.5443, train_acc=0.600 | val_loss=1.6180, val_acc=0.450
# [RBF] Epoch 016 | train_loss=1.5419, train_acc=0.600 | val_loss=1.6181, val_acc=0.450
# [RBF] Epoch 017 | train_loss=1.5396, train_acc=0.600 | val_loss=1.6181, val_acc=0.450
# [RBF] Epoch 018 | train_loss=1.5374, train_acc=0.644 | val_loss=1.6183, val_acc=0.450
# [RBF] Epoch 019 | train_loss=1.5351, train_acc=0.700 | val_loss=1.6184, val_acc=0.450
# [RBF] Epoch 020 | train_loss=1.5330, train_acc=0.722 | val_loss=1.6185, val_acc=0.450
# [RBF] Epoch 021 | train_loss=1.5308, train_acc=0.733 | val_loss=1.6187, val_acc=0.450
# [RBF] Epoch 022 | train_loss=1.5287, train_acc=0.733 | val_loss=1.6188, val_acc=0.450
# [RBF] Epoch 023 | train_loss=1.5266, train_acc=0.733 | val_loss=1.6190, val_acc=0.400
# [RBF] Epoch 024 | train_loss=1.5245, train_acc=0.733 | val_loss=1.6191, val_acc=0.400
# [RBF] Epoch 025 | train_loss=1.5224, train_acc=0.844 | val_loss=1.6192, val_acc=0.400
# [RBF] Epoch 026 | train_loss=1.5203, train_acc=0.922 | val_loss=1.6193, val_acc=0.400
# [RBF] Epoch 027 | train_loss=1.5182, train_acc=0.900 | val_loss=1.6193, val_acc=0.350
# [RBF] Epoch 028 | train_loss=1.5162, train_acc=0.906 | val_loss=1.6194, val_acc=0.400
# [RBF] Epoch 029 | train_loss=1.5141, train_acc=0.894 | val_loss=1.6194, val_acc=0.400
# [RBF] Epoch 030 | train_loss=1.5120, train_acc=0.900 | val_loss=1.6194, val_acc=0.400
# [RBF] Epoch 031 | train_loss=1.5100, train_acc=0.906 | val_loss=1.6193, val_acc=0.400
# [RBF] Epoch 032 | train_loss=1.5079, train_acc=0.917 | val_loss=1.6193, val_acc=0.400
# [RBF] Epoch 033 | train_loss=1.5058, train_acc=0.917 | val_loss=1.6192, val_acc=0.350
# [RBF] Epoch 034 | train_loss=1.5037, train_acc=0.917 | val_loss=1.6191, val_acc=0.350
# [RBF] Epoch 035 | train_loss=1.5017, train_acc=0.922 | val_loss=1.6190, val_acc=0.350
# [RBF] Epoch 036 | train_loss=1.4996, train_acc=0.922 | val_loss=1.6189, val_acc=0.350
# [RBF] Epoch 037 | train_loss=1.4975, train_acc=0.922 | val_loss=1.6187, val_acc=0.400
# [RBF] Epoch 038 | train_loss=1.4954, train_acc=0.922 | val_loss=1.6186, val_acc=0.400
# [RBF] Epoch 039 | train_loss=1.4934, train_acc=0.922 | val_loss=1.6184, val_acc=0.400
# [RBF] Epoch 040 | train_loss=1.4913, train_acc=0.939 | val_loss=1.6182, val_acc=0.400
# [RBF] Epoch 041 | train_loss=1.4892, train_acc=0.950 | val_loss=1.6180, val_acc=0.400
# [RBF] Epoch 042 | train_loss=1.4871, train_acc=0.950 | val_loss=1.6178, val_acc=0.400
# [RBF] Epoch 043 | train_loss=1.4850, train_acc=0.956 | val_loss=1.6176, val_acc=0.400
# [RBF] Epoch 044 | train_loss=1.4830, train_acc=0.961 | val_loss=1.6174, val_acc=0.450
# [RBF] Epoch 045 | train_loss=1.4809, train_acc=0.989 | val_loss=1.6172, val_acc=0.450
# [RBF] Epoch 046 | train_loss=1.4788, train_acc=0.994 | val_loss=1.6170, val_acc=0.450
# [RBF] Epoch 047 | train_loss=1.4767, train_acc=0.994 | val_loss=1.6168, val_acc=0.450
# [RBF] Epoch 048 | train_loss=1.4746, train_acc=0.994 | val_loss=1.6166, val_acc=0.450
# [RBF] Epoch 049 | train_loss=1.4726, train_acc=0.994 | val_loss=1.6164, val_acc=0.450
# [RBF] Epoch 050 | train_loss=1.4705, train_acc=0.994 | val_loss=1.6161, val_acc=0.450
# [RBF] Epoch 051 | train_loss=1.4684, train_acc=0.994 | val_loss=1.6159, val_acc=0.450
# [RBF] Epoch 052 | train_loss=1.4663, train_acc=0.994 | val_loss=1.6157, val_acc=0.450
# [RBF] Epoch 053 | train_loss=1.4643, train_acc=0.994 | val_loss=1.6155, val_acc=0.450
# [RBF] Epoch 054 | train_loss=1.4622, train_acc=0.994 | val_loss=1.6154, val_acc=0.450
# [RBF] Epoch 055 | train_loss=1.4601, train_acc=0.994 | val_loss=1.6152, val_acc=0.450
# [RBF] Epoch 056 | train_loss=1.4580, train_acc=0.994 | val_loss=1.6150, val_acc=0.450
# [RBF] Epoch 057 | train_loss=1.4560, train_acc=0.994 | val_loss=1.6148, val_acc=0.450
# [RBF] Epoch 058 | train_loss=1.4539, train_acc=0.994 | val_loss=1.6146, val_acc=0.450
# [RBF] Epoch 059 | train_loss=1.4518, train_acc=0.994 | val_loss=1.6145, val_acc=0.450
# [RBF] Epoch 060 | train_loss=1.4498, train_acc=0.994 | val_loss=1.6143, val_acc=0.450
# [RBF] Epoch 061 | train_loss=1.4477, train_acc=1.000 | val_loss=1.6141, val_acc=0.450
# [RBF] Epoch 062 | train_loss=1.4456, train_acc=1.000 | val_loss=1.6140, val_acc=0.450
# [RBF] Epoch 063 | train_loss=1.4436, train_acc=1.000 | val_loss=1.6138, val_acc=0.450
# [RBF] Epoch 064 | train_loss=1.4415, train_acc=1.000 | val_loss=1.6137, val_acc=0.450
# [RBF] Epoch 065 | train_loss=1.4395, train_acc=1.000 | val_loss=1.6136, val_acc=0.450
# [RBF] Epoch 066 | train_loss=1.4374, train_acc=1.000 | val_loss=1.6134, val_acc=0.450
# [RBF] Epoch 067 | train_loss=1.4353, train_acc=1.000 | val_loss=1.6133, val_acc=0.450
# [RBF] Epoch 068 | train_loss=1.4333, train_acc=1.000 | val_loss=1.6132, val_acc=0.450
# [RBF] Epoch 069 | train_loss=1.4312, train_acc=1.000 | val_loss=1.6131, val_acc=0.450
# [RBF] Epoch 070 | train_loss=1.4292, train_acc=1.000 | val_loss=1.6129, val_acc=0.450
# [RBF] Epoch 071 | train_loss=1.4271, train_acc=1.000 | val_loss=1.6128, val_acc=0.450
# [RBF] Epoch 072 | train_loss=1.4251, train_acc=1.000 | val_loss=1.6127, val_acc=0.450
# [RBF] Epoch 073 | train_loss=1.4230, train_acc=1.000 | val_loss=1.6126, val_acc=0.450
# [RBF] Epoch 074 | train_loss=1.4210, train_acc=1.000 | val_loss=1.6125, val_acc=0.450
# [RBF] Epoch 075 | train_loss=1.4189, train_acc=1.000 | val_loss=1.6124, val_acc=0.450
# [RBF] Epoch 076 | train_loss=1.4169, train_acc=1.000 | val_loss=1.6123, val_acc=0.450
# [RBF] Epoch 077 | train_loss=1.4148, train_acc=1.000 | val_loss=1.6122, val_acc=0.450
# [RBF] Epoch 078 | train_loss=1.4128, train_acc=1.000 | val_loss=1.6121, val_acc=0.450
# [RBF] Epoch 079 | train_loss=1.4108, train_acc=1.000 | val_loss=1.6120, val_acc=0.450
# [RBF] Epoch 080 | train_loss=1.4087, train_acc=1.000 | val_loss=1.6119, val_acc=0.450
# [RBF] Epoch 081 | train_loss=1.4067, train_acc=1.000 | val_loss=1.6118, val_acc=0.450
# [RBF] Epoch 082 | train_loss=1.4046, train_acc=1.000 | val_loss=1.6117, val_acc=0.450
# [RBF] Epoch 083 | train_loss=1.4026, train_acc=1.000 | val_loss=1.6116, val_acc=0.450
# [RBF] Epoch 084 | train_loss=1.4006, train_acc=1.000 | val_loss=1.6115, val_acc=0.450
# [RBF] Epoch 085 | train_loss=1.3985, train_acc=1.000 | val_loss=1.6114, val_acc=0.450
# [RBF] Epoch 086 | train_loss=1.3965, train_acc=1.000 | val_loss=1.6113, val_acc=0.400
# [RBF] Epoch 087 | train_loss=1.3945, train_acc=1.000 | val_loss=1.6112, val_acc=0.400
# [RBF] Epoch 088 | train_loss=1.3925, train_acc=1.000 | val_loss=1.6111, val_acc=0.400
# [RBF] Epoch 089 | train_loss=1.3904, train_acc=1.000 | val_loss=1.6110, val_acc=0.400
# [RBF] Epoch 090 | train_loss=1.3884, train_acc=1.000 | val_loss=1.6109, val_acc=0.400
# [RBF] Epoch 091 | train_loss=1.3864, train_acc=1.000 | val_loss=1.6108, val_acc=0.400
# [RBF] Epoch 092 | train_loss=1.3844, train_acc=1.000 | val_loss=1.6107, val_acc=0.400
# [RBF] Epoch 093 | train_loss=1.3823, train_acc=1.000 | val_loss=1.6106, val_acc=0.400
# [RBF] Epoch 094 | train_loss=1.3803, train_acc=1.000 | val_loss=1.6105, val_acc=0.400
# [RBF] Epoch 095 | train_loss=1.3783, train_acc=1.000 | val_loss=1.6104, val_acc=0.400
# [RBF] Epoch 096 | train_loss=1.3763, train_acc=1.000 | val_loss=1.6103, val_acc=0.400
# [RBF] Epoch 097 | train_loss=1.3743, train_acc=1.000 | val_loss=1.6102, val_acc=0.400
# [RBF] Epoch 098 | train_loss=1.3723, train_acc=1.000 | val_loss=1.6101, val_acc=0.400
# [RBF] Epoch 099 | train_loss=1.3703, train_acc=1.000 | val_loss=1.6100, val_acc=0.400
# [RBF] Epoch 100 | train_loss=1.3683, train_acc=1.000 | val_loss=1.6099, val_acc=0.400
# [RBF] Epoch 101 | train_loss=1.3663, train_acc=1.000 | val_loss=1.6098, val_acc=0.400
# [RBF] Epoch 102 | train_loss=1.3643, train_acc=1.000 | val_loss=1.6097, val_acc=0.400
# [RBF] Epoch 103 | train_loss=1.3623, train_acc=1.000 | val_loss=1.6096, val_acc=0.400
# [RBF] Epoch 104 | train_loss=1.3603, train_acc=1.000 | val_loss=1.6095, val_acc=0.400
# [RBF] Epoch 105 | train_loss=1.3583, train_acc=1.000 | val_loss=1.6094, val_acc=0.400
# [RBF] Epoch 106 | train_loss=1.3563, train_acc=1.000 | val_loss=1.6093, val_acc=0.400
# [RBF] Epoch 107 | train_loss=1.3543, train_acc=1.000 | val_loss=1.6092, val_acc=0.400
# [RBF] Epoch 108 | train_loss=1.3523, train_acc=1.000 | val_loss=1.6091, val_acc=0.400
# [RBF] Epoch 109 | train_loss=1.3503, train_acc=1.000 | val_loss=1.6090, val_acc=0.400
# [RBF] Epoch 110 | train_loss=1.3483, train_acc=1.000 | val_loss=1.6089, val_acc=0.400
# [RBF] Epoch 111 | train_loss=1.3463, train_acc=1.000 | val_loss=1.6088, val_acc=0.400
# [RBF] Epoch 112 | train_loss=1.3444, train_acc=1.000 | val_loss=1.6087, val_acc=0.400
# [RBF] Epoch 113 | train_loss=1.3424, train_acc=1.000 | val_loss=1.6086, val_acc=0.400
# [RBF] Epoch 114 | train_loss=1.3404, train_acc=1.000 | val_loss=1.6085, val_acc=0.400
# [RBF] Epoch 115 | train_loss=1.3384, train_acc=1.000 | val_loss=1.6084, val_acc=0.400
# [RBF] Epoch 116 | train_loss=1.3364, train_acc=1.000 | val_loss=1.6083, val_acc=0.400
# [RBF] Epoch 117 | train_loss=1.3345, train_acc=1.000 | val_loss=1.6082, val_acc=0.400
# [RBF] Epoch 118 | train_loss=1.3325, train_acc=1.000 | val_loss=1.6081, val_acc=0.400
# [RBF] Epoch 119 | train_loss=1.3305, train_acc=1.000 | val_loss=1.6081, val_acc=0.400
# [RBF] Epoch 120 | train_loss=1.3286, train_acc=1.000 | val_loss=1.6080, val_acc=0.400
# [RBF] Epoch 121 | train_loss=1.3266, train_acc=1.000 | val_loss=1.6079, val_acc=0.400
# [RBF] Epoch 122 | train_loss=1.3246, train_acc=1.000 | val_loss=1.6078, val_acc=0.400
# [RBF] Epoch 123 | train_loss=1.3227, train_acc=1.000 | val_loss=1.6077, val_acc=0.400
# [RBF] Epoch 124 | train_loss=1.3207, train_acc=1.000 | val_loss=1.6076, val_acc=0.400
# [RBF] Epoch 125 | train_loss=1.3188, train_acc=1.000 | val_loss=1.6075, val_acc=0.400
# [RBF] Epoch 126 | train_loss=1.3168, train_acc=1.000 | val_loss=1.6074, val_acc=0.400
# [RBF] Epoch 127 | train_loss=1.3149, train_acc=1.000 | val_loss=1.6073, val_acc=0.400
# [RBF] Epoch 128 | train_loss=1.3129, train_acc=1.000 | val_loss=1.6072, val_acc=0.400
# [RBF] Epoch 129 | train_loss=1.3110, train_acc=1.000 | val_loss=1.6071, val_acc=0.400
# [RBF] Epoch 130 | train_loss=1.3090, train_acc=1.000 | val_loss=1.6071, val_acc=0.400
# [RBF] Epoch 131 | train_loss=1.3071, train_acc=1.000 | val_loss=1.6070, val_acc=0.400
# [RBF] Epoch 132 | train_loss=1.3051, train_acc=1.000 | val_loss=1.6069, val_acc=0.400
# [RBF] Epoch 133 | train_loss=1.3032, train_acc=1.000 | val_loss=1.6068, val_acc=0.400
# [RBF] Epoch 134 | train_loss=1.3013, train_acc=1.000 | val_loss=1.6067, val_acc=0.400
# [RBF] Epoch 135 | train_loss=1.2993, train_acc=1.000 | val_loss=1.6066, val_acc=0.400
# [RBF] Epoch 136 | train_loss=1.2974, train_acc=1.000 | val_loss=1.6065, val_acc=0.400
# [RBF] Epoch 137 | train_loss=1.2955, train_acc=1.000 | val_loss=1.6065, val_acc=0.400
# [RBF] Epoch 138 | train_loss=1.2936, train_acc=1.000 | val_loss=1.6064, val_acc=0.400
# [RBF] Epoch 139 | train_loss=1.2916, train_acc=1.000 | val_loss=1.6063, val_acc=0.400
# [RBF] Epoch 140 | train_loss=1.2897, train_acc=1.000 | val_loss=1.6062, val_acc=0.400
# [RBF] Epoch 141 | train_loss=1.2878, train_acc=1.000 | val_loss=1.6061, val_acc=0.400
# [RBF] Epoch 142 | train_loss=1.2859, train_acc=1.000 | val_loss=1.6060, val_acc=0.400
# [RBF] Epoch 143 | train_loss=1.2840, train_acc=1.000 | val_loss=1.6060, val_acc=0.400
# [RBF] Epoch 144 | train_loss=1.2820, train_acc=1.000 | val_loss=1.6059, val_acc=0.400
# [RBF] Epoch 145 | train_loss=1.2801, train_acc=1.000 | val_loss=1.6058, val_acc=0.400
# [RBF] Epoch 146 | train_loss=1.2782, train_acc=1.000 | val_loss=1.6057, val_acc=0.400
# [RBF] Epoch 147 | train_loss=1.2763, train_acc=1.000 | val_loss=1.6056, val_acc=0.400
# [RBF] Epoch 148 | train_loss=1.2744, train_acc=1.000 | val_loss=1.6056, val_acc=0.400
# [RBF] Epoch 149 | train_loss=1.2725, train_acc=1.000 | val_loss=1.6055, val_acc=0.400
# [RBF] Epoch 150 | train_loss=1.2706, train_acc=1.000 | val_loss=1.6054, val_acc=0.400
# [RBF] Epoch 151 | train_loss=1.2687, train_acc=1.000 | val_loss=1.6053, val_acc=0.400
# [RBF] Epoch 152 | train_loss=1.2668, train_acc=1.000 | val_loss=1.6053, val_acc=0.400
# [RBF] Epoch 153 | train_loss=1.2649, train_acc=1.000 | val_loss=1.6052, val_acc=0.400
# [RBF] Epoch 154 | train_loss=1.2630, train_acc=1.000 | val_loss=1.6051, val_acc=0.400
# [RBF] Epoch 155 | train_loss=1.2611, train_acc=1.000 | val_loss=1.6050, val_acc=0.400
# [RBF] Epoch 156 | train_loss=1.2593, train_acc=1.000 | val_loss=1.6050, val_acc=0.400
# [RBF] Epoch 157 | train_loss=1.2574, train_acc=1.000 | val_loss=1.6049, val_acc=0.400
# [RBF] Epoch 158 | train_loss=1.2555, train_acc=1.000 | val_loss=1.6048, val_acc=0.400
# [RBF] Epoch 159 | train_loss=1.2536, train_acc=1.000 | val_loss=1.6047, val_acc=0.400
# [RBF] Epoch 160 | train_loss=1.2517, train_acc=1.000 | val_loss=1.6047, val_acc=0.400
# [RBF] Epoch 161 | train_loss=1.2499, train_acc=1.000 | val_loss=1.6046, val_acc=0.400
# [RBF] Epoch 162 | train_loss=1.2480, train_acc=1.000 | val_loss=1.6045, val_acc=0.400
# [RBF] Epoch 163 | train_loss=1.2461, train_acc=1.000 | val_loss=1.6044, val_acc=0.400
# [RBF] Epoch 164 | train_loss=1.2442, train_acc=1.000 | val_loss=1.6044, val_acc=0.400
# [RBF] Epoch 165 | train_loss=1.2424, train_acc=1.000 | val_loss=1.6043, val_acc=0.400
# [RBF] Epoch 166 | train_loss=1.2405, train_acc=1.000 | val_loss=1.6042, val_acc=0.400
# [RBF] Epoch 167 | train_loss=1.2387, train_acc=1.000 | val_loss=1.6042, val_acc=0.400
# [RBF] Epoch 168 | train_loss=1.2368, train_acc=1.000 | val_loss=1.6041, val_acc=0.400
# [RBF] Epoch 169 | train_loss=1.2349, train_acc=1.000 | val_loss=1.6040, val_acc=0.400
# [RBF] Epoch 170 | train_loss=1.2331, train_acc=1.000 | val_loss=1.6040, val_acc=0.400
# [RBF] Epoch 171 | train_loss=1.2312, train_acc=1.000 | val_loss=1.6039, val_acc=0.400
# [RBF] Epoch 172 | train_loss=1.2294, train_acc=1.000 | val_loss=1.6038, val_acc=0.400
# [RBF] Epoch 173 | train_loss=1.2275, train_acc=1.000 | val_loss=1.6037, val_acc=0.400
# [RBF] Epoch 174 | train_loss=1.2257, train_acc=1.000 | val_loss=1.6037, val_acc=0.400
# [RBF] Epoch 175 | train_loss=1.2239, train_acc=1.000 | val_loss=1.6036, val_acc=0.400
# [RBF] Epoch 176 | train_loss=1.2220, train_acc=1.000 | val_loss=1.6035, val_acc=0.400
# [RBF] Epoch 177 | train_loss=1.2202, train_acc=1.000 | val_loss=1.6035, val_acc=0.400
# [RBF] Epoch 178 | train_loss=1.2183, train_acc=1.000 | val_loss=1.6034, val_acc=0.400
# [RBF] Epoch 179 | train_loss=1.2165, train_acc=1.000 | val_loss=1.6033, val_acc=0.400
# [RBF] Epoch 180 | train_loss=1.2147, train_acc=1.000 | val_loss=1.6033, val_acc=0.400
# [RBF] Epoch 181 | train_loss=1.2128, train_acc=1.000 | val_loss=1.6032, val_acc=0.400
# [RBF] Epoch 182 | train_loss=1.2110, train_acc=1.000 | val_loss=1.6032, val_acc=0.400
# [RBF] Epoch 183 | train_loss=1.2092, train_acc=1.000 | val_loss=1.6031, val_acc=0.400
# [RBF] Epoch 184 | train_loss=1.2074, train_acc=1.000 | val_loss=1.6030, val_acc=0.400
# [RBF] Epoch 185 | train_loss=1.2056, train_acc=1.000 | val_loss=1.6030, val_acc=0.400
# [RBF] Epoch 186 | train_loss=1.2037, train_acc=1.000 | val_loss=1.6029, val_acc=0.400
# [RBF] Epoch 187 | train_loss=1.2019, train_acc=1.000 | val_loss=1.6028, val_acc=0.400
# [RBF] Epoch 188 | train_loss=1.2001, train_acc=1.000 | val_loss=1.6028, val_acc=0.400
# [RBF] Epoch 189 | train_loss=1.1983, train_acc=1.000 | val_loss=1.6027, val_acc=0.400
# [RBF] Epoch 190 | train_loss=1.1965, train_acc=1.000 | val_loss=1.6027, val_acc=0.400
# [RBF] Epoch 191 | train_loss=1.1947, train_acc=1.000 | val_loss=1.6026, val_acc=0.400
# [RBF] Epoch 192 | train_loss=1.1929, train_acc=1.000 | val_loss=1.6025, val_acc=0.400
# [RBF] Epoch 193 | train_loss=1.1911, train_acc=1.000 | val_loss=1.6025, val_acc=0.400
# [RBF] Epoch 194 | train_loss=1.1893, train_acc=1.000 | val_loss=1.6024, val_acc=0.400
# [RBF] Epoch 195 | train_loss=1.1875, train_acc=1.000 | val_loss=1.6024, val_acc=0.400
# [RBF] Epoch 196 | train_loss=1.1857, train_acc=1.000 | val_loss=1.6023, val_acc=0.400
# [RBF] Epoch 197 | train_loss=1.1839, train_acc=1.000 | val_loss=1.6023, val_acc=0.400
# [RBF] Epoch 198 | train_loss=1.1821, train_acc=1.000 | val_loss=1.6022, val_acc=0.400
# [RBF] Epoch 199 | train_loss=1.1803, train_acc=1.000 | val_loss=1.6021, val_acc=0.400
# [RBF] Epoch 200 | train_loss=1.1786, train_acc=1.000 | val_loss=1.6021, val_acc=0.400
# [RBF] Epoch 201 | train_loss=1.1768, train_acc=1.000 | val_loss=1.6020, val_acc=0.400
# [RBF] Epoch 202 | train_loss=1.1750, train_acc=1.000 | val_loss=1.6020, val_acc=0.400
# [RBF] Epoch 203 | train_loss=1.1732, train_acc=1.000 | val_loss=1.6019, val_acc=0.400
# [RBF] Epoch 204 | train_loss=1.1715, train_acc=1.000 | val_loss=1.6019, val_acc=0.400
# [RBF] Epoch 205 | train_loss=1.1697, train_acc=1.000 | val_loss=1.6018, val_acc=0.400
# [RBF] Epoch 206 | train_loss=1.1679, train_acc=1.000 | val_loss=1.6018, val_acc=0.400
# [RBF] Epoch 207 | train_loss=1.1662, train_acc=1.000 | val_loss=1.6017, val_acc=0.400
# [RBF] Epoch 208 | train_loss=1.1644, train_acc=1.000 | val_loss=1.6017, val_acc=0.400
# [RBF] Epoch 209 | train_loss=1.1626, train_acc=1.000 | val_loss=1.6016, val_acc=0.400
# [RBF] Epoch 210 | train_loss=1.1609, train_acc=1.000 | val_loss=1.6015, val_acc=0.400
# [RBF] Epoch 211 | train_loss=1.1591, train_acc=1.000 | val_loss=1.6015, val_acc=0.400
# [RBF] Epoch 212 | train_loss=1.1574, train_acc=1.000 | val_loss=1.6014, val_acc=0.400
# [RBF] Epoch 213 | train_loss=1.1556, train_acc=1.000 | val_loss=1.6014, val_acc=0.400
# [RBF] Epoch 214 | train_loss=1.1539, train_acc=1.000 | val_loss=1.6013, val_acc=0.400
# [RBF] Epoch 215 | train_loss=1.1521, train_acc=1.000 | val_loss=1.6013, val_acc=0.400
# [RBF] Epoch 216 | train_loss=1.1504, train_acc=1.000 | val_loss=1.6012, val_acc=0.400
# [RBF] Epoch 217 | train_loss=1.1486, train_acc=1.000 | val_loss=1.6012, val_acc=0.400
# [RBF] Epoch 218 | train_loss=1.1469, train_acc=1.000 | val_loss=1.6011, val_acc=0.400
# [RBF] Epoch 219 | train_loss=1.1452, train_acc=1.000 | val_loss=1.6011, val_acc=0.400
# [RBF] Epoch 220 | train_loss=1.1434, train_acc=1.000 | val_loss=1.6011, val_acc=0.400
# [RBF] Epoch 221 | train_loss=1.1417, train_acc=1.000 | val_loss=1.6010, val_acc=0.400
# [RBF] Epoch 222 | train_loss=1.1400, train_acc=1.000 | val_loss=1.6010, val_acc=0.400
# [RBF] Epoch 223 | train_loss=1.1382, train_acc=1.000 | val_loss=1.6009, val_acc=0.400
# [RBF] Epoch 224 | train_loss=1.1365, train_acc=1.000 | val_loss=1.6009, val_acc=0.400
# [RBF] Epoch 225 | train_loss=1.1348, train_acc=1.000 | val_loss=1.6008, val_acc=0.400
# [RBF] Epoch 226 | train_loss=1.1331, train_acc=1.000 | val_loss=1.6008, val_acc=0.400
# [RBF] Epoch 227 | train_loss=1.1313, train_acc=1.000 | val_loss=1.6007, val_acc=0.400
# [RBF] Epoch 228 | train_loss=1.1296, train_acc=1.000 | val_loss=1.6007, val_acc=0.400
# [RBF] Epoch 229 | train_loss=1.1279, train_acc=1.000 | val_loss=1.6006, val_acc=0.400
# [RBF] Epoch 230 | train_loss=1.1262, train_acc=1.000 | val_loss=1.6006, val_acc=0.400
# [RBF] Epoch 231 | train_loss=1.1245, train_acc=1.000 | val_loss=1.6006, val_acc=0.400
# [RBF] Epoch 232 | train_loss=1.1228, train_acc=1.000 | val_loss=1.6005, val_acc=0.400
# [RBF] Epoch 233 | train_loss=1.1211, train_acc=1.000 | val_loss=1.6005, val_acc=0.400
# [RBF] Epoch 234 | train_loss=1.1194, train_acc=1.000 | val_loss=1.6004, val_acc=0.400
# [RBF] Epoch 235 | train_loss=1.1177, train_acc=1.000 | val_loss=1.6004, val_acc=0.400
# [RBF] Epoch 236 | train_loss=1.1160, train_acc=1.000 | val_loss=1.6003, val_acc=0.400
# [RBF] Epoch 237 | train_loss=1.1143, train_acc=1.000 | val_loss=1.6003, val_acc=0.400
# [RBF] Epoch 238 | train_loss=1.1126, train_acc=1.000 | val_loss=1.6003, val_acc=0.400
# [RBF] Epoch 239 | train_loss=1.1109, train_acc=1.000 | val_loss=1.6002, val_acc=0.400
# [RBF] Epoch 240 | train_loss=1.1092, train_acc=1.000 | val_loss=1.6002, val_acc=0.400
# [RBF] Epoch 241 | train_loss=1.1076, train_acc=1.000 | val_loss=1.6001, val_acc=0.400
# [RBF] Epoch 242 | train_loss=1.1059, train_acc=1.000 | val_loss=1.6001, val_acc=0.400
# [RBF] Epoch 243 | train_loss=1.1042, train_acc=1.000 | val_loss=1.6001, val_acc=0.400
# [RBF] Epoch 244 | train_loss=1.1025, train_acc=1.000 | val_loss=1.6000, val_acc=0.400
# [RBF] Epoch 245 | train_loss=1.1008, train_acc=1.000 | val_loss=1.6000, val_acc=0.400
# [RBF] Epoch 246 | train_loss=1.0992, train_acc=1.000 | val_loss=1.6000, val_acc=0.400
# [RBF] Epoch 247 | train_loss=1.0975, train_acc=1.000 | val_loss=1.5999, val_acc=0.400
# [RBF] Epoch 248 | train_loss=1.0958, train_acc=1.000 | val_loss=1.5999, val_acc=0.400
# [RBF] Epoch 249 | train_loss=1.0942, train_acc=1.000 | val_loss=1.5998, val_acc=0.400
# [RBF] Epoch 250 | train_loss=1.0925, train_acc=1.000 | val_loss=1.5998, val_acc=0.400
# [RBF] Epoch 251 | train_loss=1.0908, train_acc=1.000 | val_loss=1.5998, val_acc=0.400
# [RBF] Epoch 252 | train_loss=1.0892, train_acc=1.000 | val_loss=1.5997, val_acc=0.400
# [RBF] Epoch 253 | train_loss=1.0875, train_acc=1.000 | val_loss=1.5997, val_acc=0.400
# [RBF] Epoch 254 | train_loss=1.0859, train_acc=1.000 | val_loss=1.5997, val_acc=0.400
# [RBF] Epoch 255 | train_loss=1.0842, train_acc=1.000 | val_loss=1.5996, val_acc=0.400
# [RBF] Epoch 256 | train_loss=1.0826, train_acc=1.000 | val_loss=1.5996, val_acc=0.400
# [RBF] Epoch 257 | train_loss=1.0809, train_acc=1.000 | val_loss=1.5996, val_acc=0.400
# [RBF] Epoch 258 | train_loss=1.0793, train_acc=1.000 | val_loss=1.5995, val_acc=0.400
# [RBF] Epoch 259 | train_loss=1.0777, train_acc=1.000 | val_loss=1.5995, val_acc=0.400
# [RBF] Epoch 260 | train_loss=1.0760, train_acc=1.000 | val_loss=1.5995, val_acc=0.400
# [RBF] Epoch 261 | train_loss=1.0744, train_acc=1.000 | val_loss=1.5994, val_acc=0.400
# [RBF] Epoch 262 | train_loss=1.0728, train_acc=1.000 | val_loss=1.5994, val_acc=0.400
# [RBF] Epoch 263 | train_loss=1.0711, train_acc=1.000 | val_loss=1.5994, val_acc=0.400
# [RBF] Epoch 264 | train_loss=1.0695, train_acc=1.000 | val_loss=1.5994, val_acc=0.400
# [RBF] Epoch 265 | train_loss=1.0679, train_acc=1.000 | val_loss=1.5993, val_acc=0.400
# [RBF] Epoch 266 | train_loss=1.0662, train_acc=1.000 | val_loss=1.5993, val_acc=0.400
# [RBF] Epoch 267 | train_loss=1.0646, train_acc=1.000 | val_loss=1.5993, val_acc=0.400
# [RBF] Epoch 268 | train_loss=1.0630, train_acc=1.000 | val_loss=1.5992, val_acc=0.400
# [RBF] Epoch 269 | train_loss=1.0614, train_acc=1.000 | val_loss=1.5992, val_acc=0.400
# [RBF] Epoch 270 | train_loss=1.0598, train_acc=1.000 | val_loss=1.5992, val_acc=0.400
# [RBF] Epoch 271 | train_loss=1.0582, train_acc=1.000 | val_loss=1.5991, val_acc=0.400
# [RBF] Epoch 272 | train_loss=1.0566, train_acc=1.000 | val_loss=1.5991, val_acc=0.400
# [RBF] Epoch 273 | train_loss=1.0550, train_acc=1.000 | val_loss=1.5991, val_acc=0.400
# [RBF] Epoch 274 | train_loss=1.0533, train_acc=1.000 | val_loss=1.5991, val_acc=0.400
# [RBF] Epoch 275 | train_loss=1.0517, train_acc=1.000 | val_loss=1.5990, val_acc=0.400
# [RBF] Epoch 276 | train_loss=1.0501, train_acc=1.000 | val_loss=1.5990, val_acc=0.400
# [RBF] Epoch 277 | train_loss=1.0485, train_acc=1.000 | val_loss=1.5990, val_acc=0.400
# [RBF] Epoch 278 | train_loss=1.0470, train_acc=1.000 | val_loss=1.5990, val_acc=0.400
# [RBF] Epoch 279 | train_loss=1.0454, train_acc=1.000 | val_loss=1.5989, val_acc=0.400
# [RBF] Epoch 280 | train_loss=1.0438, train_acc=1.000 | val_loss=1.5989, val_acc=0.400
# [RBF] Epoch 281 | train_loss=1.0422, train_acc=1.000 | val_loss=1.5989, val_acc=0.400
# [RBF] Epoch 282 | train_loss=1.0406, train_acc=1.000 | val_loss=1.5989, val_acc=0.400
# [RBF] Epoch 283 | train_loss=1.0390, train_acc=1.000 | val_loss=1.5988, val_acc=0.400
# [RBF] Epoch 284 | train_loss=1.0374, train_acc=1.000 | val_loss=1.5988, val_acc=0.400
# [RBF] Epoch 285 | train_loss=1.0359, train_acc=1.000 | val_loss=1.5988, val_acc=0.400
# [RBF] Epoch 286 | train_loss=1.0343, train_acc=1.000 | val_loss=1.5988, val_acc=0.400
# [RBF] Epoch 287 | train_loss=1.0327, train_acc=1.000 | val_loss=1.5988, val_acc=0.400
# [RBF] Epoch 288 | train_loss=1.0311, train_acc=1.000 | val_loss=1.5987, val_acc=0.400
# [RBF] Epoch 289 | train_loss=1.0296, train_acc=1.000 | val_loss=1.5987, val_acc=0.400
# [RBF] Epoch 290 | train_loss=1.0280, train_acc=1.000 | val_loss=1.5987, val_acc=0.400
# [RBF] Epoch 291 | train_loss=1.0264, train_acc=1.000 | val_loss=1.5987, val_acc=0.400
# [RBF] Epoch 292 | train_loss=1.0249, train_acc=1.000 | val_loss=1.5987, val_acc=0.400
# [RBF] Epoch 293 | train_loss=1.0233, train_acc=1.000 | val_loss=1.5986, val_acc=0.400
# [RBF] Epoch 294 | train_loss=1.0218, train_acc=1.000 | val_loss=1.5986, val_acc=0.400
# [RBF] Epoch 295 | train_loss=1.0202, train_acc=1.000 | val_loss=1.5986, val_acc=0.400
# [RBF] Epoch 296 | train_loss=1.0187, train_acc=1.000 | val_loss=1.5986, val_acc=0.400
# [RBF] Epoch 297 | train_loss=1.0171, train_acc=1.000 | val_loss=1.5986, val_acc=0.400
# [RBF] Epoch 298 | train_loss=1.0156, train_acc=1.000 | val_loss=1.5985, val_acc=0.400
# [RBF] Epoch 299 | train_loss=1.0140, train_acc=1.000 | val_loss=1.5985, val_acc=0.400
# [RBF] Epoch 300 | train_loss=1.0125, train_acc=1.000 | val_loss=1.5985, val_acc=0.400
# [RBF] Epoch 301 | train_loss=1.0109, train_acc=1.000 | val_loss=1.5985, val_acc=0.400
# [RBF] Epoch 302 | train_loss=1.0094, train_acc=1.000 | val_loss=1.5985, val_acc=0.400
# [RBF] Epoch 303 | train_loss=1.0079, train_acc=1.000 | val_loss=1.5985, val_acc=0.400
# [RBF] Epoch 304 | train_loss=1.0063, train_acc=1.000 | val_loss=1.5984, val_acc=0.400
# [RBF] Epoch 305 | train_loss=1.0048, train_acc=1.000 | val_loss=1.5984, val_acc=0.400
# [RBF] Epoch 306 | train_loss=1.0033, train_acc=1.000 | val_loss=1.5984, val_acc=0.400
# [RBF] Epoch 307 | train_loss=1.0018, train_acc=1.000 | val_loss=1.5984, val_acc=0.400
# [RBF] Epoch 308 | train_loss=1.0002, train_acc=1.000 | val_loss=1.5984, val_acc=0.400
# [RBF] Epoch 309 | train_loss=0.9987, train_acc=1.000 | val_loss=1.5984, val_acc=0.400
# [RBF] Epoch 310 | train_loss=0.9972, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 311 | train_loss=0.9957, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 312 | train_loss=0.9942, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 313 | train_loss=0.9927, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 314 | train_loss=0.9911, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 315 | train_loss=0.9896, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 316 | train_loss=0.9881, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 317 | train_loss=0.9866, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 318 | train_loss=0.9851, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 319 | train_loss=0.9836, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 320 | train_loss=0.9821, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 321 | train_loss=0.9806, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 322 | train_loss=0.9792, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 323 | train_loss=0.9777, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 324 | train_loss=0.9762, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 325 | train_loss=0.9747, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 326 | train_loss=0.9732, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 327 | train_loss=0.9717, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 328 | train_loss=0.9703, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 329 | train_loss=0.9688, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 330 | train_loss=0.9673, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 331 | train_loss=0.9658, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 332 | train_loss=0.9644, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 333 | train_loss=0.9629, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 334 | train_loss=0.9615, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 335 | train_loss=0.9600, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 336 | train_loss=0.9585, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 337 | train_loss=0.9571, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 338 | train_loss=0.9556, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 339 | train_loss=0.9542, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 340 | train_loss=0.9527, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 341 | train_loss=0.9513, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 342 | train_loss=0.9498, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 343 | train_loss=0.9484, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 344 | train_loss=0.9470, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 345 | train_loss=0.9455, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 346 | train_loss=0.9441, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 347 | train_loss=0.9427, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 348 | train_loss=0.9412, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 349 | train_loss=0.9398, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 350 | train_loss=0.9384, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 351 | train_loss=0.9369, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 352 | train_loss=0.9355, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 353 | train_loss=0.9341, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 354 | train_loss=0.9327, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 355 | train_loss=0.9313, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 356 | train_loss=0.9299, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 357 | train_loss=0.9285, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 358 | train_loss=0.9271, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 359 | train_loss=0.9256, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 360 | train_loss=0.9242, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 361 | train_loss=0.9228, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 362 | train_loss=0.9214, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 363 | train_loss=0.9200, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 364 | train_loss=0.9187, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 365 | train_loss=0.9173, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 366 | train_loss=0.9159, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 367 | train_loss=0.9145, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 368 | train_loss=0.9131, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 369 | train_loss=0.9117, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 370 | train_loss=0.9103, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 371 | train_loss=0.9090, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 372 | train_loss=0.9076, train_acc=1.000 | val_loss=1.5981, val_acc=0.400
# [RBF] Epoch 373 | train_loss=0.9062, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 374 | train_loss=0.9048, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 375 | train_loss=0.9035, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 376 | train_loss=0.9021, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 377 | train_loss=0.9007, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 378 | train_loss=0.8994, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 379 | train_loss=0.8980, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 380 | train_loss=0.8967, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 381 | train_loss=0.8953, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 382 | train_loss=0.8939, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 383 | train_loss=0.8926, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 384 | train_loss=0.8912, train_acc=1.000 | val_loss=1.5982, val_acc=0.400
# [RBF] Epoch 385 | train_loss=0.8899, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 386 | train_loss=0.8886, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 387 | train_loss=0.8872, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 388 | train_loss=0.8859, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 389 | train_loss=0.8845, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 390 | train_loss=0.8832, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 391 | train_loss=0.8819, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 392 | train_loss=0.8805, train_acc=1.000 | val_loss=1.5983, val_acc=0.400
# [RBF] Epoch 393 | train_loss=0.8792, train_acc=1.000 | val_loss=1.5984, val_acc=0.400
# [RBF] Epoch 394 | train_loss=0.8779, train_acc=1.000 | val_loss=1.5984, val_acc=0.400
# [RBF] Epoch 395 | train_loss=0.8765, train_acc=1.000 | val_loss=1.5984, val_acc=0.400
# [RBF] Epoch 396 | train_loss=0.8752, train_acc=1.000 | val_loss=1.5984, val_acc=0.400
# [RBF] Epoch 397 | train_loss=0.8739, train_acc=1.000 | val_loss=1.5984, val_acc=0.400
# [RBF] Epoch 398 | train_loss=0.8726, train_acc=1.000 | val_loss=1.5984, val_acc=0.400
# [RBF] Epoch 399 | train_loss=0.8713, train_acc=1.000 | val_loss=1.5984, val_acc=0.400
# [RBF] Epoch 400 | train_loss=0.8700, train_acc=1.000 | val_loss=1.5985, val_acc=0.400
# [RBF] Epoch 401 | train_loss=0.8686, train_acc=1.000 | val_loss=1.5985, val_acc=0.400
# [RBF] Epoch 402 | train_loss=0.8673, train_acc=1.000 | val_loss=1.5985, val_acc=0.400
# [RBF] Epoch 403 | train_loss=0.8660, train_acc=1.000 | val_loss=1.5985, val_acc=0.400
# [RBF] Epoch 404 | train_loss=0.8647, train_acc=1.000 | val_loss=1.5985, val_acc=0.400
# [RBF] Epoch 405 | train_loss=0.8634, train_acc=1.000 | val_loss=1.5985, val_acc=0.400
# [RBF] Epoch 406 | train_loss=0.8621, train_acc=1.000 | val_loss=1.5986, val_acc=0.400
# [RBF] Epoch 407 | train_loss=0.8608, train_acc=1.000 | val_loss=1.5986, val_acc=0.400
# [RBF] Epoch 408 | train_loss=0.8595, train_acc=1.000 | val_loss=1.5986, val_acc=0.400
# [RBF] Epoch 409 | train_loss=0.8582, train_acc=1.000 | val_loss=1.5986, val_acc=0.400
# [RBF] Epoch 410 | train_loss=0.8569, train_acc=1.000 | val_loss=1.5986, val_acc=0.400
# [RBF] Epoch 411 | train_loss=0.8556, train_acc=1.000 | val_loss=1.5986, val_acc=0.400
# [RBF] Epoch 412 | train_loss=0.8544, train_acc=1.000 | val_loss=1.5987, val_acc=0.400
# [RBF] Epoch 413 | train_loss=0.8531, train_acc=1.000 | val_loss=1.5987, val_acc=0.400
# [RBF] Epoch 414 | train_loss=0.8518, train_acc=1.000 | val_loss=1.5987, val_acc=0.400
# [RBF] Epoch 415 | train_loss=0.8505, train_acc=1.000 | val_loss=1.5987, val_acc=0.400
# [RBF] Epoch 416 | train_loss=0.8492, train_acc=1.000 | val_loss=1.5987, val_acc=0.400
# [RBF] Epoch 417 | train_loss=0.8479, train_acc=1.000 | val_loss=1.5988, val_acc=0.400
# [RBF] Epoch 418 | train_loss=0.8467, train_acc=1.000 | val_loss=1.5988, val_acc=0.400
# [RBF] Epoch 419 | train_loss=0.8454, train_acc=1.000 | val_loss=1.5988, val_acc=0.400
# [RBF] Epoch 420 | train_loss=0.8441, train_acc=1.000 | val_loss=1.5988, val_acc=0.400
# [RBF] Epoch 421 | train_loss=0.8428, train_acc=1.000 | val_loss=1.5988, val_acc=0.400
# [RBF] Epoch 422 | train_loss=0.8416, train_acc=1.000 | val_loss=1.5989, val_acc=0.400
# [RBF] Epoch 423 | train_loss=0.8403, train_acc=1.000 | val_loss=1.5989, val_acc=0.400
# [RBF] Epoch 424 | train_loss=0.8391, train_acc=1.000 | val_loss=1.5989, val_acc=0.400
# [RBF] Epoch 425 | train_loss=0.8378, train_acc=1.000 | val_loss=1.5989, val_acc=0.400
# [RBF] Epoch 426 | train_loss=0.8365, train_acc=1.000 | val_loss=1.5989, val_acc=0.400
# [RBF] Epoch 427 | train_loss=0.8353, train_acc=1.000 | val_loss=1.5990, val_acc=0.400
# [RBF] Epoch 428 | train_loss=0.8340, train_acc=1.000 | val_loss=1.5990, val_acc=0.400
# [RBF] Epoch 429 | train_loss=0.8328, train_acc=1.000 | val_loss=1.5990, val_acc=0.400
# [RBF] Epoch 430 | train_loss=0.8315, train_acc=1.000 | val_loss=1.5990, val_acc=0.400
# [RBF] Epoch 431 | train_loss=0.8303, train_acc=1.000 | val_loss=1.5991, val_acc=0.400
# [RBF] Epoch 432 | train_loss=0.8290, train_acc=1.000 | val_loss=1.5991, val_acc=0.400
# [RBF] Epoch 433 | train_loss=0.8278, train_acc=1.000 | val_loss=1.5991, val_acc=0.400
# [RBF] Epoch 434 | train_loss=0.8265, train_acc=1.000 | val_loss=1.5991, val_acc=0.400
# [RBF] Epoch 435 | train_loss=0.8253, train_acc=1.000 | val_loss=1.5992, val_acc=0.400
# [RBF] Epoch 436 | train_loss=0.8241, train_acc=1.000 | val_loss=1.5992, val_acc=0.400
# [RBF] Epoch 437 | train_loss=0.8228, train_acc=1.000 | val_loss=1.5992, val_acc=0.400
# [RBF] Epoch 438 | train_loss=0.8216, train_acc=1.000 | val_loss=1.5992, val_acc=0.400
# [RBF] Epoch 439 | train_loss=0.8204, train_acc=1.000 | val_loss=1.5993, val_acc=0.400
# [RBF] Epoch 440 | train_loss=0.8191, train_acc=1.000 | val_loss=1.5993, val_acc=0.400
# [RBF] Epoch 441 | train_loss=0.8179, train_acc=1.000 | val_loss=1.5993, val_acc=0.400
# [RBF] Epoch 442 | train_loss=0.8167, train_acc=1.000 | val_loss=1.5993, val_acc=0.400
# [RBF] Epoch 443 | train_loss=0.8154, train_acc=1.000 | val_loss=1.5994, val_acc=0.400
# [RBF] Epoch 444 | train_loss=0.8142, train_acc=1.000 | val_loss=1.5994, val_acc=0.400
# [RBF] Epoch 445 | train_loss=0.8130, train_acc=1.000 | val_loss=1.5994, val_acc=0.400
# [RBF] Epoch 446 | train_loss=0.8118, train_acc=1.000 | val_loss=1.5995, val_acc=0.400
# [RBF] Epoch 447 | train_loss=0.8106, train_acc=1.000 | val_loss=1.5995, val_acc=0.400
# [RBF] Epoch 448 | train_loss=0.8094, train_acc=1.000 | val_loss=1.5995, val_acc=0.400
# [RBF] Epoch 449 | train_loss=0.8081, train_acc=1.000 | val_loss=1.5995, val_acc=0.400
# [RBF] Epoch 450 | train_loss=0.8069, train_acc=1.000 | val_loss=1.5996, val_acc=0.400
# [RBF] Epoch 451 | train_loss=0.8057, train_acc=1.000 | val_loss=1.5996, val_acc=0.400
# [RBF] Epoch 452 | train_loss=0.8045, train_acc=1.000 | val_loss=1.5996, val_acc=0.400
# [RBF] Epoch 453 | train_loss=0.8033, train_acc=1.000 | val_loss=1.5997, val_acc=0.400
# [RBF] Epoch 454 | train_loss=0.8021, train_acc=1.000 | val_loss=1.5997, val_acc=0.400
# [RBF] Epoch 455 | train_loss=0.8009, train_acc=1.000 | val_loss=1.5997, val_acc=0.400
# [RBF] Epoch 456 | train_loss=0.7997, train_acc=1.000 | val_loss=1.5998, val_acc=0.400
# [RBF] Epoch 457 | train_loss=0.7985, train_acc=1.000 | val_loss=1.5998, val_acc=0.400
# [RBF] Epoch 458 | train_loss=0.7973, train_acc=1.000 | val_loss=1.5998, val_acc=0.400
# [RBF] Epoch 459 | train_loss=0.7961, train_acc=1.000 | val_loss=1.5998, val_acc=0.400
# [RBF] Epoch 460 | train_loss=0.7950, train_acc=1.000 | val_loss=1.5999, val_acc=0.400
# [RBF] Epoch 461 | train_loss=0.7938, train_acc=1.000 | val_loss=1.5999, val_acc=0.400
# [RBF] Epoch 462 | train_loss=0.7926, train_acc=1.000 | val_loss=1.5999, val_acc=0.400
# [RBF] Epoch 463 | train_loss=0.7914, train_acc=1.000 | val_loss=1.6000, val_acc=0.400
# [RBF] Epoch 464 | train_loss=0.7902, train_acc=1.000 | val_loss=1.6000, val_acc=0.400
# [RBF] Epoch 465 | train_loss=0.7890, train_acc=1.000 | val_loss=1.6000, val_acc=0.400
# [RBF] Epoch 466 | train_loss=0.7879, train_acc=1.000 | val_loss=1.6001, val_acc=0.400
# [RBF] Epoch 467 | train_loss=0.7867, train_acc=1.000 | val_loss=1.6001, val_acc=0.400
# [RBF] Epoch 468 | train_loss=0.7855, train_acc=1.000 | val_loss=1.6001, val_acc=0.400
# [RBF] Epoch 469 | train_loss=0.7843, train_acc=1.000 | val_loss=1.6002, val_acc=0.400
# [RBF] Epoch 470 | train_loss=0.7832, train_acc=1.000 | val_loss=1.6002, val_acc=0.400
# [RBF] Epoch 471 | train_loss=0.7820, train_acc=1.000 | val_loss=1.6002, val_acc=0.400
# [RBF] Epoch 472 | train_loss=0.7808, train_acc=1.000 | val_loss=1.6003, val_acc=0.400
# [RBF] Epoch 473 | train_loss=0.7797, train_acc=1.000 | val_loss=1.6003, val_acc=0.400
# [RBF] Epoch 474 | train_loss=0.7785, train_acc=1.000 | val_loss=1.6004, val_acc=0.400
# [RBF] Epoch 475 | train_loss=0.7774, train_acc=1.000 | val_loss=1.6004, val_acc=0.400
# [RBF] Epoch 476 | train_loss=0.7762, train_acc=1.000 | val_loss=1.6004, val_acc=0.400
# [RBF] Epoch 477 | train_loss=0.7750, train_acc=1.000 | val_loss=1.6005, val_acc=0.400
# [RBF] Epoch 478 | train_loss=0.7739, train_acc=1.000 | val_loss=1.6005, val_acc=0.400
# [RBF] Epoch 479 | train_loss=0.7727, train_acc=1.000 | val_loss=1.6005, val_acc=0.400
# [RBF] Epoch 480 | train_loss=0.7716, train_acc=1.000 | val_loss=1.6006, val_acc=0.400
# [RBF] Epoch 481 | train_loss=0.7704, train_acc=1.000 | val_loss=1.6006, val_acc=0.400
# [RBF] Epoch 482 | train_loss=0.7693, train_acc=1.000 | val_loss=1.6006, val_acc=0.400
# [RBF] Epoch 483 | train_loss=0.7681, train_acc=1.000 | val_loss=1.6007, val_acc=0.400
# [RBF] Epoch 484 | train_loss=0.7670, train_acc=1.000 | val_loss=1.6007, val_acc=0.400
# [RBF] Epoch 485 | train_loss=0.7659, train_acc=1.000 | val_loss=1.6008, val_acc=0.400
# [RBF] Epoch 486 | train_loss=0.7647, train_acc=1.000 | val_loss=1.6008, val_acc=0.400
# [RBF] Epoch 487 | train_loss=0.7636, train_acc=1.000 | val_loss=1.6008, val_acc=0.400
# [RBF] Epoch 488 | train_loss=0.7625, train_acc=1.000 | val_loss=1.6009, val_acc=0.400
# [RBF] Epoch 489 | train_loss=0.7613, train_acc=1.000 | val_loss=1.6009, val_acc=0.400
# [RBF] Epoch 490 | train_loss=0.7602, train_acc=1.000 | val_loss=1.6010, val_acc=0.400
# [RBF] Epoch 491 | train_loss=0.7591, train_acc=1.000 | val_loss=1.6010, val_acc=0.400
# [RBF] Epoch 492 | train_loss=0.7579, train_acc=1.000 | val_loss=1.6010, val_acc=0.400
# [RBF] Epoch 493 | train_loss=0.7568, train_acc=1.000 | val_loss=1.6011, val_acc=0.400
# [RBF] Epoch 494 | train_loss=0.7557, train_acc=1.000 | val_loss=1.6011, val_acc=0.400
# [RBF] Epoch 495 | train_loss=0.7546, train_acc=1.000 | val_loss=1.6012, val_acc=0.400
# [RBF] Epoch 496 | train_loss=0.7535, train_acc=1.000 | val_loss=1.6012, val_acc=0.400
# [RBF] Epoch 497 | train_loss=0.7523, train_acc=1.000 | val_loss=1.6012, val_acc=0.400
# [RBF] Epoch 498 | train_loss=0.7512, train_acc=1.000 | val_loss=1.6013, val_acc=0.400
# [RBF] Epoch 499 | train_loss=0.7501, train_acc=1.000 | val_loss=1.6013, val_acc=0.400
# [RBF] Epoch 500 | train_loss=0.7490, train_acc=1.000 | val_loss=1.6014, val_acc=0.400
# [RBF] Epoch 501 | train_loss=0.7479, train_acc=1.000 | val_loss=1.6014, val_acc=0.400
# [RBF] Epoch 502 | train_loss=0.7468, train_acc=1.000 | val_loss=1.6015, val_acc=0.400
# [RBF] Epoch 503 | train_loss=0.7457, train_acc=1.000 | val_loss=1.6015, val_acc=0.400
# [RBF] Epoch 504 | train_loss=0.7446, train_acc=1.000 | val_loss=1.6015, val_acc=0.400
# [RBF] Epoch 505 | train_loss=0.7435, train_acc=1.000 | val_loss=1.6016, val_acc=0.400
# [RBF] Epoch 506 | train_loss=0.7424, train_acc=1.000 | val_loss=1.6016, val_acc=0.400
# [RBF] Epoch 507 | train_loss=0.7413, train_acc=1.000 | val_loss=1.6017, val_acc=0.400
# [RBF] Epoch 508 | train_loss=0.7402, train_acc=1.000 | val_loss=1.6017, val_acc=0.400
# [RBF] Epoch 509 | train_loss=0.7391, train_acc=1.000 | val_loss=1.6018, val_acc=0.400
# [RBF] Epoch 510 | train_loss=0.7380, train_acc=1.000 | val_loss=1.6018, val_acc=0.400
# [RBF] Epoch 511 | train_loss=0.7369, train_acc=1.000 | val_loss=1.6018, val_acc=0.400
# [RBF] Epoch 512 | train_loss=0.7358, train_acc=1.000 | val_loss=1.6019, val_acc=0.400
# [RBF] Epoch 513 | train_loss=0.7347, train_acc=1.000 | val_loss=1.6019, val_acc=0.400
# [RBF] Epoch 514 | train_loss=0.7336, train_acc=1.000 | val_loss=1.6020, val_acc=0.400
# [RBF] Epoch 515 | train_loss=0.7325, train_acc=1.000 | val_loss=1.6020, val_acc=0.400
# [RBF] Epoch 516 | train_loss=0.7315, train_acc=1.000 | val_loss=1.6021, val_acc=0.400
# [RBF] Epoch 517 | train_loss=0.7304, train_acc=1.000 | val_loss=1.6021, val_acc=0.400
# [RBF] Epoch 518 | train_loss=0.7293, train_acc=1.000 | val_loss=1.6022, val_acc=0.400
# [RBF] Epoch 519 | train_loss=0.7282, train_acc=1.000 | val_loss=1.6022, val_acc=0.400
# [RBF] Epoch 520 | train_loss=0.7272, train_acc=1.000 | val_loss=1.6023, val_acc=0.400
# [RBF] Epoch 521 | train_loss=0.7261, train_acc=1.000 | val_loss=1.6023, val_acc=0.400
# [RBF] Epoch 522 | train_loss=0.7250, train_acc=1.000 | val_loss=1.6024, val_acc=0.400
# [RBF] Epoch 523 | train_loss=0.7239, train_acc=1.000 | val_loss=1.6024, val_acc=0.400
# [RBF] Epoch 524 | train_loss=0.7229, train_acc=1.000 | val_loss=1.6025, val_acc=0.400
# [RBF] Epoch 525 | train_loss=0.7218, train_acc=1.000 | val_loss=1.6025, val_acc=0.400
# [RBF] Epoch 526 | train_loss=0.7208, train_acc=1.000 | val_loss=1.6025, val_acc=0.400
# [RBF] Epoch 527 | train_loss=0.7197, train_acc=1.000 | val_loss=1.6026, val_acc=0.400
# [RBF] Epoch 528 | train_loss=0.7186, train_acc=1.000 | val_loss=1.6026, val_acc=0.400
# [RBF] Epoch 529 | train_loss=0.7176, train_acc=1.000 | val_loss=1.6027, val_acc=0.400
# [RBF] Epoch 530 | train_loss=0.7165, train_acc=1.000 | val_loss=1.6027, val_acc=0.400
# [RBF] Epoch 531 | train_loss=0.7155, train_acc=1.000 | val_loss=1.6028, val_acc=0.400
# [RBF] Epoch 532 | train_loss=0.7144, train_acc=1.000 | val_loss=1.6028, val_acc=0.400
# [RBF] Epoch 533 | train_loss=0.7134, train_acc=1.000 | val_loss=1.6029, val_acc=0.400
# [RBF] Epoch 534 | train_loss=0.7123, train_acc=1.000 | val_loss=1.6029, val_acc=0.400
# [RBF] Epoch 535 | train_loss=0.7113, train_acc=1.000 | val_loss=1.6030, val_acc=0.400
# [RBF] Epoch 536 | train_loss=0.7102, train_acc=1.000 | val_loss=1.6030, val_acc=0.400
# [RBF] Epoch 537 | train_loss=0.7092, train_acc=1.000 | val_loss=1.6031, val_acc=0.400
# [RBF] Epoch 538 | train_loss=0.7081, train_acc=1.000 | val_loss=1.6031, val_acc=0.400
# [RBF] Epoch 539 | train_loss=0.7071, train_acc=1.000 | val_loss=1.6032, val_acc=0.400
# [RBF] Epoch 540 | train_loss=0.7061, train_acc=1.000 | val_loss=1.6032, val_acc=0.400
# [RBF] Epoch 541 | train_loss=0.7050, train_acc=1.000 | val_loss=1.6033, val_acc=0.400
# [RBF] Epoch 542 | train_loss=0.7040, train_acc=1.000 | val_loss=1.6034, val_acc=0.400
# [RBF] Epoch 543 | train_loss=0.7030, train_acc=1.000 | val_loss=1.6034, val_acc=0.400
# [RBF] Epoch 544 | train_loss=0.7019, train_acc=1.000 | val_loss=1.6035, val_acc=0.400
# [RBF] Epoch 545 | train_loss=0.7009, train_acc=1.000 | val_loss=1.6035, val_acc=0.400
# [RBF] Epoch 546 | train_loss=0.6999, train_acc=1.000 | val_loss=1.6036, val_acc=0.400
# [RBF] Epoch 547 | train_loss=0.6988, train_acc=1.000 | val_loss=1.6036, val_acc=0.400
# [RBF] Epoch 548 | train_loss=0.6978, train_acc=1.000 | val_loss=1.6037, val_acc=0.400
# ...
# [RBF] Epoch 816 | train_loss=0.4783, train_acc=1.000 | val_loss=1.6250, val_acc=0.450
# [RBF] Epoch 817 | train_loss=0.4776, train_acc=1.000 | val_loss=1.6251, val_acc=0.450
# [RBF] Epoch 818 | train_loss=0.4770, train_acc=1.000 | val_loss=1.6252, val_acc=0.450
# [RBF] Epoch 819 | train_loss=0.4763, train_acc=1.000 | val_loss=1.6253, val_acc=0.450
# [RBF] Epoch 820 | train_loss=0.4757, train_acc=1.000 | val_loss=1.6254, val_acc=0.450
# [RBF] Epoch 821 | train_loss=0.4750, train_acc=1.000 | val_loss=1.6255, val_acc=0.450
# [RBF] Epoch 822 | train_loss=0.4744, train_acc=1.000 | val_loss=1.6256, val_acc=0.450
# [RBF] Epoch 823 | train_loss=0.4738, train_acc=1.000 | val_loss=1.6257, val_acc=0.450
# [RBF] Epoch 824 | train_loss=0.4731, train_acc=1.000 | val_loss=1.6258, val_acc=0.450
# [RBF] Epoch 825 | train_loss=0.4725, train_acc=1.000 | val_loss=1.6259, val_acc=0.450
# [RBF] Epoch 826 | train_loss=0.4719, train_acc=1.000 | val_loss=1.6260, val_acc=0.450
# [RBF] Epoch 827 | train_loss=0.4712, train_acc=1.000 | val_loss=1.6262, val_acc=0.450
# [RBF] Epoch 828 | train_loss=0.4706, train_acc=1.000 | val_loss=1.6263, val_acc=0.450
# [RBF] Epoch 829 | train_loss=0.4700, train_acc=1.000 | val_loss=1.6264, val_acc=0.450
# [RBF] Epoch 830 | train_loss=0.4693, train_acc=1.000 | val_loss=1.6265, val_acc=0.450
# [RBF] Epoch 831 | train_loss=0.4687, train_acc=1.000 | val_loss=1.6266, val_acc=0.450
# [RBF] Epoch 832 | train_loss=0.4681, train_acc=1.000 | val_loss=1.6267, val_acc=0.450
# [RBF] Epoch 833 | train_loss=0.4674, train_acc=1.000 | val_loss=1.6268, val_acc=0.450
# [RBF] Epoch 834 | train_loss=0.4668, train_acc=1.000 | val_loss=1.6269, val_acc=0.450
# [RBF] Epoch 835 | train_loss=0.4662, train_acc=1.000 | val_loss=1.6270, val_acc=0.450
# [RBF] Epoch 836 | train_loss=0.4656, train_acc=1.000 | val_loss=1.6271, val_acc=0.450
# [RBF] Epoch 837 | train_loss=0.4649, train_acc=1.000 | val_loss=1.6272, val_acc=0.450
# [RBF] Epoch 838 | train_loss=0.4643, train_acc=1.000 | val_loss=1.6273, val_acc=0.450
# [RBF] Epoch 839 | train_loss=0.4637, train_acc=1.000 | val_loss=1.6274, val_acc=0.450
# [RBF] Epoch 840 | train_loss=0.4631, train_acc=1.000 | val_loss=1.6275, val_acc=0.450
# [RBF] Epoch 841 | train_loss=0.4625, train_acc=1.000 | val_loss=1.6276, val_acc=0.450
# [RBF] Epoch 842 | train_loss=0.4618, train_acc=1.000 | val_loss=1.6277, val_acc=0.450
# [RBF] Epoch 843 | train_loss=0.4612, train_acc=1.000 | val_loss=1.6278, val_acc=0.450
# [RBF] Epoch 844 | train_loss=0.4606, train_acc=1.000 | val_loss=1.6279, val_acc=0.450
# [RBF] Epoch 845 | train_loss=0.4600, train_acc=1.000 | val_loss=1.6280, val_acc=0.450
# [RBF] Epoch 846 | train_loss=0.4594, train_acc=1.000 | val_loss=1.6281, val_acc=0.450
# [RBF] Epoch 847 | train_loss=0.4588, train_acc=1.000 | val_loss=1.6282, val_acc=0.450
# [RBF] Epoch 848 | train_loss=0.4582, train_acc=1.000 | val_loss=1.6283, val_acc=0.450
# [RBF] Epoch 849 | train_loss=0.4576, train_acc=1.000 | val_loss=1.6284, val_acc=0.450
# [RBF] Epoch 850 | train_loss=0.4569, train_acc=1.000 | val_loss=1.6286, val_acc=0.450
# [RBF] Epoch 851 | train_loss=0.4563, train_acc=1.000 | val_loss=1.6287, val_acc=0.450
# [RBF] Epoch 852 | train_loss=0.4557, train_acc=1.000 | val_loss=1.6288, val_acc=0.450
# [RBF] Epoch 853 | train_loss=0.4551, train_acc=1.000 | val_loss=1.6289, val_acc=0.450
# [RBF] Epoch 854 | train_loss=0.4545, train_acc=1.000 | val_loss=1.6290, val_acc=0.450
# [RBF] Epoch 855 | train_loss=0.4539, train_acc=1.000 | val_loss=1.6291, val_acc=0.450
# [RBF] Epoch 856 | train_loss=0.4533, train_acc=1.000 | val_loss=1.6292, val_acc=0.450
# [RBF] Epoch 857 | train_loss=0.4527, train_acc=1.000 | val_loss=1.6293, val_acc=0.450
# [RBF] Epoch 858 | train_loss=0.4521, train_acc=1.000 | val_loss=1.6294, val_acc=0.450
# [RBF] Epoch 859 | train_loss=0.4515, train_acc=1.000 | val_loss=1.6295, val_acc=0.450
# [RBF] Epoch 860 | train_loss=0.4509, train_acc=1.000 | val_loss=1.6296, val_acc=0.450
# [RBF] Epoch 861 | train_loss=0.4503, train_acc=1.000 | val_loss=1.6297, val_acc=0.450
# [RBF] Epoch 862 | train_loss=0.4497, train_acc=1.000 | val_loss=1.6298, val_acc=0.450
# [RBF] Epoch 863 | train_loss=0.4491, train_acc=1.000 | val_loss=1.6299, val_acc=0.450
# [RBF] Epoch 864 | train_loss=0.4485, train_acc=1.000 | val_loss=1.6301, val_acc=0.450
# [RBF] Epoch 865 | train_loss=0.4479, train_acc=1.000 | val_loss=1.6302, val_acc=0.450
# [RBF] Epoch 866 | train_loss=0.4473, train_acc=1.000 | val_loss=1.6303, val_acc=0.450
# [RBF] Epoch 867 | train_loss=0.4467, train_acc=1.000 | val_loss=1.6304, val_acc=0.450
# [RBF] Epoch 868 | train_loss=0.4461, train_acc=1.000 | val_loss=1.6305, val_acc=0.450
# [RBF] Epoch 869 | train_loss=0.4456, train_acc=1.000 | val_loss=1.6306, val_acc=0.450
# [RBF] Epoch 870 | train_loss=0.4450, train_acc=1.000 | val_loss=1.6307, val_acc=0.450
# [RBF] Epoch 871 | train_loss=0.4444, train_acc=1.000 | val_loss=1.6308, val_acc=0.450
# [RBF] Epoch 872 | train_loss=0.4438, train_acc=1.000 | val_loss=1.6309, val_acc=0.450
# [RBF] Epoch 873 | train_loss=0.4432, train_acc=1.000 | val_loss=1.6310, val_acc=0.450
# [RBF] Epoch 874 | train_loss=0.4426, train_acc=1.000 | val_loss=1.6311, val_acc=0.450
# [RBF] Epoch 875 | train_loss=0.4420, train_acc=1.000 | val_loss=1.6312, val_acc=0.450
# [RBF] Epoch 876 | train_loss=0.4415, train_acc=1.000 | val_loss=1.6314, val_acc=0.450
# [RBF] Epoch 877 | train_loss=0.4409, train_acc=1.000 | val_loss=1.6315, val_acc=0.450
# [RBF] Epoch 878 | train_loss=0.4403, train_acc=1.000 | val_loss=1.6316, val_acc=0.450
# [RBF] Epoch 879 | train_loss=0.4397, train_acc=1.000 | val_loss=1.6317, val_acc=0.450
# [RBF] Epoch 880 | train_loss=0.4391, train_acc=1.000 | val_loss=1.6318, val_acc=0.450
# [RBF] Epoch 881 | train_loss=0.4386, train_acc=1.000 | val_loss=1.6319, val_acc=0.450
# [RBF] Epoch 882 | train_loss=0.4380, train_acc=1.000 | val_loss=1.6320, val_acc=0.450
# [RBF] Epoch 883 | train_loss=0.4374, train_acc=1.000 | val_loss=1.6321, val_acc=0.450
# [RBF] Epoch 884 | train_loss=0.4368, train_acc=1.000 | val_loss=1.6322, val_acc=0.450
# [RBF] Epoch 885 | train_loss=0.4362, train_acc=1.000 | val_loss=1.6323, val_acc=0.450
# [RBF] Epoch 886 | train_loss=0.4357, train_acc=1.000 | val_loss=1.6325, val_acc=0.450
# [RBF] Epoch 887 | train_loss=0.4351, train_acc=1.000 | val_loss=1.6326, val_acc=0.450
# [RBF] Epoch 888 | train_loss=0.4345, train_acc=1.000 | val_loss=1.6327, val_acc=0.450
# [RBF] Epoch 889 | train_loss=0.4340, train_acc=1.000 | val_loss=1.6328, val_acc=0.450
# [RBF] Epoch 890 | train_loss=0.4334, train_acc=1.000 | val_loss=1.6329, val_acc=0.450
# [RBF] Epoch 891 | train_loss=0.4328, train_acc=1.000 | val_loss=1.6330, val_acc=0.450
# [RBF] Epoch 892 | train_loss=0.4323, train_acc=1.000 | val_loss=1.6331, val_acc=0.450
# [RBF] Epoch 893 | train_loss=0.4317, train_acc=1.000 | val_loss=1.6332, val_acc=0.450
# [RBF] Epoch 894 | train_loss=0.4311, train_acc=1.000 | val_loss=1.6333, val_acc=0.450
# [RBF] Epoch 895 | train_loss=0.4306, train_acc=1.000 | val_loss=1.6334, val_acc=0.450
# [RBF] Epoch 896 | train_loss=0.4300, train_acc=1.000 | val_loss=1.6336, val_acc=0.450
# [RBF] Epoch 897 | train_loss=0.4294, train_acc=1.000 | val_loss=1.6337, val_acc=0.450
# [RBF] Epoch 898 | train_loss=0.4289, train_acc=1.000 | val_loss=1.6338, val_acc=0.450
# [RBF] Epoch 899 | train_loss=0.4283, train_acc=1.000 | val_loss=1.6339, val_acc=0.450
# [RBF] Epoch 900 | train_loss=0.4277, train_acc=1.000 | val_loss=1.6340, val_acc=0.450
# [RBF] Epoch 901 | train_loss=0.4272, train_acc=1.000 | val_loss=1.6341, val_acc=0.450
# [RBF] Epoch 902 | train_loss=0.4266, train_acc=1.000 | val_loss=1.6342, val_acc=0.450
# [RBF] Epoch 903 | train_loss=0.4261, train_acc=1.000 | val_loss=1.6343, val_acc=0.450
# [RBF] Epoch 904 | train_loss=0.4255, train_acc=1.000 | val_loss=1.6345, val_acc=0.450
# [RBF] Epoch 905 | train_loss=0.4250, train_acc=1.000 | val_loss=1.6346, val_acc=0.450
# [RBF] Epoch 906 | train_loss=0.4244, train_acc=1.000 | val_loss=1.6347, val_acc=0.450
# [RBF] Epoch 907 | train_loss=0.4239, train_acc=1.000 | val_loss=1.6348, val_acc=0.450
# [RBF] Epoch 908 | train_loss=0.4233, train_acc=1.000 | val_loss=1.6349, val_acc=0.450
# [RBF] Epoch 909 | train_loss=0.4227, train_acc=1.000 | val_loss=1.6350, val_acc=0.450
# [RBF] Epoch 910 | train_loss=0.4222, train_acc=1.000 | val_loss=1.6351, val_acc=0.450
# [RBF] Epoch 911 | train_loss=0.4216, train_acc=1.000 | val_loss=1.6352, val_acc=0.450
# [RBF] Epoch 912 | train_loss=0.4211, train_acc=1.000 | val_loss=1.6354, val_acc=0.450
# [RBF] Epoch 913 | train_loss=0.4205, train_acc=1.000 | val_loss=1.6355, val_acc=0.450
# [RBF] Epoch 914 | train_loss=0.4200, train_acc=1.000 | val_loss=1.6356, val_acc=0.450
# [RBF] Epoch 915 | train_loss=0.4195, train_acc=1.000 | val_loss=1.6357, val_acc=0.450
# [RBF] Epoch 916 | train_loss=0.4189, train_acc=1.000 | val_loss=1.6358, val_acc=0.450
# [RBF] Epoch 917 | train_loss=0.4184, train_acc=1.000 | val_loss=1.6359, val_acc=0.450
# [RBF] Epoch 918 | train_loss=0.4178, train_acc=1.000 | val_loss=1.6360, val_acc=0.450
# [RBF] Epoch 919 | train_loss=0.4173, train_acc=1.000 | val_loss=1.6362, val_acc=0.450
# [RBF] Epoch 920 | train_loss=0.4167, train_acc=1.000 | val_loss=1.6363, val_acc=0.450
# [RBF] Epoch 921 | train_loss=0.4162, train_acc=1.000 | val_loss=1.6364, val_acc=0.450
# [RBF] Epoch 922 | train_loss=0.4157, train_acc=1.000 | val_loss=1.6365, val_acc=0.450
# [RBF] Epoch 923 | train_loss=0.4151, train_acc=1.000 | val_loss=1.6366, val_acc=0.450
# [RBF] Epoch 924 | train_loss=0.4146, train_acc=1.000 | val_loss=1.6367, val_acc=0.450
# [RBF] Epoch 925 | train_loss=0.4140, train_acc=1.000 | val_loss=1.6368, val_acc=0.450
# [RBF] Epoch 926 | train_loss=0.4135, train_acc=1.000 | val_loss=1.6370, val_acc=0.450
# [RBF] Epoch 927 | train_loss=0.4130, train_acc=1.000 | val_loss=1.6371, val_acc=0.450
# [RBF] Epoch 928 | train_loss=0.4124, train_acc=1.000 | val_loss=1.6372, val_acc=0.450
# [RBF] Epoch 929 | train_loss=0.4119, train_acc=1.000 | val_loss=1.6373, val_acc=0.450
# [RBF] Epoch 930 | train_loss=0.4114, train_acc=1.000 | val_loss=1.6374, val_acc=0.450
# [RBF] Epoch 931 | train_loss=0.4108, train_acc=1.000 | val_loss=1.6375, val_acc=0.450
# [RBF] Epoch 932 | train_loss=0.4103, train_acc=1.000 | val_loss=1.6376, val_acc=0.450
# [RBF] Epoch 933 | train_loss=0.4098, train_acc=1.000 | val_loss=1.6378, val_acc=0.450
# [RBF] Epoch 934 | train_loss=0.4092, train_acc=1.000 | val_loss=1.6379, val_acc=0.450
# [RBF] Epoch 935 | train_loss=0.4087, train_acc=1.000 | val_loss=1.6380, val_acc=0.450
# [RBF] Epoch 936 | train_loss=0.4082, train_acc=1.000 | val_loss=1.6381, val_acc=0.450
# [RBF] Epoch 937 | train_loss=0.4077, train_acc=1.000 | val_loss=1.6382, val_acc=0.450
# [RBF] Epoch 938 | train_loss=0.4071, train_acc=1.000 | val_loss=1.6383, val_acc=0.450
# [RBF] Epoch 939 | train_loss=0.4066, train_acc=1.000 | val_loss=1.6385, val_acc=0.450
# [RBF] Epoch 940 | train_loss=0.4061, train_acc=1.000 | val_loss=1.6386, val_acc=0.450
# [RBF] Epoch 941 | train_loss=0.4056, train_acc=1.000 | val_loss=1.6387, val_acc=0.450
# [RBF] Epoch 942 | train_loss=0.4050, train_acc=1.000 | val_loss=1.6388, val_acc=0.450
# [RBF] Epoch 943 | train_loss=0.4045, train_acc=1.000 | val_loss=1.6389, val_acc=0.450
# [RBF] Epoch 944 | train_loss=0.4040, train_acc=1.000 | val_loss=1.6390, val_acc=0.450
# [RBF] Epoch 945 | train_loss=0.4035, train_acc=1.000 | val_loss=1.6392, val_acc=0.450
# [RBF] Epoch 946 | train_loss=0.4030, train_acc=1.000 | val_loss=1.6393, val_acc=0.450
# [RBF] Epoch 947 | train_loss=0.4024, train_acc=1.000 | val_loss=1.6394, val_acc=0.450
# [RBF] Epoch 948 | train_loss=0.4019, train_acc=1.000 | val_loss=1.6395, val_acc=0.450
# [RBF] Epoch 949 | train_loss=0.4014, train_acc=1.000 | val_loss=1.6396, val_acc=0.450
# [RBF] Epoch 950 | train_loss=0.4009, train_acc=1.000 | val_loss=1.6397, val_acc=0.450
# [RBF] Epoch 951 | train_loss=0.4004, train_acc=1.000 | val_loss=1.6399, val_acc=0.450
# [RBF] Epoch 952 | train_loss=0.3999, train_acc=1.000 | val_loss=1.6400, val_acc=0.450
# [RBF] Epoch 953 | train_loss=0.3994, train_acc=1.000 | val_loss=1.6401, val_acc=0.450
# [RBF] Epoch 954 | train_loss=0.3988, train_acc=1.000 | val_loss=1.6402, val_acc=0.450
# [RBF] Epoch 955 | train_loss=0.3983, train_acc=1.000 | val_loss=1.6403, val_acc=0.450
# [RBF] Epoch 956 | train_loss=0.3978, train_acc=1.000 | val_loss=1.6404, val_acc=0.450
# [RBF] Epoch 957 | train_loss=0.3973, train_acc=1.000 | val_loss=1.6406, val_acc=0.450
# [RBF] Epoch 958 | train_loss=0.3968, train_acc=1.000 | val_loss=1.6407, val_acc=0.450
# [RBF] Epoch 959 | train_loss=0.3963, train_acc=1.000 | val_loss=1.6408, val_acc=0.450
# [RBF] Epoch 960 | train_loss=0.3958, train_acc=1.000 | val_loss=1.6409, val_acc=0.450
# [RBF] Epoch 961 | train_loss=0.3953, train_acc=1.000 | val_loss=1.6410, val_acc=0.450
# [RBF] Epoch 962 | train_loss=0.3948, train_acc=1.000 | val_loss=1.6412, val_acc=0.450
# [RBF] Epoch 963 | train_loss=0.3943, train_acc=1.000 | val_loss=1.6413, val_acc=0.450
# [RBF] Epoch 964 | train_loss=0.3938, train_acc=1.000 | val_loss=1.6414, val_acc=0.450
# [RBF] Epoch 965 | train_loss=0.3933, train_acc=1.000 | val_loss=1.6415, val_acc=0.450
# [RBF] Epoch 966 | train_loss=0.3928, train_acc=1.000 | val_loss=1.6416, val_acc=0.450
# [RBF] Epoch 967 | train_loss=0.3923, train_acc=1.000 | val_loss=1.6417, val_acc=0.450
# [RBF] Epoch 968 | train_loss=0.3918, train_acc=1.000 | val_loss=1.6419, val_acc=0.450
# [RBF] Epoch 969 | train_loss=0.3913, train_acc=1.000 | val_loss=1.6420, val_acc=0.450
# [RBF] Epoch 970 | train_loss=0.3908, train_acc=1.000 | val_loss=1.6421, val_acc=0.450
# [RBF] Epoch 971 | train_loss=0.3903, train_acc=1.000 | val_loss=1.6422, val_acc=0.450
# [RBF] Epoch 972 | train_loss=0.3898, train_acc=1.000 | val_loss=1.6423, val_acc=0.450
# [RBF] Epoch 973 | train_loss=0.3893, train_acc=1.000 | val_loss=1.6425, val_acc=0.450
# [RBF] Epoch 974 | train_loss=0.3888, train_acc=1.000 | val_loss=1.6426, val_acc=0.450
# [RBF] Epoch 975 | train_loss=0.3883, train_acc=1.000 | val_loss=1.6427, val_acc=0.450
# [RBF] Epoch 976 | train_loss=0.3878, train_acc=1.000 | val_loss=1.6428, val_acc=0.450
# [RBF] Epoch 977 | train_loss=0.3873, train_acc=1.000 | val_loss=1.6429, val_acc=0.450
# [RBF] Epoch 978 | train_loss=0.3868, train_acc=1.000 | val_loss=1.6431, val_acc=0.450
# [RBF] Epoch 979 | train_loss=0.3863, train_acc=1.000 | val_loss=1.6432, val_acc=0.450
# [RBF] Epoch 980 | train_loss=0.3858, train_acc=1.000 | val_loss=1.6433, val_acc=0.450
# [RBF] Epoch 981 | train_loss=0.3853, train_acc=1.000 | val_loss=1.6434, val_acc=0.450
# [RBF] Epoch 982 | train_loss=0.3848, train_acc=1.000 | val_loss=1.6435, val_acc=0.450
# [RBF] Epoch 983 | train_loss=0.3844, train_acc=1.000 | val_loss=1.6437, val_acc=0.450
# [RBF] Epoch 984 | train_loss=0.3839, train_acc=1.000 | val_loss=1.6438, val_acc=0.450
# [RBF] Epoch 985 | train_loss=0.3834, train_acc=1.000 | val_loss=1.6439, val_acc=0.450
# [RBF] Epoch 986 | train_loss=0.3829, train_acc=1.000 | val_loss=1.6440, val_acc=0.450
# [RBF] Epoch 987 | train_loss=0.3824, train_acc=1.000 | val_loss=1.6441, val_acc=0.450
# [RBF] Epoch 988 | train_loss=0.3819, train_acc=1.000 | val_loss=1.6443, val_acc=0.450
# [RBF] Epoch 989 | train_loss=0.3815, train_acc=1.000 | val_loss=1.6444, val_acc=0.450
# [RBF] Epoch 990 | train_loss=0.3810, train_acc=1.000 | val_loss=1.6445, val_acc=0.450
# [RBF] Epoch 991 | train_loss=0.3805, train_acc=1.000 | val_loss=1.6446, val_acc=0.450
# [RBF] Epoch 992 | train_loss=0.3800, train_acc=1.000 | val_loss=1.6448, val_acc=0.450
# [RBF] Epoch 993 | train_loss=0.3795, train_acc=1.000 | val_loss=1.6449, val_acc=0.450
# [RBF] Epoch 994 | train_loss=0.3790, train_acc=1.000 | val_loss=1.6450, val_acc=0.450
# [RBF] Epoch 995 | train_loss=0.3786, train_acc=1.000 | val_loss=1.6451, val_acc=0.450
# [RBF] Epoch 996 | train_loss=0.3781, train_acc=1.000 | val_loss=1.6452, val_acc=0.450
# [RBF] Epoch 997 | train_loss=0.3776, train_acc=1.000 | val_loss=1.6454, val_acc=0.450
# [RBF] Epoch 998 | train_loss=0.3771, train_acc=1.000 | val_loss=1.6455, val_acc=0.450
# [RBF] Epoch 999 | train_loss=0.3767, train_acc=1.000 | val_loss=1.6456, val_acc=0.450
# [RBF] Epoch 1000 | train_loss=0.3762, train_acc=1.000 | val_loss=1.6457, val_acc=0.450
# Best val_acc (RBF meta): 0.45000001788139343

# %%
# ------------------------------------------------------------------
# 7) Inference: full pipeline for a new image
# ------------------------------------------------------------------
from PIL import Image

inv_genre = {v: k for k, v in genre_to_label.items()}

def predict_full_pipeline(img_path, models_quadrant, transforms_quadrant, rbf_meta_model):
    img = Image.open(img_path).convert("RGB")
    quadrant_names = list(models_quadrant.keys())
    probs_all = []

    with torch.no_grad():
        for q in quadrant_names:
            x_q = transforms_quadrant[q](img)   # C x H x W
            x_q = x_q.unsqueeze(0).to(device)   # 1 x C x H x W

            model_q = models_quadrant[q].to(device)
            model_q.eval()
            logits_q = model_q(x_q)
            probs_q = torch.softmax(logits_q, dim=1)  # 1 x C
            probs_all.append(probs_q.cpu())

        feat = torch.cat(probs_all, dim=1).to(device)  # 1 x (4*C)
        rbf_meta_model.eval()
        logits_meta = rbf_meta_model(feat)
        probs_meta = torch.softmax(logits_meta, dim=1)  # 1 x C
        pred_idx = torch.argmax(probs_meta, dim=1).item()

    return pred_idx, probs_meta.cpu().numpy()[0]

# %% [markdown]
# # Visualización del modelo

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scripts import style
style.mpl_apply()

# %%
import matplotlib.pyplot as plt

quadrant_names = ["ul", "ur", "ll", "lr"]

for q in quadrant_names:
    hist = histories_quadrant[q]
    epochs = range(1, len(hist["train_loss"]) + 1)

    plt.figure(figsize=(10, 4))
    plt.suptitle(f"Training curves – quadrant: {q}")

    # --- Loss ---
    plt.subplot(1, 2, 1)
    plt.plot(epochs, hist["train_loss"], label="train_loss")
    plt.plot(epochs, hist["val_loss"],   label="val_loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True, alpha=0.3)

    # --- Accuracy ---
    if "train_acc" in hist:
        plt.subplot(1, 2, 2)
        plt.plot(epochs, hist["train_acc"], label="train_acc")
        plt.plot(epochs, hist["val_acc"],   label="val_acc")
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy")
        plt.ylim(0.0, 1.0)
        plt.legend()
        plt.grid(True, alpha=0.3)
    else:
        # fallback if you didn't re-train with train_acc stored
        plt.subplot(1, 2, 2)
        plt.plot(epochs, hist["val_acc"], label="val_acc")
        plt.xlabel("Epoch")
        plt.ylabel("Val accuracy")
        plt.ylim(0.0, 1.0)
        plt.legend()
        plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
from PIL import Image
import torch
import numpy as np
import matplotlib.pyplot as plt

inv_genre = {v: k for k, v in genre_to_label.items()}
quadrant_names = ["ul", "ur", "ll", "lr"]
import matplotlib.pyplot as plt

inv_genre = {v: k for k, v in genre_to_label.items()}
quadrant_names = ["ul", "ur", "ll", "lr"]

def show_quadrant_probs(img_path, models_quadrant, transforms_quadrant):
    img = Image.open(img_path).convert("RGB")

    fig, axes = plt.subplots(2, 4, figsize=(18, 8))
    fig.suptitle(f"Quadrant Analysis for {img_path.split('/')[-1]}")

    for i, q in enumerate(quadrant_names):
        # apply transform for this quadrant (includes crop + resize + normalize)
        x_q = transforms_quadrant[q](img)        # C x H x W
        x_vis = x_q.clone()

        # for visualization: un-normalize using that quadrant's mean/std if you want
        # but simplest: just use raw (might look slightly off colors)
        x_vis = x_vis.permute(1, 2, 0).numpy()
        x_vis = np.clip(x_vis, 0, 1)

        # Image in top row
        axes[0, i].imshow(x_vis)
        axes[0, i].axis("off")
        axes[0, i].set_title(f"Quadrant view: {q}")

        # model prediction
        model_q = models_quadrant[q].to(device)
        model_q.eval()

        with torch.no_grad():
            x_batch = x_q.unsqueeze(0).to(device)
            logits = model_q(x_batch)
            probs = torch.softmax(logits, dim=1).cpu().numpy()[0]  # shape (C,)

        # Bar plot in bottom row
        axes[1, i].bar(range(len(probs)), probs)
        axes[1, i].set_xticks(range(len(probs)))
        axes[1, i].set_xticklabels([inv_genre[j] for j in range(len(probs))], rotation=45, ha="right")
        axes[1, i].set_ylim(0, 1)
        axes[1, i].set_title(f"Probabilities for quadrant {q}")

    plt.tight_layout()
    plt.show()

# %%
import random   
test_img = random.choice(df['path'].tolist())
show_quadrant_probs(test_img, models_quadrant, transforms_quadrant)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# 1) meta predictions on validation
rbf_meta_model.eval()
X_val_t = torch.tensor(X_val_meta, dtype=torch.float32).to(device)

with torch.no_grad():
    logits_val = rbf_meta_model(X_val_t)
    probs_val  = torch.softmax(logits_val, dim=1)
    y_pred_val = probs_val.argmax(dim=1).cpu().numpy()

# 2) confusion matrix
cm = confusion_matrix(y_val_meta, y_pred_val)
class_names = [inv_genre[i] for i in range(len(genre_to_label))]

fig, ax = plt.subplots(figsize=(6, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(ax=ax, cmap="Blues", xticks_rotation=90, colorbar=True)
ax.set_title("Confusion matrix – meta RBF (validation)")
plt.tight_layout()
plt.grid(False)
plt.show()

# %%
cm_norm = confusion_matrix(y_val_meta, y_pred_val, normalize="true")
fig, ax = plt.subplots(figsize=(6, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_norm, display_labels=class_names)
disp.plot(ax=ax, cmap="Blues", xticks_rotation=90, colorbar=True, values_format=".2f")
ax.set_title("Normalized confusion matrix – meta RBF (validation)")
plt.tight_layout()
plt.grid(False)
plt.show()
