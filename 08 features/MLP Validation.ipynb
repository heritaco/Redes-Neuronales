# %% [markdown]
# # MLP feedforward bagging ensemble
#
# En esta notebook se hace bagging! yupi!
# Vemos como le va en la validacion

# %%
from pathlib import Path
import random
import math

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
)
from sklearn.utils.class_weight import compute_class_weight

from scripts import style
style.mpl_apply()

import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader

from dataclasses import dataclass
import copy
import random
import math

import numpy as np
import pandas as pd


from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import f1_score, accuracy_score

from torch.utils.data import TensorDataset, DataLoader


# Reproducibility
SEED = 246
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# # Load the data

# %%
DATA_PATH = Path("09 features/redes_local/datos/processed/df.csv")

df = pd.read_csv(DATA_PATH)
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (200, 57)
#       mean_R      mean_G      mean_B      std_R      std_G      std_B  min_R  \
# 0  102.20103  105.277170  106.873116  32.077003  33.305286  33.510914    0.0
# 1  123.62030  136.959850  149.195050  46.771084  43.979904  49.263435    0.0
# 2  118.90262  116.895996  108.091415  48.649280  52.237015  61.140570    0.0
# 3  133.78065  140.773590  146.314380  36.072636  36.483162  50.136950    4.0
# 4  107.30281  108.520706   92.723560  32.748276  32.094944  37.935650    0.0
#
#    min_G  min_B  max_R  ...  pct_bright_block_2_2    H_shannon  \
# 0    0.0    0.0  186.0  ...              0.195138 -1419.565426
# 1    0.0    0.0  255.0  ...              0.098290 -1419.565426
# 2    0.0    0.0  255.0  ...              0.117654 -1419.489874
# 3    4.0    0.0  255.0  ...              0.018207 -1419.565426
# 4    0.0    0.0  229.0  ...              0.020639 -1419.565426
#
#    center_mean_ratio  center_bright_ratio  lum_centroid_x  lum_centroid_y  \
# 0           1.198618             1.749636        0.486834       -0.154286
# 1           1.061136             0.937835        0.502996       -0.188640
# 2           0.852622             1.311007        0.504956       -0.304950
# 3           1.091522             1.702214        0.500399       -0.215292
# 4           1.132043             2.128325        0.506062       -0.137083
#
#                filename        painter          genre  label
# 0   Alfred_Sisley_1.jpg  Alfred_Sisley  Impresionismo      4
# 1  Alfred_Sisley_10.jpg  Alfred_Sisley  Impresionismo      4
# 2  Alfred_Sisley_11.jpg  Alfred_Sisley  Impresionismo      4
# 3  Alfred_Sisley_12.jpg  Alfred_Sisley  Impresionismo      4
# 4  Alfred_Sisley_13.jpg  Alfred_Sisley  Impresionismo      4
#
# [5 rows x 57 columns]

# %%
# Encode painters
painter_names = sorted(df["painter"].unique())
painter_to_idx = {name: i for i, name in enumerate(painter_names)}
idx_to_painter = {i: name for name, i in painter_to_idx.items()}

df["painter_idx"] = df["painter"].map(painter_to_idx)

NUM_PAINTERS = len(painter_names)

# Labels (movement / genre index)
# Assume df["label"] is already integer-coded per genre
NUM_LABELS = df["label"].nunique()

# Derive genre names per label (sorted by label index)
label_to_genre = (
    df.drop_duplicates("label")
      .sort_values("label")
      .set_index("label")["genre"]
      .to_dict()
)
class_names = [label_to_genre[i] for i in range(NUM_LABELS)]

print("Painters:", painter_names)
print("NUM_PAINTERS:", NUM_PAINTERS)
print("NUM_LABELS:", NUM_LABELS)
print("Labels → genres:", label_to_genre)
# Out:
# Painters: ['Alfred_Sisley', 'Camille_Pissarro', 'Caravaggio', 'Claude_Monet', 'Jackson_Pollock', 'Joan_Miro', 'Pablo_Picasso', 'Rembrandt', 'Rene_Magritte', 'Salvador_Dali', 'Vincent_van_Gogh']
# NUM_PAINTERS: 11
# NUM_LABELS: 5
# Labels → genres: {0: 'Surrealismo', 1: 'Cubismo', 2: 'Expresionismo abstracto', 3: 'Barroco', 4: 'Impresionismo'}

# %%
meta_cols = ["filename", "painter", "genre", "label", "painter_idx"]

feature_cols = [c for c in df.columns if c not in meta_cols]

X = df[feature_cols].to_numpy(dtype=np.float32)
y_painter = df["painter_idx"].to_numpy(dtype=np.int64)
y_label   = df["label"].to_numpy(dtype=np.int64)

print("X shape:", X.shape)
print("y_painter shape:", y_painter.shape)
print("y_label shape:", y_label.shape)
print("Painter counts:", np.bincount(y_painter))
print("Label counts:",   np.bincount(y_label))
# Out:
# X shape: (200, 53)
# y_painter shape: (200,)
# y_label shape: (200,)
# Painter counts: [20 10 10 30 15 20 30 20 10 20 15]
# Label counts: [50 30 15 30 75]

# %% [markdown]
# # Train Set and Validation Set

# %%
X_train, X_val, y_p_train, y_p_val = train_test_split(
    X,
    y_painter,
    test_size=0.1,           # e.g. 80% train / 20% val
    stratify=y_painter,      # stratify by painter (since painter is first task)
    random_state=SEED,
)

print("Train X:", X_train.shape)
print("Val   X:", X_val.shape)
# Out:
# Train X: (180, 53)
# Val   X: (20, 53)

# %% [markdown]
# ## Scaling

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled   = scaler.transform(X_val)

# %%
BATCH_SIZE = 32

X_train_t = torch.from_numpy(X_train_scaled).float()
y_p_train_t = torch.from_numpy(y_p_train).long()

X_val_t = torch.from_numpy(X_val_scaled).float()
y_p_val_t = torch.from_numpy(y_p_val).long()

train_ds = TensorDataset(X_train_t, y_p_train_t)
val_ds   = TensorDataset(X_val_t,   y_p_val_t)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False)

len(train_loader), len(val_loader)
# Out:
# (6, 1)

# %% [markdown]
# ## Weights

# %%
painter_class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.arange(NUM_PAINTERS),
    y=y_p_train,
)

print("Painter class weights:", painter_class_weights)

painter_class_weights_t = torch.tensor(painter_class_weights, dtype=torch.float32, device=device)
# Out:
# Painter class weights: [0.90909091 1.81818182 1.81818182 0.60606061 1.25874126 0.90909091
#  0.60606061 0.90909091 1.81818182 0.90909091 1.16883117]

# %% [markdown]
# # Architectures

# %% [markdown]
# ## MLP

# %%
class PainterMLP_Slim(nn.Module):
    def __init__(
        self,
        input_dim: int,
        num_painters: int,
        bottleneck: int = 16,
        hidden_first: int = 32,
        dropout_p: float = 0.5,
    ):
        super().__init__()
        self.trunk = nn.Sequential(
            nn.Linear(input_dim, hidden_first),
            nn.BatchNorm1d(hidden_first),
            nn.ReLU(),
            nn.Dropout(dropout_p),

            nn.Linear(hidden_first, bottleneck),
            nn.Tanh(),
            nn.Dropout(dropout_p),
        )
        self.head = nn.Linear(bottleneck, num_painters)

    def forward(self, x):
        h = self.trunk(x)
        return self.head(h)


def make_model(hp, input_dim, num_painters, device):
    return PainterMLP_Slim(
        input_dim=input_dim,
        num_painters=num_painters,
        bottleneck=hp["bottleneck"],
        hidden_first=hp["hidden_first"],
        dropout_p=hp["dropout_p"],
    ).to(device)

# %% [markdown]
# # Training

# %% [markdown]
# ## Criterion

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class WeightedCrossEntropy(nn.Module):
    def __init__(self, class_weights: torch.Tensor):
        super().__init__()
        self.ce = nn.CrossEntropyLoss(weight=class_weights)

    def forward(self, logits, targets):
        return self.ce(logits, targets)


class WeightedLabelSmoothingCE(nn.Module):
    def __init__(self, class_weights: torch.Tensor, smoothing: float = 0.1):
        super().__init__()
        self.class_weights = class_weights
        self.smoothing = smoothing

    def forward(self, logits, targets):
        log_probs = F.log_softmax(logits, dim=1)
        C = logits.size(1)

        with torch.no_grad():
            true_dist = torch.zeros_like(log_probs)
            true_dist.fill_(self.smoothing / (C - 1))
            true_dist.scatter_(1, targets.unsqueeze(1), 1.0 - self.smoothing)

        w = self.class_weights[targets].unsqueeze(1)  # (B,1)
        loss = -(w * true_dist * log_probs).sum(dim=1).mean()
        return loss


class WeightedFocalLoss(nn.Module):
    def __init__(self, class_weights: torch.Tensor, gamma: float = 2.0):
        super().__init__()
        self.class_weights = class_weights
        self.gamma = gamma

    def forward(self, logits, targets):
        ce = F.cross_entropy(logits, targets, weight=self.class_weights, reduction="none")
        pt = torch.exp(-ce)
        focal = ((1.0 - pt) ** self.gamma) * ce
        return focal.mean()


def make_criterion(name: str, class_weights: torch.Tensor, smoothing=0.1, gamma=2.0):
    if name == "wce":
        return WeightedCrossEntropy(class_weights)
    if name == "wce_ls":
        return WeightedLabelSmoothingCE(class_weights, smoothing=smoothing)
    if name == "wfocal":
        return WeightedFocalLoss(class_weights, gamma=gamma)
    raise ValueError(f"Unknown criterion: {name}")

# %% [markdown]
# ## Train

# %%
def train_one_epoch_painter(model, loader, optimizer, criterion, device):
    model.train()
    total, sum_loss = 0, 0.0
    for xb, yb in loader:
        xb, yb = xb.to(device), yb.to(device)

        optimizer.zero_grad()
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        optimizer.step()

        sum_loss += loss.item() * xb.size(0)
        total += xb.size(0)
    return sum_loss / total


@torch.no_grad()
def eval_fold_painter(model, loader, device):
    model.eval()
    y_true, y_pred = [], []
    for xb, yb in loader:
        xb = xb.to(device)
        logits = model(xb)
        y_pred.append(logits.argmax(1).cpu().numpy())
        y_true.append(yb.numpy())
    return np.concatenate(y_true), np.concatenate(y_pred)


def fit_and_score_fold_painter(
    X_tr, y_tr,
    X_va, y_va,
    hp,
    input_dim,
    num_painters,
    device,
    max_epochs=40,
    patience=8,
    batch_size=32,
    verbose=False,
):
    # scale per fold
    scaler = StandardScaler()
    X_tr_s = scaler.fit_transform(X_tr)
    X_va_s = scaler.transform(X_va)

    # tensors
    X_tr_t = torch.from_numpy(X_tr_s).float()
    y_tr_t = torch.from_numpy(y_tr).long()
    X_va_t = torch.from_numpy(X_va_s).float()
    y_va_t = torch.from_numpy(y_va).long()

    # loaders
    tr_loader = DataLoader(TensorDataset(X_tr_t, y_tr_t),
                           batch_size=batch_size, shuffle=True)
    va_loader = DataLoader(TensorDataset(X_va_t, y_va_t),
                           batch_size=batch_size, shuffle=False)

    # class weights on train fold
    w = compute_class_weight("balanced", classes=np.arange(num_painters), y=y_tr)
    w_t = torch.tensor(w, dtype=torch.float32, device=device)

    criterion = make_criterion(
        hp["criterion"],
        w_t,
        smoothing=hp.get("smoothing", 0.1),
        gamma=hp.get("gamma", 2.0),
    )

    model = make_model(hp, input_dim, num_painters, device)
    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=hp["lr"],
        weight_decay=hp["weight_decay"],
    )

    best_state = None
    best_f1 = -np.inf
    best_acc = 0.0
    no_improve = 0

    for epoch in range(1, max_epochs + 1):
        train_loss = train_one_epoch_painter(model, tr_loader, optimizer, criterion, device)
        y_t, y_hat = eval_fold_painter(model, va_loader, device)

        val_f1  = f1_score(y_t, y_hat, average="macro")
        val_acc = accuracy_score(y_t, y_hat)

        if verbose:
            print(
                f"    epoch {epoch:02d} | train_loss={train_loss:.4f} | "
                f"val_f1_macro={val_f1:.3f} | val_acc={val_acc:.3f}"
            )

        if val_f1 > best_f1 + 1e-4:
            best_f1 = val_f1
            best_acc = val_acc
            best_state = copy.deepcopy(model.state_dict())
            no_improve = 0
        else:
            no_improve += 1
            if no_improve >= patience:
                break

    if best_state is not None:
        model.load_state_dict(best_state)

    return best_f1, best_acc

# %% [markdown]
# ## Best hyperparameters

# %%
# best_h={'bottleneck': 24, 'hidden_first': 32, 'dropout_p': 0.4, 'lr': 0.0024555426586822136, 'weight_decay': 4.070640977962409e-05, 'criterion': np.str_('wce_ls'), 'smoothing': 0.1}
best_h={'bottleneck': 32, 'hidden_first': 128, 'dropout_p': 0.2, 'lr': 0.006, 'weight_decay': 0.0009, 'criterion': np.str_('wce')}
best_h2 ={'bottleneck': 24, 'hidden_first': 48, 'dropout_p': 0.3, 'lr': 0.009809571718290793, 'weight_decay': 0.00017286437161330762, 'criterion': np.str_('wce')}
best_h3 = {'bottleneck': 24, 'hidden_first': 128, 'dropout_p': 0.1, 'lr': 0.002396152506176631, 'weight_decay': 0.000580016413870336, 'criterion': np.str_('wce')}

# %% [markdown]
# ## Training

# %%
input_dim = X.shape[1]

def make_model(hp):
    return PainterMLP_Slim(
        input_dim=input_dim,
        num_painters=NUM_PAINTERS,
        bottleneck=hp["bottleneck"],
        hidden_first=hp["hidden_first"],
        dropout_p=hp["dropout_p"],
    ).to(device)

# %%
LR = best_h["lr"]
WEIGHT_DECAY = best_h["weight_decay"]

painter_criterion = make_criterion(
    name=best_h["criterion"],
    class_weights=painter_class_weights_t,
    smoothing=best_h.get("smoothing", 0.1),
)

# %%
K = 12
MAX_EPOCHS = 1000
PATIENCE = 250

# %%
def train_one_epoch(
    model,
    loader,
    optimizer,
    painter_criterion,
    device,
):
    model.train()
    total = 0
    sum_loss = 0.0
    correct_painter = 0

    for X_batch, y_p_batch in loader:  
        X_batch = X_batch.to(device)
        y_p_batch = y_p_batch.to(device)

        optimizer.zero_grad()
        painter_logits = model(X_batch) 

        painter_loss = painter_criterion(painter_logits, y_p_batch)

        painter_loss.backward()
        optimizer.step()

        batch_size = X_batch.size(0)
        sum_loss += painter_loss.item() * batch_size
        total += batch_size

        painter_pred = painter_logits.argmax(dim=1)
        correct_painter += (painter_pred == y_p_batch).sum().item()

    epoch_loss = sum_loss / total
    painter_acc = correct_painter / total
    return epoch_loss, painter_acc


@torch.no_grad()
def evaluate(
    model,
    loader,
    painter_criterion,
    device,
):
    model.eval()
    total = 0
    sum_loss = 0.0
    correct_painter = 0

    for X_batch, y_p_batch in loader:
        X_batch = X_batch.to(device)
        y_p_batch = y_p_batch.to(device)

        painter_logits = model(X_batch)

        painter_loss = painter_criterion(painter_logits, y_p_batch)

        batch_size = X_batch.size(0)
        sum_loss += painter_loss.item() * batch_size
        total += batch_size

        painter_pred = painter_logits.argmax(dim=1)
        correct_painter += (painter_pred == y_p_batch).sum().item()

    epoch_loss = sum_loss / total
    painter_acc = correct_painter / total
    return epoch_loss, painter_acc

# %%
import numpy as np
import random
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import f1_score, accuracy_score


def train_one_epoch_painter(model, loader, optimizer, criterion, device):
    model.train()
    total, sum_loss = 0, 0.0
    y_true_all, y_pred_all = [], []

    for xb, yb in loader:
        xb, yb = xb.to(device), yb.to(device)

        optimizer.zero_grad()
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        optimizer.step()

        sum_loss += loss.item() * xb.size(0)
        total += xb.size(0)

        y_true_all.append(yb.detach().cpu().numpy())
        y_pred_all.append(logits.argmax(1).detach().cpu().numpy())

    y_true_all = np.concatenate(y_true_all)
    y_pred_all = np.concatenate(y_pred_all)

    epoch_loss = sum_loss / total
    epoch_acc  = accuracy_score(y_true_all, y_pred_all)
    epoch_f1   = f1_score(y_true_all, y_pred_all, average="macro")

    return epoch_loss, epoch_acc, epoch_f1


@torch.no_grad()
def evaluate_painter(model, loader, criterion, device):
    model.eval()
    total, sum_loss = 0, 0.0
    y_true_all, y_pred_all = [], []

    for xb, yb in loader:
        xb, yb = xb.to(device), yb.to(device)
        logits = model(xb)
        loss = criterion(logits, yb)

        sum_loss += loss.item() * xb.size(0)
        total += xb.size(0)

        y_true_all.append(yb.cpu().numpy())
        y_pred_all.append(logits.argmax(1).cpu().numpy())

    y_true_all = np.concatenate(y_true_all)
    y_pred_all = np.concatenate(y_pred_all)

    epoch_loss = sum_loss / total
    epoch_acc  = accuracy_score(y_true_all, y_pred_all)
    epoch_f1   = f1_score(y_true_all, y_pred_all, average="macro")

    return epoch_loss, epoch_acc, epoch_f1

# %%
import numpy as np
import random
import copy

def train_single_model_with_history(
    seed: int,
    max_epochs: int = 40,
    patience: int = 8,
    best_h: dict = None,
):
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)

    # 1) model from best hyperparams
    model = make_model(best_h).to(device)

    # 2) optimizer from best hyperparams
    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=float(best_h["lr"]),
        weight_decay=float(best_h["weight_decay"]),
    )

    try:
        # prefer global tensor if exists
        painter_weights_t = painter_class_weights_t
    except NameError:
        # otherwise compute from y_p_train
        w = compute_class_weight(
            class_weight="balanced",
            classes=np.arange(NUM_PAINTERS),
            y=y_p_train,
        )
        painter_weights_t = torch.tensor(w, dtype=torch.float32, device=device)

    painter_criterion = make_criterion(
        best_h["criterion"],
        painter_weights_t,
        smoothing=float(best_h.get("smoothing", 0.1)),
        gamma=float(best_h.get("gamma", 2.0)),
    )

    history = {
        "train_loss": [],
        "train_painter_acc": [],
        "train_painter_f1": [],
        "val_loss": [],
        "val_painter_acc": [],
        "val_painter_f1": [],
    }

    best_state = None
    best_val_f1 = -np.inf
    epochs_no_improve = 0

    for epoch in range(1, max_epochs + 1):
        train_loss, train_acc, train_f1 = train_one_epoch_painter(
            model,
            train_loader,
            optimizer,
            painter_criterion,
            device,
        )

        val_loss, val_acc, val_f1 = evaluate_painter(
            model,
            val_loader,
            painter_criterion,
            device,
        )

        history["train_loss"].append(train_loss)
        history["train_painter_acc"].append(train_acc)
        history["train_painter_f1"].append(train_f1)
        history["val_loss"].append(val_loss)
        history["val_painter_acc"].append(val_acc)
        history["val_painter_f1"].append(val_f1)

        print(
            f"[seed {seed}] epoch {epoch:02d} | "
            f"train_loss={train_loss:.4f}, train_acc={train_acc:.3f}, train_f1={train_f1:.3f} | "
            f"val_loss={val_loss:.4f}, val_acc={val_acc:.3f}, val_f1={val_f1:.3f}"
        )

        # early stop on macro-F1 (matches CV selection)
        if val_f1 > best_val_f1 + 1e-4:
            best_val_f1 = val_f1
            best_state = copy.deepcopy(model.state_dict())
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"[seed {seed}] Early stopping at epoch {epoch}")
                break

    if best_state is not None:
        model.load_state_dict(best_state)

    return model, history, best_val_f1

# %%
models, histories, scores = [], [], []

for k in range(K):
    seed_k = SEED + k
    best_h = [best_h, best_h2, best_h3][k % 3]  # cycle through best hyperparams
    print(f"\n=== Training model {k+1}/{K} (seed={seed_k}) ===")
    model_k, hist_k, score_k = train_single_model_with_history(
        seed=seed_k,
        max_epochs=MAX_EPOCHS,
        patience=PATIENCE, 
        best_h=best_h
    )
    models.append(model_k)
    histories.append(hist_k)
    scores.append(score_k)

print("Val painter acc of each model:", scores)
print("Mean:", np.mean(scores), "Std:", np.std(scores))
# Out:
# === Training model 1/12 (seed=246) ===
# [seed 246] epoch 01 | train_loss=2.2206, train_acc=0.194, train_f1=0.174 | val_loss=2.0146, val_acc=0.300, val_f1=0.149
# [seed 246] epoch 02 | train_loss=1.7772, train_acc=0.433, train_f1=0.397 | val_loss=1.7828, val_acc=0.300, val_f1=0.171
# [seed 246] epoch 03 | train_loss=1.5225, train_acc=0.517, train_f1=0.499 | val_loss=1.6711, val_acc=0.350, val_f1=0.255
# [seed 246] epoch 04 | train_loss=1.3918, train_acc=0.567, train_f1=0.554 | val_loss=1.6204, val_acc=0.300, val_f1=0.227
# [seed 246] epoch 05 | train_loss=1.2086, train_acc=0.639, train_f1=0.626 | val_loss=1.5724, val_acc=0.400, val_f1=0.342
# [seed 246] epoch 06 | train_loss=1.1070, train_acc=0.650, train_f1=0.656 | val_loss=1.5350, val_acc=0.400, val_f1=0.316
# [seed 246] epoch 07 | train_loss=0.9929, train_acc=0.694, train_f1=0.701 | val_loss=1.4305, val_acc=0.500, val_f1=0.461
# [seed 246] epoch 08 | train_loss=0.8187, train_acc=0.717, train_f1=0.725 | val_loss=1.3838, val_acc=0.600, val_f1=0.606
# [seed 246] epoch 09 | train_loss=0.7427, train_acc=0.761, train_f1=0.770 | val_loss=1.2937, val_acc=0.650, val_f1=0.645
# [seed 246] epoch 10 | train_loss=0.6779, train_acc=0.817, train_f1=0.824 | val_loss=1.2427, val_acc=0.650, val_f1=0.612
# [seed 246] epoch 11 | train_loss=0.5735, train_acc=0.811, train_f1=0.824 | val_loss=1.2512, val_acc=0.650, val_f1=0.658
# [seed 246] epoch 12 | train_loss=0.5657, train_acc=0.800, train_f1=0.798 | val_loss=1.3767, val_acc=0.650, val_f1=0.603
# [seed 246] epoch 13 | train_loss=0.5387, train_acc=0.811, train_f1=0.812 | val_loss=1.3471, val_acc=0.650, val_f1=0.573
# [seed 246] epoch 14 | train_loss=0.4590, train_acc=0.850, train_f1=0.855 | val_loss=1.2602, val_acc=0.600, val_f1=0.564
# [seed 246] epoch 15 | train_loss=0.4610, train_acc=0.867, train_f1=0.871 | val_loss=1.2825, val_acc=0.550, val_f1=0.452
# [seed 246] epoch 16 | train_loss=0.4314, train_acc=0.878, train_f1=0.883 | val_loss=1.3265, val_acc=0.650, val_f1=0.542
# [seed 246] epoch 17 | train_loss=0.4069, train_acc=0.872, train_f1=0.878 | val_loss=1.3753, val_acc=0.450, val_f1=0.370
# [seed 246] epoch 18 | train_loss=0.3674, train_acc=0.906, train_f1=0.906 | val_loss=1.3337, val_acc=0.700, val_f1=0.603
# [seed 246] epoch 19 | train_loss=0.3361, train_acc=0.889, train_f1=0.894 | val_loss=1.4822, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 20 | train_loss=0.2968, train_acc=0.922, train_f1=0.918 | val_loss=1.5815, val_acc=0.600, val_f1=0.530
# [seed 246] epoch 21 | train_loss=0.4321, train_acc=0.817, train_f1=0.824 | val_loss=1.5522, val_acc=0.550, val_f1=0.461
# [seed 246] epoch 22 | train_loss=0.3268, train_acc=0.911, train_f1=0.911 | val_loss=1.6291, val_acc=0.550, val_f1=0.458
# [seed 246] epoch 23 | train_loss=0.2298, train_acc=0.939, train_f1=0.929 | val_loss=1.6261, val_acc=0.550, val_f1=0.491
# [seed 246] epoch 24 | train_loss=0.2884, train_acc=0.928, train_f1=0.929 | val_loss=1.5398, val_acc=0.700, val_f1=0.664
# [seed 246] epoch 25 | train_loss=0.2473, train_acc=0.928, train_f1=0.931 | val_loss=1.4621, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 26 | train_loss=0.2312, train_acc=0.928, train_f1=0.931 | val_loss=1.4616, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 27 | train_loss=0.2494, train_acc=0.933, train_f1=0.935 | val_loss=1.5808, val_acc=0.550, val_f1=0.430
# [seed 246] epoch 28 | train_loss=0.2403, train_acc=0.922, train_f1=0.929 | val_loss=1.6425, val_acc=0.500, val_f1=0.397
# [seed 246] epoch 29 | train_loss=0.2150, train_acc=0.933, train_f1=0.939 | val_loss=1.7223, val_acc=0.500, val_f1=0.421
# [seed 246] epoch 30 | train_loss=0.2262, train_acc=0.928, train_f1=0.928 | val_loss=1.7439, val_acc=0.600, val_f1=0.497
# [seed 246] epoch 31 | train_loss=0.1882, train_acc=0.922, train_f1=0.928 | val_loss=1.7154, val_acc=0.600, val_f1=0.517
# [seed 246] epoch 32 | train_loss=0.2065, train_acc=0.944, train_f1=0.947 | val_loss=1.7369, val_acc=0.550, val_f1=0.448
# [seed 246] epoch 33 | train_loss=0.2478, train_acc=0.950, train_f1=0.954 | val_loss=1.8658, val_acc=0.500, val_f1=0.382
# [seed 246] epoch 34 | train_loss=0.1437, train_acc=0.972, train_f1=0.974 | val_loss=1.8179, val_acc=0.500, val_f1=0.412
# [seed 246] epoch 35 | train_loss=0.1525, train_acc=0.944, train_f1=0.950 | val_loss=1.8319, val_acc=0.500, val_f1=0.393
# [seed 246] epoch 36 | train_loss=0.2008, train_acc=0.922, train_f1=0.920 | val_loss=1.6833, val_acc=0.500, val_f1=0.393
# [seed 246] epoch 37 | train_loss=0.1099, train_acc=0.978, train_f1=0.981 | val_loss=1.6374, val_acc=0.600, val_f1=0.539
# [seed 246] epoch 38 | train_loss=0.1713, train_acc=0.950, train_f1=0.962 | val_loss=1.6786, val_acc=0.650, val_f1=0.576
# [seed 246] epoch 39 | train_loss=0.1084, train_acc=0.983, train_f1=0.981 | val_loss=1.7513, val_acc=0.650, val_f1=0.606
# [seed 246] epoch 40 | train_loss=0.1555, train_acc=0.944, train_f1=0.952 | val_loss=1.8246, val_acc=0.600, val_f1=0.500
# [seed 246] epoch 41 | train_loss=0.1291, train_acc=0.967, train_f1=0.964 | val_loss=1.7618, val_acc=0.600, val_f1=0.470
# [seed 246] epoch 42 | train_loss=0.1453, train_acc=0.967, train_f1=0.970 | val_loss=1.9308, val_acc=0.550, val_f1=0.461
# [seed 246] epoch 43 | train_loss=0.1936, train_acc=0.956, train_f1=0.952 | val_loss=2.2234, val_acc=0.500, val_f1=0.421
# [seed 246] epoch 44 | train_loss=0.1651, train_acc=0.961, train_f1=0.967 | val_loss=1.9452, val_acc=0.600, val_f1=0.497
# [seed 246] epoch 45 | train_loss=0.2199, train_acc=0.922, train_f1=0.918 | val_loss=1.9032, val_acc=0.550, val_f1=0.473
# [seed 246] epoch 46 | train_loss=0.1631, train_acc=0.933, train_f1=0.939 | val_loss=1.9533, val_acc=0.450, val_f1=0.367
# [seed 246] epoch 47 | train_loss=0.1876, train_acc=0.933, train_f1=0.938 | val_loss=1.9300, val_acc=0.550, val_f1=0.461
# [seed 246] epoch 48 | train_loss=0.1587, train_acc=0.956, train_f1=0.959 | val_loss=1.9577, val_acc=0.600, val_f1=0.487
# [seed 246] epoch 49 | train_loss=0.1673, train_acc=0.956, train_f1=0.951 | val_loss=2.0637, val_acc=0.500, val_f1=0.403
# [seed 246] epoch 50 | train_loss=0.1344, train_acc=0.967, train_f1=0.966 | val_loss=2.1241, val_acc=0.550, val_f1=0.458
# [seed 246] epoch 51 | train_loss=0.0722, train_acc=0.989, train_f1=0.992 | val_loss=2.1391, val_acc=0.600, val_f1=0.497
# [seed 246] epoch 52 | train_loss=0.1027, train_acc=0.978, train_f1=0.978 | val_loss=2.1630, val_acc=0.600, val_f1=0.500
# [seed 246] epoch 53 | train_loss=0.1138, train_acc=0.967, train_f1=0.967 | val_loss=2.1790, val_acc=0.500, val_f1=0.394
# [seed 246] epoch 54 | train_loss=0.1293, train_acc=0.950, train_f1=0.949 | val_loss=2.2491, val_acc=0.500, val_f1=0.394
# [seed 246] epoch 55 | train_loss=0.1153, train_acc=0.950, train_f1=0.957 | val_loss=1.9465, val_acc=0.600, val_f1=0.488
# [seed 246] epoch 56 | train_loss=0.1138, train_acc=0.956, train_f1=0.956 | val_loss=1.8483, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 57 | train_loss=0.1362, train_acc=0.961, train_f1=0.956 | val_loss=2.0313, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 58 | train_loss=0.0994, train_acc=0.978, train_f1=0.971 | val_loss=2.0589, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 59 | train_loss=0.0984, train_acc=0.967, train_f1=0.964 | val_loss=2.1134, val_acc=0.550, val_f1=0.467
# [seed 246] epoch 60 | train_loss=0.1050, train_acc=0.972, train_f1=0.968 | val_loss=2.1204, val_acc=0.450, val_f1=0.367
# [seed 246] epoch 61 | train_loss=0.0945, train_acc=0.972, train_f1=0.971 | val_loss=2.0703, val_acc=0.500, val_f1=0.397
# [seed 246] epoch 62 | train_loss=0.1227, train_acc=0.961, train_f1=0.961 | val_loss=2.1935, val_acc=0.550, val_f1=0.461
# [seed 246] epoch 63 | train_loss=0.0942, train_acc=0.961, train_f1=0.965 | val_loss=2.0372, val_acc=0.600, val_f1=0.488
# [seed 246] epoch 64 | train_loss=0.0735, train_acc=0.972, train_f1=0.974 | val_loss=2.0607, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 65 | train_loss=0.0992, train_acc=0.950, train_f1=0.956 | val_loss=2.0872, val_acc=0.550, val_f1=0.443
# [seed 246] epoch 66 | train_loss=0.0703, train_acc=0.972, train_f1=0.973 | val_loss=2.3005, val_acc=0.500, val_f1=0.406
# [seed 246] epoch 67 | train_loss=0.0839, train_acc=0.989, train_f1=0.984 | val_loss=2.3620, val_acc=0.500, val_f1=0.397
# [seed 246] epoch 68 | train_loss=0.1499, train_acc=0.944, train_f1=0.942 | val_loss=2.4722, val_acc=0.550, val_f1=0.436
# [seed 246] epoch 69 | train_loss=0.0859, train_acc=0.961, train_f1=0.962 | val_loss=2.5537, val_acc=0.550, val_f1=0.436
# [seed 246] epoch 70 | train_loss=0.0907, train_acc=0.978, train_f1=0.982 | val_loss=2.5554, val_acc=0.600, val_f1=0.491
# [seed 246] epoch 71 | train_loss=0.1013, train_acc=0.961, train_f1=0.962 | val_loss=2.5193, val_acc=0.550, val_f1=0.452
# [seed 246] epoch 72 | train_loss=0.0943, train_acc=0.956, train_f1=0.952 | val_loss=2.5448, val_acc=0.550, val_f1=0.452
# [seed 246] epoch 73 | train_loss=0.0548, train_acc=0.994, train_f1=0.993 | val_loss=2.4967, val_acc=0.550, val_f1=0.448
# [seed 246] epoch 74 | train_loss=0.0605, train_acc=0.989, train_f1=0.992 | val_loss=2.5797, val_acc=0.550, val_f1=0.432
# [seed 246] epoch 75 | train_loss=0.0877, train_acc=0.972, train_f1=0.974 | val_loss=2.5864, val_acc=0.550, val_f1=0.432
# [seed 246] epoch 76 | train_loss=0.0775, train_acc=0.961, train_f1=0.967 | val_loss=2.5663, val_acc=0.500, val_f1=0.415
# [seed 246] epoch 77 | train_loss=0.0792, train_acc=0.967, train_f1=0.970 | val_loss=2.5423, val_acc=0.500, val_f1=0.445
# [seed 246] epoch 78 | train_loss=0.1148, train_acc=0.944, train_f1=0.950 | val_loss=2.3308, val_acc=0.400, val_f1=0.358
# [seed 246] epoch 79 | train_loss=0.0507, train_acc=0.989, train_f1=0.992 | val_loss=2.2500, val_acc=0.500, val_f1=0.445
# [seed 246] epoch 80 | train_loss=0.0905, train_acc=0.967, train_f1=0.969 | val_loss=2.3868, val_acc=0.550, val_f1=0.458
# [seed 246] epoch 81 | train_loss=0.0489, train_acc=0.994, train_f1=0.994 | val_loss=2.5642, val_acc=0.500, val_f1=0.412
# [seed 246] epoch 82 | train_loss=0.1009, train_acc=0.967, train_f1=0.970 | val_loss=2.5495, val_acc=0.450, val_f1=0.367
# [seed 246] epoch 83 | train_loss=0.0678, train_acc=0.989, train_f1=0.992 | val_loss=2.4083, val_acc=0.450, val_f1=0.367
# [seed 246] epoch 84 | train_loss=0.0506, train_acc=0.978, train_f1=0.978 | val_loss=2.1035, val_acc=0.500, val_f1=0.406
# [seed 246] epoch 85 | train_loss=0.0572, train_acc=0.978, train_f1=0.977 | val_loss=2.0312, val_acc=0.500, val_f1=0.406
# [seed 246] epoch 86 | train_loss=0.0228, train_acc=1.000, train_f1=1.000 | val_loss=2.0035, val_acc=0.500, val_f1=0.418
# [seed 246] epoch 87 | train_loss=0.0427, train_acc=0.994, train_f1=0.997 | val_loss=2.1397, val_acc=0.500, val_f1=0.427
# [seed 246] epoch 88 | train_loss=0.0519, train_acc=0.983, train_f1=0.979 | val_loss=2.2587, val_acc=0.550, val_f1=0.461
# [seed 246] epoch 89 | train_loss=0.0510, train_acc=0.983, train_f1=0.984 | val_loss=2.4616, val_acc=0.600, val_f1=0.500
# [seed 246] epoch 90 | train_loss=0.1192, train_acc=0.972, train_f1=0.968 | val_loss=2.6428, val_acc=0.600, val_f1=0.500
# [seed 246] epoch 91 | train_loss=0.0962, train_acc=0.972, train_f1=0.974 | val_loss=2.6192, val_acc=0.550, val_f1=0.458
# [seed 246] epoch 92 | train_loss=0.0732, train_acc=0.972, train_f1=0.971 | val_loss=2.6463, val_acc=0.550, val_f1=0.473
# [seed 246] epoch 93 | train_loss=0.1040, train_acc=0.950, train_f1=0.955 | val_loss=2.6498, val_acc=0.550, val_f1=0.458
# [seed 246] epoch 94 | train_loss=0.0662, train_acc=0.983, train_f1=0.983 | val_loss=2.4866, val_acc=0.550, val_f1=0.458
# [seed 246] epoch 95 | train_loss=0.0865, train_acc=0.967, train_f1=0.966 | val_loss=2.6510, val_acc=0.500, val_f1=0.421
# [seed 246] epoch 96 | train_loss=0.0856, train_acc=0.956, train_f1=0.962 | val_loss=2.8710, val_acc=0.500, val_f1=0.397
# [seed 246] epoch 97 | train_loss=0.0600, train_acc=0.989, train_f1=0.991 | val_loss=2.6520, val_acc=0.500, val_f1=0.397
# [seed 246] epoch 98 | train_loss=0.0792, train_acc=0.983, train_f1=0.982 | val_loss=2.4115, val_acc=0.500, val_f1=0.406
# [seed 246] epoch 99 | train_loss=0.0642, train_acc=0.989, train_f1=0.991 | val_loss=2.3600, val_acc=0.600, val_f1=0.470
# [seed 246] epoch 100 | train_loss=0.0757, train_acc=0.983, train_f1=0.985 | val_loss=2.2143, val_acc=0.550, val_f1=0.467
# [seed 246] epoch 101 | train_loss=0.0572, train_acc=0.994, train_f1=0.996 | val_loss=2.3515, val_acc=0.450, val_f1=0.394
# [seed 246] epoch 102 | train_loss=0.0493, train_acc=0.983, train_f1=0.988 | val_loss=2.3716, val_acc=0.450, val_f1=0.361
# [seed 246] epoch 103 | train_loss=0.0740, train_acc=0.967, train_f1=0.973 | val_loss=2.2243, val_acc=0.500, val_f1=0.394
# [seed 246] epoch 104 | train_loss=0.0543, train_acc=0.983, train_f1=0.984 | val_loss=2.1266, val_acc=0.500, val_f1=0.376
# [seed 246] epoch 105 | train_loss=0.0811, train_acc=0.967, train_f1=0.973 | val_loss=2.2132, val_acc=0.550, val_f1=0.442
# [seed 246] epoch 106 | train_loss=0.0557, train_acc=0.989, train_f1=0.992 | val_loss=2.1688, val_acc=0.600, val_f1=0.500
# [seed 246] epoch 107 | train_loss=0.0635, train_acc=0.967, train_f1=0.973 | val_loss=2.1562, val_acc=0.550, val_f1=0.445
# [seed 246] epoch 108 | train_loss=0.0490, train_acc=0.989, train_f1=0.992 | val_loss=2.2915, val_acc=0.550, val_f1=0.409
# [seed 246] epoch 109 | train_loss=0.0327, train_acc=0.994, train_f1=0.993 | val_loss=2.2786, val_acc=0.500, val_f1=0.370
# [seed 246] epoch 110 | train_loss=0.0766, train_acc=0.978, train_f1=0.975 | val_loss=2.3146, val_acc=0.500, val_f1=0.361
# [seed 246] epoch 111 | train_loss=0.0587, train_acc=0.978, train_f1=0.980 | val_loss=2.5162, val_acc=0.500, val_f1=0.361
# [seed 246] epoch 112 | train_loss=0.0675, train_acc=0.972, train_f1=0.971 | val_loss=2.6803, val_acc=0.550, val_f1=0.430
# [seed 246] epoch 113 | train_loss=0.0450, train_acc=0.994, train_f1=0.996 | val_loss=2.7379, val_acc=0.500, val_f1=0.387
# [seed 246] epoch 114 | train_loss=0.0765, train_acc=0.983, train_f1=0.980 | val_loss=2.7104, val_acc=0.500, val_f1=0.387
# [seed 246] epoch 115 | train_loss=0.1014, train_acc=0.961, train_f1=0.958 | val_loss=2.9629, val_acc=0.550, val_f1=0.439
# [seed 246] epoch 116 | train_loss=0.1222, train_acc=0.967, train_f1=0.966 | val_loss=2.8782, val_acc=0.550, val_f1=0.439
# [seed 246] epoch 117 | train_loss=0.0396, train_acc=0.994, train_f1=0.996 | val_loss=2.5755, val_acc=0.500, val_f1=0.376
# [seed 246] epoch 118 | train_loss=0.0734, train_acc=0.983, train_f1=0.986 | val_loss=2.4257, val_acc=0.500, val_f1=0.372
# [seed 246] epoch 119 | train_loss=0.0780, train_acc=0.967, train_f1=0.973 | val_loss=2.2953, val_acc=0.550, val_f1=0.429
# [seed 246] epoch 120 | train_loss=0.0625, train_acc=0.967, train_f1=0.966 | val_loss=2.3567, val_acc=0.550, val_f1=0.465
# [seed 246] epoch 121 | train_loss=0.0644, train_acc=0.983, train_f1=0.984 | val_loss=2.2151, val_acc=0.550, val_f1=0.430
# [seed 246] epoch 122 | train_loss=0.0514, train_acc=0.989, train_f1=0.985 | val_loss=2.2518, val_acc=0.600, val_f1=0.500
# [seed 246] epoch 123 | train_loss=0.0533, train_acc=0.978, train_f1=0.982 | val_loss=2.3131, val_acc=0.550, val_f1=0.473
# [seed 246] epoch 124 | train_loss=0.0462, train_acc=0.983, train_f1=0.987 | val_loss=2.2888, val_acc=0.500, val_f1=0.403
# [seed 246] epoch 125 | train_loss=0.0421, train_acc=0.989, train_f1=0.991 | val_loss=2.2582, val_acc=0.550, val_f1=0.430
# [seed 246] epoch 126 | train_loss=0.0309, train_acc=0.989, train_f1=0.990 | val_loss=2.2707, val_acc=0.550, val_f1=0.510
# [seed 246] epoch 127 | train_loss=0.0510, train_acc=0.983, train_f1=0.987 | val_loss=2.2126, val_acc=0.600, val_f1=0.552
# [seed 246] epoch 128 | train_loss=0.0691, train_acc=0.978, train_f1=0.981 | val_loss=2.1953, val_acc=0.600, val_f1=0.573
# [seed 246] epoch 129 | train_loss=0.0853, train_acc=0.972, train_f1=0.971 | val_loss=2.2114, val_acc=0.650, val_f1=0.606
# [seed 246] epoch 130 | train_loss=0.0302, train_acc=1.000, train_f1=1.000 | val_loss=2.3218, val_acc=0.600, val_f1=0.500
# [seed 246] epoch 131 | train_loss=0.0681, train_acc=0.978, train_f1=0.982 | val_loss=2.3979, val_acc=0.600, val_f1=0.500
# [seed 246] epoch 132 | train_loss=0.0477, train_acc=0.978, train_f1=0.982 | val_loss=2.4305, val_acc=0.550, val_f1=0.445
# [seed 246] epoch 133 | train_loss=0.0433, train_acc=0.983, train_f1=0.987 | val_loss=2.6345, val_acc=0.450, val_f1=0.382
# [seed 246] epoch 134 | train_loss=0.0598, train_acc=0.978, train_f1=0.977 | val_loss=2.8723, val_acc=0.450, val_f1=0.382
# [seed 246] epoch 135 | train_loss=0.0192, train_acc=0.994, train_f1=0.996 | val_loss=2.8790, val_acc=0.450, val_f1=0.382
# [seed 246] epoch 136 | train_loss=0.0629, train_acc=0.978, train_f1=0.978 | val_loss=2.9244, val_acc=0.450, val_f1=0.382
# [seed 246] epoch 137 | train_loss=0.0327, train_acc=0.989, train_f1=0.987 | val_loss=2.8785, val_acc=0.450, val_f1=0.382
# [seed 246] epoch 138 | train_loss=0.0413, train_acc=0.989, train_f1=0.985 | val_loss=2.8291, val_acc=0.500, val_f1=0.419
# [seed 246] epoch 139 | train_loss=0.0391, train_acc=0.989, train_f1=0.992 | val_loss=2.9041, val_acc=0.450, val_f1=0.382
# [seed 246] epoch 140 | train_loss=0.0362, train_acc=0.989, train_f1=0.989 | val_loss=2.9771, val_acc=0.450, val_f1=0.382
# [seed 246] epoch 141 | train_loss=0.0704, train_acc=0.972, train_f1=0.975 | val_loss=2.8650, val_acc=0.450, val_f1=0.409
# [seed 246] epoch 142 | train_loss=0.0314, train_acc=0.989, train_f1=0.987 | val_loss=2.6685, val_acc=0.500, val_f1=0.442
# [seed 246] epoch 143 | train_loss=0.0629, train_acc=0.978, train_f1=0.977 | val_loss=2.7342, val_acc=0.500, val_f1=0.437
# [seed 246] epoch 144 | train_loss=0.0383, train_acc=0.989, train_f1=0.991 | val_loss=2.7367, val_acc=0.500, val_f1=0.406
# [seed 246] epoch 145 | train_loss=0.0360, train_acc=0.994, train_f1=0.996 | val_loss=2.7233, val_acc=0.500, val_f1=0.419
# [seed 246] epoch 146 | train_loss=0.0583, train_acc=0.972, train_f1=0.972 | val_loss=2.6712, val_acc=0.500, val_f1=0.419
# [seed 246] epoch 147 | train_loss=0.0912, train_acc=0.972, train_f1=0.975 | val_loss=2.7152, val_acc=0.550, val_f1=0.462
# [seed 246] epoch 148 | train_loss=0.0532, train_acc=0.983, train_f1=0.984 | val_loss=2.7372, val_acc=0.550, val_f1=0.473
# [seed 246] epoch 149 | train_loss=0.0854, train_acc=0.972, train_f1=0.974 | val_loss=2.6012, val_acc=0.550, val_f1=0.473
# [seed 246] epoch 150 | train_loss=0.0853, train_acc=0.983, train_f1=0.989 | val_loss=2.5851, val_acc=0.550, val_f1=0.443
# [seed 246] epoch 151 | train_loss=0.1088, train_acc=0.956, train_f1=0.952 | val_loss=2.8123, val_acc=0.550, val_f1=0.473
# [seed 246] epoch 152 | train_loss=0.0863, train_acc=0.961, train_f1=0.966 | val_loss=2.6120, val_acc=0.500, val_f1=0.437
# [seed 246] epoch 153 | train_loss=0.0229, train_acc=1.000, train_f1=1.000 | val_loss=2.6437, val_acc=0.500, val_f1=0.391
# [seed 246] epoch 154 | train_loss=0.0623, train_acc=0.978, train_f1=0.980 | val_loss=2.4367, val_acc=0.550, val_f1=0.439
# [seed 246] epoch 155 | train_loss=0.0299, train_acc=0.989, train_f1=0.991 | val_loss=2.4050, val_acc=0.550, val_f1=0.470
# [seed 246] epoch 156 | train_loss=0.0509, train_acc=0.989, train_f1=0.988 | val_loss=2.6022, val_acc=0.550, val_f1=0.470
# [seed 246] epoch 157 | train_loss=0.0335, train_acc=0.994, train_f1=0.996 | val_loss=2.7355, val_acc=0.550, val_f1=0.439
# [seed 246] epoch 158 | train_loss=0.0449, train_acc=0.989, train_f1=0.988 | val_loss=2.7892, val_acc=0.550, val_f1=0.443
# [seed 246] epoch 159 | train_loss=0.0285, train_acc=0.994, train_f1=0.993 | val_loss=2.8013, val_acc=0.550, val_f1=0.443
# [seed 246] epoch 160 | train_loss=0.0489, train_acc=0.983, train_f1=0.987 | val_loss=3.0360, val_acc=0.500, val_f1=0.382
# [seed 246] epoch 161 | train_loss=0.0749, train_acc=0.967, train_f1=0.963 | val_loss=3.1560, val_acc=0.500, val_f1=0.412
# [seed 246] epoch 162 | train_loss=0.0591, train_acc=0.972, train_f1=0.972 | val_loss=2.9043, val_acc=0.550, val_f1=0.427
# [seed 246] epoch 163 | train_loss=0.0685, train_acc=0.972, train_f1=0.965 | val_loss=2.6914, val_acc=0.550, val_f1=0.421
# [seed 246] epoch 164 | train_loss=0.0765, train_acc=0.983, train_f1=0.982 | val_loss=2.5448, val_acc=0.550, val_f1=0.417
# [seed 246] epoch 165 | train_loss=0.0635, train_acc=0.983, train_f1=0.984 | val_loss=2.5098, val_acc=0.600, val_f1=0.521
# [seed 246] epoch 166 | train_loss=0.0740, train_acc=0.961, train_f1=0.959 | val_loss=2.4759, val_acc=0.650, val_f1=0.591
# [seed 246] epoch 167 | train_loss=0.0773, train_acc=0.961, train_f1=0.963 | val_loss=2.4595, val_acc=0.650, val_f1=0.561
# [seed 246] epoch 168 | train_loss=0.0595, train_acc=0.978, train_f1=0.984 | val_loss=2.5607, val_acc=0.600, val_f1=0.521
# [seed 246] epoch 169 | train_loss=0.1091, train_acc=0.978, train_f1=0.980 | val_loss=2.7609, val_acc=0.550, val_f1=0.485
# [seed 246] epoch 170 | train_loss=0.0273, train_acc=0.994, train_f1=0.997 | val_loss=2.7291, val_acc=0.550, val_f1=0.503
# [seed 246] epoch 171 | train_loss=0.0901, train_acc=0.944, train_f1=0.952 | val_loss=2.7966, val_acc=0.550, val_f1=0.443
# [seed 246] epoch 172 | train_loss=0.0430, train_acc=0.983, train_f1=0.983 | val_loss=2.6261, val_acc=0.600, val_f1=0.491
# [seed 246] epoch 173 | train_loss=0.0212, train_acc=1.000, train_f1=1.000 | val_loss=2.5717, val_acc=0.600, val_f1=0.491
# [seed 246] epoch 174 | train_loss=0.0345, train_acc=0.994, train_f1=0.995 | val_loss=2.5835, val_acc=0.600, val_f1=0.491
# [seed 246] epoch 175 | train_loss=0.0299, train_acc=0.994, train_f1=0.993 | val_loss=2.6508, val_acc=0.550, val_f1=0.436
# [seed 246] epoch 176 | train_loss=0.0262, train_acc=1.000, train_f1=1.000 | val_loss=2.9321, val_acc=0.600, val_f1=0.491
# [seed 246] epoch 177 | train_loss=0.0256, train_acc=0.983, train_f1=0.984 | val_loss=2.9528, val_acc=0.600, val_f1=0.491
# [seed 246] epoch 178 | train_loss=0.0494, train_acc=0.972, train_f1=0.980 | val_loss=3.0090, val_acc=0.500, val_f1=0.406
# [seed 246] epoch 179 | train_loss=0.0302, train_acc=0.989, train_f1=0.988 | val_loss=3.0480, val_acc=0.550, val_f1=0.458
# [seed 246] epoch 180 | train_loss=0.0478, train_acc=0.983, train_f1=0.982 | val_loss=2.9369, val_acc=0.550, val_f1=0.464
# [seed 246] epoch 181 | train_loss=0.0290, train_acc=0.989, train_f1=0.989 | val_loss=2.8412, val_acc=0.500, val_f1=0.424
# [seed 246] epoch 182 | train_loss=0.0218, train_acc=0.989, train_f1=0.992 | val_loss=2.7680, val_acc=0.600, val_f1=0.491
# [seed 246] epoch 183 | train_loss=0.0295, train_acc=0.994, train_f1=0.994 | val_loss=2.9087, val_acc=0.600, val_f1=0.491
# [seed 246] epoch 184 | train_loss=0.0190, train_acc=1.000, train_f1=1.000 | val_loss=3.0121, val_acc=0.600, val_f1=0.491
# [seed 246] epoch 185 | train_loss=0.0189, train_acc=0.994, train_f1=0.996 | val_loss=3.1241, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 186 | train_loss=0.0085, train_acc=1.000, train_f1=1.000 | val_loss=3.0566, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 187 | train_loss=0.0387, train_acc=0.989, train_f1=0.987 | val_loss=2.9179, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 188 | train_loss=0.0569, train_acc=0.978, train_f1=0.982 | val_loss=2.6523, val_acc=0.600, val_f1=0.491
# [seed 246] epoch 189 | train_loss=0.0621, train_acc=0.983, train_f1=0.979 | val_loss=2.6435, val_acc=0.600, val_f1=0.491
# [seed 246] epoch 190 | train_loss=0.0184, train_acc=0.994, train_f1=0.992 | val_loss=2.6865, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 191 | train_loss=0.0567, train_acc=0.967, train_f1=0.967 | val_loss=2.6644, val_acc=0.600, val_f1=0.521
# [seed 246] epoch 192 | train_loss=0.0156, train_acc=1.000, train_f1=1.000 | val_loss=2.6596, val_acc=0.600, val_f1=0.500
# [seed 246] epoch 193 | train_loss=0.0346, train_acc=0.989, train_f1=0.992 | val_loss=2.8198, val_acc=0.600, val_f1=0.485
# [seed 246] epoch 194 | train_loss=0.0458, train_acc=0.989, train_f1=0.989 | val_loss=3.1240, val_acc=0.500, val_f1=0.408
# [seed 246] epoch 195 | train_loss=0.0229, train_acc=1.000, train_f1=1.000 | val_loss=3.1121, val_acc=0.500, val_f1=0.392
# [seed 246] epoch 196 | train_loss=0.0612, train_acc=0.983, train_f1=0.978 | val_loss=3.0181, val_acc=0.600, val_f1=0.500
# [seed 246] epoch 197 | train_loss=0.1362, train_acc=0.939, train_f1=0.934 | val_loss=2.8868, val_acc=0.600, val_f1=0.500
# [seed 246] epoch 198 | train_loss=0.0300, train_acc=0.989, train_f1=0.987 | val_loss=2.6125, val_acc=0.450, val_f1=0.406
# [seed 246] epoch 199 | train_loss=0.1339, train_acc=0.944, train_f1=0.943 | val_loss=2.5051, val_acc=0.500, val_f1=0.476
# [seed 246] epoch 200 | train_loss=0.0558, train_acc=0.967, train_f1=0.959 | val_loss=2.4310, val_acc=0.650, val_f1=0.558
# [seed 246] epoch 201 | train_loss=0.0932, train_acc=0.967, train_f1=0.966 | val_loss=2.3807, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 202 | train_loss=0.0996, train_acc=0.972, train_f1=0.967 | val_loss=2.4514, val_acc=0.550, val_f1=0.497
# [seed 246] epoch 203 | train_loss=0.0689, train_acc=0.983, train_f1=0.987 | val_loss=2.6650, val_acc=0.500, val_f1=0.465
# [seed 246] epoch 204 | train_loss=0.0698, train_acc=0.961, train_f1=0.962 | val_loss=2.7232, val_acc=0.600, val_f1=0.521
# [seed 246] epoch 205 | train_loss=0.0564, train_acc=0.978, train_f1=0.981 | val_loss=2.8336, val_acc=0.550, val_f1=0.432
# [seed 246] epoch 206 | train_loss=0.0330, train_acc=0.983, train_f1=0.986 | val_loss=3.1268, val_acc=0.550, val_f1=0.432
# [seed 246] epoch 207 | train_loss=0.1042, train_acc=0.961, train_f1=0.962 | val_loss=3.3516, val_acc=0.550, val_f1=0.467
# [seed 246] epoch 208 | train_loss=0.0506, train_acc=0.983, train_f1=0.986 | val_loss=3.4530, val_acc=0.550, val_f1=0.442
# [seed 246] epoch 209 | train_loss=0.0521, train_acc=0.972, train_f1=0.970 | val_loss=3.5045, val_acc=0.500, val_f1=0.412
# [seed 246] epoch 210 | train_loss=0.0493, train_acc=0.972, train_f1=0.971 | val_loss=3.4560, val_acc=0.550, val_f1=0.442
# [seed 246] epoch 211 | train_loss=0.0523, train_acc=0.983, train_f1=0.982 | val_loss=3.5671, val_acc=0.550, val_f1=0.436
# [seed 246] epoch 212 | train_loss=0.0331, train_acc=0.978, train_f1=0.982 | val_loss=3.5924, val_acc=0.550, val_f1=0.411
# [seed 246] epoch 213 | train_loss=0.1021, train_acc=0.956, train_f1=0.957 | val_loss=3.2864, val_acc=0.600, val_f1=0.470
# [seed 246] epoch 214 | train_loss=0.0580, train_acc=0.978, train_f1=0.978 | val_loss=3.1843, val_acc=0.550, val_f1=0.452
# [seed 246] epoch 215 | train_loss=0.0466, train_acc=0.994, train_f1=0.990 | val_loss=3.1276, val_acc=0.600, val_f1=0.509
# [seed 246] epoch 216 | train_loss=0.0400, train_acc=0.989, train_f1=0.989 | val_loss=3.1883, val_acc=0.600, val_f1=0.500
# [seed 246] epoch 217 | train_loss=0.0669, train_acc=0.972, train_f1=0.972 | val_loss=3.2142, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 218 | train_loss=0.0302, train_acc=0.989, train_f1=0.990 | val_loss=3.1181, val_acc=0.650, val_f1=0.558
# [seed 246] epoch 219 | train_loss=0.0221, train_acc=1.000, train_f1=1.000 | val_loss=2.9306, val_acc=0.650, val_f1=0.558
# [seed 246] epoch 220 | train_loss=0.0184, train_acc=1.000, train_f1=1.000 | val_loss=2.8114, val_acc=0.650, val_f1=0.558
# [seed 246] epoch 221 | train_loss=0.0594, train_acc=0.967, train_f1=0.970 | val_loss=2.8294, val_acc=0.650, val_f1=0.558
# [seed 246] epoch 222 | train_loss=0.1017, train_acc=0.944, train_f1=0.952 | val_loss=2.6108, val_acc=0.650, val_f1=0.558
# [seed 246] epoch 223 | train_loss=0.0436, train_acc=0.978, train_f1=0.978 | val_loss=2.7743, val_acc=0.550, val_f1=0.473
# [seed 246] epoch 224 | train_loss=0.0754, train_acc=0.956, train_f1=0.956 | val_loss=2.8915, val_acc=0.550, val_f1=0.473
# [seed 246] epoch 225 | train_loss=0.0228, train_acc=0.994, train_f1=0.996 | val_loss=2.7968, val_acc=0.600, val_f1=0.500
# [seed 246] epoch 226 | train_loss=0.0598, train_acc=0.989, train_f1=0.991 | val_loss=2.7521, val_acc=0.600, val_f1=0.500
# [seed 246] epoch 227 | train_loss=0.0904, train_acc=0.983, train_f1=0.982 | val_loss=2.6806, val_acc=0.650, val_f1=0.558
# [seed 246] epoch 228 | train_loss=0.0327, train_acc=0.989, train_f1=0.988 | val_loss=2.8179, val_acc=0.650, val_f1=0.558
# [seed 246] epoch 229 | train_loss=0.0331, train_acc=0.994, train_f1=0.992 | val_loss=3.0076, val_acc=0.650, val_f1=0.558
# [seed 246] epoch 230 | train_loss=0.1191, train_acc=0.972, train_f1=0.965 | val_loss=2.9402, val_acc=0.550, val_f1=0.445
# [seed 246] epoch 231 | train_loss=0.0426, train_acc=0.978, train_f1=0.979 | val_loss=3.0581, val_acc=0.550, val_f1=0.430
# [seed 246] epoch 232 | train_loss=0.0609, train_acc=0.983, train_f1=0.986 | val_loss=3.1391, val_acc=0.550, val_f1=0.430
# [seed 246] epoch 233 | train_loss=0.0113, train_acc=1.000, train_f1=1.000 | val_loss=3.1597, val_acc=0.550, val_f1=0.430
# [seed 246] epoch 234 | train_loss=0.0911, train_acc=0.972, train_f1=0.966 | val_loss=2.8244, val_acc=0.550, val_f1=0.430
# [seed 246] epoch 235 | train_loss=0.0539, train_acc=0.978, train_f1=0.976 | val_loss=2.7748, val_acc=0.550, val_f1=0.430
# [seed 246] epoch 236 | train_loss=0.0451, train_acc=0.978, train_f1=0.978 | val_loss=2.7372, val_acc=0.600, val_f1=0.488
# [seed 246] epoch 237 | train_loss=0.0596, train_acc=0.978, train_f1=0.977 | val_loss=2.4786, val_acc=0.600, val_f1=0.488
# [seed 246] epoch 238 | train_loss=0.0364, train_acc=0.983, train_f1=0.984 | val_loss=2.4910, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 239 | train_loss=0.0358, train_acc=0.989, train_f1=0.991 | val_loss=2.4521, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 240 | train_loss=0.0285, train_acc=0.989, train_f1=0.988 | val_loss=2.4802, val_acc=0.600, val_f1=0.488
# [seed 246] epoch 241 | train_loss=0.0223, train_acc=0.994, train_f1=0.993 | val_loss=2.5366, val_acc=0.600, val_f1=0.488
# [seed 246] epoch 242 | train_loss=0.0534, train_acc=0.994, train_f1=0.992 | val_loss=2.5191, val_acc=0.550, val_f1=0.415
# [seed 246] epoch 243 | train_loss=0.0414, train_acc=0.983, train_f1=0.986 | val_loss=2.3980, val_acc=0.550, val_f1=0.415
# [seed 246] epoch 244 | train_loss=0.0359, train_acc=0.978, train_f1=0.981 | val_loss=2.3848, val_acc=0.600, val_f1=0.455
# [seed 246] epoch 245 | train_loss=0.0734, train_acc=0.978, train_f1=0.973 | val_loss=2.5509, val_acc=0.600, val_f1=0.455
# [seed 246] epoch 246 | train_loss=0.0321, train_acc=0.983, train_f1=0.982 | val_loss=2.6084, val_acc=0.600, val_f1=0.455
# [seed 246] epoch 247 | train_loss=0.0402, train_acc=0.983, train_f1=0.985 | val_loss=2.5984, val_acc=0.600, val_f1=0.455
# [seed 246] epoch 248 | train_loss=0.0533, train_acc=0.983, train_f1=0.984 | val_loss=2.6578, val_acc=0.550, val_f1=0.415
# [seed 246] epoch 249 | train_loss=0.0343, train_acc=0.994, train_f1=0.992 | val_loss=2.8661, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 250 | train_loss=0.0254, train_acc=0.983, train_f1=0.985 | val_loss=3.0318, val_acc=0.650, val_f1=0.558
# [seed 246] epoch 251 | train_loss=0.0535, train_acc=0.978, train_f1=0.978 | val_loss=3.1509, val_acc=0.600, val_f1=0.455
# [seed 246] epoch 252 | train_loss=0.0361, train_acc=0.983, train_f1=0.983 | val_loss=3.1303, val_acc=0.600, val_f1=0.455
# [seed 246] epoch 253 | train_loss=0.0796, train_acc=0.983, train_f1=0.980 | val_loss=2.8630, val_acc=0.600, val_f1=0.455
# [seed 246] epoch 254 | train_loss=0.0141, train_acc=0.994, train_f1=0.996 | val_loss=3.0630, val_acc=0.550, val_f1=0.418
# [seed 246] epoch 255 | train_loss=0.0213, train_acc=0.994, train_f1=0.993 | val_loss=3.1120, val_acc=0.550, val_f1=0.428
# [seed 246] epoch 256 | train_loss=0.0182, train_acc=1.000, train_f1=1.000 | val_loss=3.1501, val_acc=0.550, val_f1=0.428
# [seed 246] epoch 257 | train_loss=0.0453, train_acc=0.972, train_f1=0.975 | val_loss=3.0377, val_acc=0.550, val_f1=0.415
# [seed 246] epoch 258 | train_loss=0.0200, train_acc=0.994, train_f1=0.992 | val_loss=2.9449, val_acc=0.550, val_f1=0.415
# [seed 246] epoch 259 | train_loss=0.0416, train_acc=0.989, train_f1=0.987 | val_loss=2.9957, val_acc=0.550, val_f1=0.415
# [seed 246] epoch 260 | train_loss=0.0243, train_acc=0.994, train_f1=0.994 | val_loss=3.1346, val_acc=0.550, val_f1=0.415
# [seed 246] epoch 261 | train_loss=0.0210, train_acc=0.994, train_f1=0.994 | val_loss=3.1839, val_acc=0.550, val_f1=0.415
# [seed 246] epoch 262 | train_loss=0.0106, train_acc=1.000, train_f1=1.000 | val_loss=3.1355, val_acc=0.550, val_f1=0.415
# [seed 246] epoch 263 | train_loss=0.0219, train_acc=0.994, train_f1=0.993 | val_loss=2.9818, val_acc=0.550, val_f1=0.415
# [seed 246] epoch 264 | train_loss=0.0880, train_acc=0.983, train_f1=0.982 | val_loss=2.9078, val_acc=0.600, val_f1=0.488
# [seed 246] epoch 265 | train_loss=0.0314, train_acc=0.989, train_f1=0.989 | val_loss=2.8818, val_acc=0.600, val_f1=0.488
# [seed 246] epoch 266 | train_loss=0.0981, train_acc=0.967, train_f1=0.960 | val_loss=2.9775, val_acc=0.600, val_f1=0.488
# [seed 246] epoch 267 | train_loss=0.0292, train_acc=0.994, train_f1=0.996 | val_loss=3.0135, val_acc=0.550, val_f1=0.415
# [seed 246] epoch 268 | train_loss=0.0198, train_acc=1.000, train_f1=1.000 | val_loss=2.8553, val_acc=0.600, val_f1=0.488
# [seed 246] epoch 269 | train_loss=0.0166, train_acc=0.994, train_f1=0.992 | val_loss=2.9461, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 270 | train_loss=0.0523, train_acc=0.972, train_f1=0.968 | val_loss=3.1275, val_acc=0.650, val_f1=0.527
# [seed 246] epoch 271 | train_loss=0.0248, train_acc=0.989, train_f1=0.988 | val_loss=3.2495, val_acc=0.600, val_f1=0.470
# [seed 246] epoch 272 | train_loss=0.0528, train_acc=0.983, train_f1=0.982 | val_loss=3.1514, val_acc=0.600, val_f1=0.470
# [seed 246] epoch 273 | train_loss=0.0808, train_acc=0.983, train_f1=0.987 | val_loss=2.9425, val_acc=0.600, val_f1=0.470
# [seed 246] epoch 274 | train_loss=0.0247, train_acc=0.989, train_f1=0.991 | val_loss=2.7467, val_acc=0.600, val_f1=0.455
# [seed 246] Early stopping at epoch 274
#
# === Training model 2/12 (seed=247) ===
# [seed 247] epoch 01 | train_loss=2.3557, train_acc=0.178, train_f1=0.155 | val_loss=2.1481, val_acc=0.300, val_f1=0.219
# [seed 247] epoch 02 | train_loss=2.0099, train_acc=0.300, train_f1=0.296 | val_loss=1.8921, val_acc=0.350, val_f1=0.283
# [seed 247] epoch 03 | train_loss=1.8116, train_acc=0.394, train_f1=0.354 | val_loss=1.6577, val_acc=0.400, val_f1=0.270
# [seed 247] epoch 04 | train_loss=1.6298, train_acc=0.400, train_f1=0.356 | val_loss=1.5415, val_acc=0.500, val_f1=0.448
# [seed 247] epoch 05 | train_loss=1.5426, train_acc=0.433, train_f1=0.408 | val_loss=1.5397, val_acc=0.450, val_f1=0.382
# [seed 247] epoch 06 | train_loss=1.4445, train_acc=0.450, train_f1=0.440 | val_loss=1.5839, val_acc=0.350, val_f1=0.279
# [seed 247] epoch 07 | train_loss=1.3290, train_acc=0.517, train_f1=0.498 | val_loss=1.5763, val_acc=0.350, val_f1=0.279
# [seed 247] epoch 08 | train_loss=1.2805, train_acc=0.517, train_f1=0.507 | val_loss=1.4478, val_acc=0.400, val_f1=0.348
# [seed 247] epoch 09 | train_loss=1.2455, train_acc=0.550, train_f1=0.534 | val_loss=1.3467, val_acc=0.550, val_f1=0.494
# [seed 247] epoch 10 | train_loss=1.0620, train_acc=0.606, train_f1=0.612 | val_loss=1.3331, val_acc=0.600, val_f1=0.530
# [seed 247] epoch 11 | train_loss=1.1325, train_acc=0.522, train_f1=0.518 | val_loss=1.3727, val_acc=0.450, val_f1=0.388
# [seed 247] epoch 12 | train_loss=0.9491, train_acc=0.672, train_f1=0.671 | val_loss=1.4300, val_acc=0.500, val_f1=0.412
# [seed 247] epoch 13 | train_loss=1.0001, train_acc=0.639, train_f1=0.644 | val_loss=1.3650, val_acc=0.500, val_f1=0.448
# [seed 247] epoch 14 | train_loss=0.9526, train_acc=0.661, train_f1=0.659 | val_loss=1.4255, val_acc=0.500, val_f1=0.448
# [seed 247] epoch 15 | train_loss=0.9092, train_acc=0.661, train_f1=0.661 | val_loss=1.3930, val_acc=0.600, val_f1=0.494
# [seed 247] epoch 16 | train_loss=0.9476, train_acc=0.722, train_f1=0.722 | val_loss=1.3926, val_acc=0.750, val_f1=0.675
# [seed 247] epoch 17 | train_loss=0.8927, train_acc=0.667, train_f1=0.668 | val_loss=1.4122, val_acc=0.700, val_f1=0.572
# [seed 247] epoch 18 | train_loss=0.8291, train_acc=0.683, train_f1=0.693 | val_loss=1.4155, val_acc=0.600, val_f1=0.497
# [seed 247] epoch 19 | train_loss=0.7899, train_acc=0.694, train_f1=0.693 | val_loss=1.5312, val_acc=0.500, val_f1=0.415
# [seed 247] epoch 20 | train_loss=0.7677, train_acc=0.683, train_f1=0.712 | val_loss=1.5467, val_acc=0.550, val_f1=0.455
# [seed 247] epoch 21 | train_loss=0.7459, train_acc=0.700, train_f1=0.717 | val_loss=1.4245, val_acc=0.650, val_f1=0.567
# [seed 247] epoch 22 | train_loss=0.8172, train_acc=0.672, train_f1=0.680 | val_loss=1.4585, val_acc=0.650, val_f1=0.555
# [seed 247] epoch 23 | train_loss=0.7305, train_acc=0.733, train_f1=0.744 | val_loss=1.5542, val_acc=0.550, val_f1=0.461
# [seed 247] epoch 24 | train_loss=0.8228, train_acc=0.633, train_f1=0.640 | val_loss=1.4814, val_acc=0.650, val_f1=0.555
# [seed 247] epoch 25 | train_loss=0.7276, train_acc=0.694, train_f1=0.699 | val_loss=1.4061, val_acc=0.700, val_f1=0.658
# [seed 247] epoch 26 | train_loss=0.7081, train_acc=0.700, train_f1=0.717 | val_loss=1.4892, val_acc=0.550, val_f1=0.515
# [seed 247] epoch 27 | train_loss=0.7655, train_acc=0.672, train_f1=0.683 | val_loss=1.5730, val_acc=0.500, val_f1=0.424
# [seed 247] epoch 28 | train_loss=0.6769, train_acc=0.744, train_f1=0.753 | val_loss=1.6079, val_acc=0.550, val_f1=0.442
# [seed 247] epoch 29 | train_loss=0.6123, train_acc=0.761, train_f1=0.765 | val_loss=1.6533, val_acc=0.650, val_f1=0.545
# [seed 247] epoch 30 | train_loss=0.7108, train_acc=0.733, train_f1=0.737 | val_loss=1.6138, val_acc=0.650, val_f1=0.545
# [seed 247] epoch 31 | train_loss=0.7141, train_acc=0.717, train_f1=0.723 | val_loss=1.6637, val_acc=0.650, val_f1=0.545
# [seed 247] epoch 32 | train_loss=0.7230, train_acc=0.717, train_f1=0.714 | val_loss=1.6826, val_acc=0.600, val_f1=0.487
# [seed 247] epoch 33 | train_loss=0.6178, train_acc=0.739, train_f1=0.761 | val_loss=1.7762, val_acc=0.550, val_f1=0.453
# [seed 247] epoch 34 | train_loss=0.6189, train_acc=0.761, train_f1=0.772 | val_loss=1.8211, val_acc=0.550, val_f1=0.453
# [seed 247] epoch 35 | train_loss=0.6149, train_acc=0.806, train_f1=0.799 | val_loss=1.7201, val_acc=0.600, val_f1=0.508
# [seed 247] epoch 36 | train_loss=0.6635, train_acc=0.772, train_f1=0.790 | val_loss=1.5866, val_acc=0.750, val_f1=0.709
# [seed 247] epoch 37 | train_loss=0.6852, train_acc=0.739, train_f1=0.741 | val_loss=1.5816, val_acc=0.700, val_f1=0.639
# [seed 247] epoch 38 | train_loss=0.5334, train_acc=0.783, train_f1=0.792 | val_loss=1.5395, val_acc=0.700, val_f1=0.635
# [seed 247] epoch 39 | train_loss=0.5018, train_acc=0.833, train_f1=0.845 | val_loss=1.5636, val_acc=0.700, val_f1=0.635
# [seed 247] epoch 40 | train_loss=0.5331, train_acc=0.822, train_f1=0.825 | val_loss=1.6679, val_acc=0.600, val_f1=0.561
# [seed 247] epoch 41 | train_loss=0.5133, train_acc=0.811, train_f1=0.815 | val_loss=1.6554, val_acc=0.550, val_f1=0.470
# [seed 247] epoch 42 | train_loss=0.4644, train_acc=0.800, train_f1=0.807 | val_loss=1.5597, val_acc=0.550, val_f1=0.470
# [seed 247] epoch 43 | train_loss=0.5251, train_acc=0.822, train_f1=0.827 | val_loss=1.4571, val_acc=0.600, val_f1=0.561
# [seed 247] epoch 44 | train_loss=0.5973, train_acc=0.739, train_f1=0.747 | val_loss=1.4734, val_acc=0.600, val_f1=0.561
# [seed 247] epoch 45 | train_loss=0.5331, train_acc=0.806, train_f1=0.811 | val_loss=1.5175, val_acc=0.550, val_f1=0.453
# [seed 247] epoch 46 | train_loss=0.4243, train_acc=0.822, train_f1=0.831 | val_loss=1.5175, val_acc=0.600, val_f1=0.508
# [seed 247] epoch 47 | train_loss=0.4284, train_acc=0.833, train_f1=0.851 | val_loss=1.5748, val_acc=0.650, val_f1=0.535
# [seed 247] epoch 48 | train_loss=0.6048, train_acc=0.794, train_f1=0.795 | val_loss=1.6907, val_acc=0.700, val_f1=0.635
# [seed 247] epoch 49 | train_loss=0.4578, train_acc=0.828, train_f1=0.833 | val_loss=1.8499, val_acc=0.600, val_f1=0.487
# [seed 247] epoch 50 | train_loss=0.5615, train_acc=0.806, train_f1=0.806 | val_loss=1.8042, val_acc=0.600, val_f1=0.487
# [seed 247] epoch 51 | train_loss=0.4440, train_acc=0.844, train_f1=0.848 | val_loss=1.7270, val_acc=0.650, val_f1=0.633
# [seed 247] epoch 52 | train_loss=0.4511, train_acc=0.833, train_f1=0.828 | val_loss=1.7262, val_acc=0.650, val_f1=0.552
# [seed 247] epoch 53 | train_loss=0.4449, train_acc=0.817, train_f1=0.819 | val_loss=1.7377, val_acc=0.650, val_f1=0.552
# [seed 247] epoch 54 | train_loss=0.4736, train_acc=0.789, train_f1=0.801 | val_loss=1.5972, val_acc=0.650, val_f1=0.545
# [seed 247] epoch 55 | train_loss=0.5589, train_acc=0.828, train_f1=0.833 | val_loss=1.7201, val_acc=0.600, val_f1=0.518
# [seed 247] epoch 56 | train_loss=0.5248, train_acc=0.789, train_f1=0.805 | val_loss=1.7849, val_acc=0.550, val_f1=0.470
# [seed 247] epoch 57 | train_loss=0.4642, train_acc=0.828, train_f1=0.825 | val_loss=1.7674, val_acc=0.550, val_f1=0.470
# [seed 247] epoch 58 | train_loss=0.4254, train_acc=0.850, train_f1=0.843 | val_loss=1.7240, val_acc=0.550, val_f1=0.470
# [seed 247] epoch 59 | train_loss=0.4275, train_acc=0.811, train_f1=0.821 | val_loss=1.6909, val_acc=0.600, val_f1=0.487
# [seed 247] epoch 60 | train_loss=0.4431, train_acc=0.833, train_f1=0.843 | val_loss=1.6756, val_acc=0.700, val_f1=0.617
# [seed 247] epoch 61 | train_loss=0.4748, train_acc=0.794, train_f1=0.794 | val_loss=1.8169, val_acc=0.600, val_f1=0.478
# [seed 247] epoch 62 | train_loss=0.4037, train_acc=0.883, train_f1=0.880 | val_loss=1.8582, val_acc=0.600, val_f1=0.487
# [seed 247] epoch 63 | train_loss=0.3871, train_acc=0.856, train_f1=0.876 | val_loss=1.7777, val_acc=0.600, val_f1=0.478
# [seed 247] epoch 64 | train_loss=0.5029, train_acc=0.856, train_f1=0.856 | val_loss=1.7708, val_acc=0.550, val_f1=0.461
# [seed 247] epoch 65 | train_loss=0.4303, train_acc=0.828, train_f1=0.850 | val_loss=1.7783, val_acc=0.550, val_f1=0.470
# [seed 247] epoch 66 | train_loss=0.3735, train_acc=0.894, train_f1=0.893 | val_loss=1.6926, val_acc=0.600, val_f1=0.502
# [seed 247] epoch 67 | train_loss=0.4819, train_acc=0.811, train_f1=0.822 | val_loss=1.6134, val_acc=0.650, val_f1=0.563
# [seed 247] epoch 68 | train_loss=0.3766, train_acc=0.850, train_f1=0.853 | val_loss=1.5959, val_acc=0.600, val_f1=0.472
# [seed 247] epoch 69 | train_loss=0.4534, train_acc=0.839, train_f1=0.841 | val_loss=1.4379, val_acc=0.650, val_f1=0.545
# [seed 247] epoch 70 | train_loss=0.4027, train_acc=0.867, train_f1=0.858 | val_loss=1.2234, val_acc=0.750, val_f1=0.709
# [seed 247] epoch 71 | train_loss=0.3394, train_acc=0.900, train_f1=0.902 | val_loss=1.2157, val_acc=0.700, val_f1=0.609
# [seed 247] epoch 72 | train_loss=0.4409, train_acc=0.817, train_f1=0.810 | val_loss=1.2813, val_acc=0.600, val_f1=0.472
# [seed 247] epoch 73 | train_loss=0.4541, train_acc=0.828, train_f1=0.827 | val_loss=1.5391, val_acc=0.650, val_f1=0.526
# [seed 247] epoch 74 | train_loss=0.4613, train_acc=0.822, train_f1=0.825 | val_loss=1.5895, val_acc=0.650, val_f1=0.526
# [seed 247] epoch 75 | train_loss=0.3771, train_acc=0.839, train_f1=0.854 | val_loss=1.3427, val_acc=0.650, val_f1=0.526
# [seed 247] epoch 76 | train_loss=0.4202, train_acc=0.850, train_f1=0.849 | val_loss=1.3522, val_acc=0.650, val_f1=0.578
# [seed 247] epoch 77 | train_loss=0.3252, train_acc=0.911, train_f1=0.923 | val_loss=1.3416, val_acc=0.650, val_f1=0.578
# [seed 247] epoch 78 | train_loss=0.3407, train_acc=0.850, train_f1=0.853 | val_loss=1.4545, val_acc=0.750, val_f1=0.709
# [seed 247] epoch 79 | train_loss=0.3218, train_acc=0.844, train_f1=0.858 | val_loss=1.7070, val_acc=0.700, val_f1=0.635
# [seed 247] epoch 80 | train_loss=0.4248, train_acc=0.867, train_f1=0.861 | val_loss=1.9165, val_acc=0.700, val_f1=0.620
# [seed 247] epoch 81 | train_loss=0.3486, train_acc=0.850, train_f1=0.845 | val_loss=2.0820, val_acc=0.600, val_f1=0.472
# [seed 247] epoch 82 | train_loss=0.3790, train_acc=0.872, train_f1=0.866 | val_loss=1.9820, val_acc=0.600, val_f1=0.487
# [seed 247] epoch 83 | train_loss=0.4307, train_acc=0.800, train_f1=0.807 | val_loss=1.7061, val_acc=0.600, val_f1=0.512
# [seed 247] epoch 84 | train_loss=0.3052, train_acc=0.872, train_f1=0.887 | val_loss=1.6922, val_acc=0.600, val_f1=0.518
# [seed 247] epoch 85 | train_loss=0.3443, train_acc=0.878, train_f1=0.886 | val_loss=1.8155, val_acc=0.500, val_f1=0.437
# [seed 247] epoch 86 | train_loss=0.3767, train_acc=0.878, train_f1=0.868 | val_loss=1.8909, val_acc=0.550, val_f1=0.453
# [seed 247] epoch 87 | train_loss=0.3418, train_acc=0.889, train_f1=0.897 | val_loss=1.7877, val_acc=0.600, val_f1=0.469
# [seed 247] epoch 88 | train_loss=0.3585, train_acc=0.844, train_f1=0.851 | val_loss=1.5072, val_acc=0.750, val_f1=0.661
# [seed 247] epoch 89 | train_loss=0.3040, train_acc=0.861, train_f1=0.879 | val_loss=1.3483, val_acc=0.700, val_f1=0.618
# [seed 247] epoch 90 | train_loss=0.3065, train_acc=0.889, train_f1=0.900 | val_loss=1.4621, val_acc=0.650, val_f1=0.560
# [seed 247] epoch 91 | train_loss=0.3147, train_acc=0.872, train_f1=0.886 | val_loss=1.6249, val_acc=0.650, val_f1=0.545
# [seed 247] epoch 92 | train_loss=0.3350, train_acc=0.839, train_f1=0.851 | val_loss=1.7982, val_acc=0.650, val_f1=0.529
# [seed 247] epoch 93 | train_loss=0.2653, train_acc=0.911, train_f1=0.910 | val_loss=1.8028, val_acc=0.600, val_f1=0.487
# [seed 247] epoch 94 | train_loss=0.3680, train_acc=0.861, train_f1=0.863 | val_loss=1.8116, val_acc=0.600, val_f1=0.487
# [seed 247] epoch 95 | train_loss=0.3564, train_acc=0.861, train_f1=0.872 | val_loss=1.7653, val_acc=0.700, val_f1=0.652
# [seed 247] epoch 96 | train_loss=0.4003, train_acc=0.833, train_f1=0.835 | val_loss=1.7704, val_acc=0.700, val_f1=0.620
# [seed 247] epoch 97 | train_loss=0.4177, train_acc=0.839, train_f1=0.840 | val_loss=1.7586, val_acc=0.700, val_f1=0.605
# [seed 247] epoch 98 | train_loss=0.3753, train_acc=0.889, train_f1=0.889 | val_loss=1.6478, val_acc=0.600, val_f1=0.490
# [seed 247] epoch 99 | train_loss=0.3141, train_acc=0.878, train_f1=0.872 | val_loss=1.6110, val_acc=0.650, val_f1=0.583
# [seed 247] epoch 100 | train_loss=0.4109, train_acc=0.839, train_f1=0.844 | val_loss=1.5792, val_acc=0.650, val_f1=0.621
# [seed 247] epoch 101 | train_loss=0.3655, train_acc=0.872, train_f1=0.871 | val_loss=1.5358, val_acc=0.700, val_f1=0.667
# [seed 247] epoch 102 | train_loss=0.3046, train_acc=0.861, train_f1=0.849 | val_loss=1.5471, val_acc=0.700, val_f1=0.652
# [seed 247] epoch 103 | train_loss=0.3390, train_acc=0.861, train_f1=0.873 | val_loss=1.6003, val_acc=0.700, val_f1=0.652
# [seed 247] epoch 104 | train_loss=0.4346, train_acc=0.844, train_f1=0.832 | val_loss=1.7254, val_acc=0.650, val_f1=0.578
# [seed 247] epoch 105 | train_loss=0.2867, train_acc=0.889, train_f1=0.892 | val_loss=1.7147, val_acc=0.650, val_f1=0.578
# [seed 247] epoch 106 | train_loss=0.2602, train_acc=0.900, train_f1=0.898 | val_loss=1.7787, val_acc=0.650, val_f1=0.578
# [seed 247] epoch 107 | train_loss=0.2808, train_acc=0.911, train_f1=0.911 | val_loss=1.6705, val_acc=0.650, val_f1=0.578
# [seed 247] epoch 108 | train_loss=0.3703, train_acc=0.839, train_f1=0.838 | val_loss=1.5283, val_acc=0.700, val_f1=0.652
# [seed 247] epoch 109 | train_loss=0.2623, train_acc=0.922, train_f1=0.929 | val_loss=1.3723, val_acc=0.700, val_f1=0.603
# [seed 247] epoch 110 | train_loss=0.3048, train_acc=0.844, train_f1=0.858 | val_loss=1.4986, val_acc=0.650, val_f1=0.545
# [seed 247] epoch 111 | train_loss=0.2870, train_acc=0.894, train_f1=0.907 | val_loss=1.4557, val_acc=0.700, val_f1=0.605
# [seed 247] epoch 112 | train_loss=0.2850, train_acc=0.917, train_f1=0.922 | val_loss=1.4325, val_acc=0.700, val_f1=0.605
# [seed 247] epoch 113 | train_loss=0.3688, train_acc=0.861, train_f1=0.861 | val_loss=1.2482, val_acc=0.750, val_f1=0.691
# [seed 247] epoch 114 | train_loss=0.3072, train_acc=0.889, train_f1=0.891 | val_loss=1.4602, val_acc=0.650, val_f1=0.570
# [seed 247] epoch 115 | train_loss=0.3556, train_acc=0.828, train_f1=0.829 | val_loss=1.5752, val_acc=0.650, val_f1=0.567
# [seed 247] epoch 116 | train_loss=0.2637, train_acc=0.894, train_f1=0.901 | val_loss=1.7181, val_acc=0.700, val_f1=0.602
# [seed 247] epoch 117 | train_loss=0.2853, train_acc=0.900, train_f1=0.906 | val_loss=1.9483, val_acc=0.700, val_f1=0.584
# [seed 247] epoch 118 | train_loss=0.2360, train_acc=0.911, train_f1=0.914 | val_loss=2.0821, val_acc=0.700, val_f1=0.584
# [seed 247] epoch 119 | train_loss=0.3167, train_acc=0.878, train_f1=0.893 | val_loss=1.9425, val_acc=0.750, val_f1=0.675
# [seed 247] epoch 120 | train_loss=0.2670, train_acc=0.911, train_f1=0.916 | val_loss=1.6624, val_acc=0.700, val_f1=0.635
# [seed 247] epoch 121 | train_loss=0.3583, train_acc=0.894, train_f1=0.883 | val_loss=1.4824, val_acc=0.700, val_f1=0.635
# [seed 247] epoch 122 | train_loss=0.3775, train_acc=0.844, train_f1=0.846 | val_loss=1.5894, val_acc=0.700, val_f1=0.584
# [seed 247] epoch 123 | train_loss=0.2298, train_acc=0.917, train_f1=0.922 | val_loss=1.6825, val_acc=0.750, val_f1=0.642
# ...
# [seed 257] epoch 344 | train_loss=0.0294, train_acc=0.994, train_f1=0.991 | val_loss=2.3751, val_acc=0.600, val_f1=0.564
# [seed 257] epoch 345 | train_loss=0.0114, train_acc=1.000, train_f1=1.000 | val_loss=2.3818, val_acc=0.600, val_f1=0.564
# [seed 257] epoch 346 | train_loss=0.0094, train_acc=1.000, train_f1=1.000 | val_loss=2.4598, val_acc=0.550, val_f1=0.473
# [seed 257] epoch 347 | train_loss=0.0364, train_acc=0.989, train_f1=0.984 | val_loss=2.4436, val_acc=0.550, val_f1=0.473
# [seed 257] epoch 348 | train_loss=0.0131, train_acc=1.000, train_f1=1.000 | val_loss=2.1876, val_acc=0.550, val_f1=0.473
# [seed 257] epoch 349 | train_loss=0.0102, train_acc=1.000, train_f1=1.000 | val_loss=2.2685, val_acc=0.550, val_f1=0.506
# [seed 257] epoch 350 | train_loss=0.0224, train_acc=0.994, train_f1=0.992 | val_loss=2.3528, val_acc=0.500, val_f1=0.461
# [seed 257] epoch 351 | train_loss=0.0141, train_acc=0.994, train_f1=0.994 | val_loss=2.5542, val_acc=0.450, val_f1=0.400
# [seed 257] epoch 352 | train_loss=0.0185, train_acc=0.994, train_f1=0.996 | val_loss=2.6240, val_acc=0.500, val_f1=0.430
# [seed 257] epoch 353 | train_loss=0.0089, train_acc=1.000, train_f1=1.000 | val_loss=2.5957, val_acc=0.550, val_f1=0.473
# [seed 257] epoch 354 | train_loss=0.0107, train_acc=1.000, train_f1=1.000 | val_loss=2.5946, val_acc=0.550, val_f1=0.473
# [seed 257] epoch 355 | train_loss=0.0102, train_acc=0.994, train_f1=0.996 | val_loss=2.5291, val_acc=0.550, val_f1=0.473
# [seed 257] epoch 356 | train_loss=0.0035, train_acc=1.000, train_f1=1.000 | val_loss=2.4398, val_acc=0.550, val_f1=0.473
# [seed 257] epoch 357 | train_loss=0.0043, train_acc=1.000, train_f1=1.000 | val_loss=2.3505, val_acc=0.600, val_f1=0.564
# [seed 257] epoch 358 | train_loss=0.0053, train_acc=1.000, train_f1=1.000 | val_loss=2.3179, val_acc=0.600, val_f1=0.564
# [seed 257] epoch 359 | train_loss=0.0087, train_acc=1.000, train_f1=1.000 | val_loss=2.3260, val_acc=0.500, val_f1=0.461
# [seed 257] epoch 360 | train_loss=0.0078, train_acc=0.994, train_f1=0.995 | val_loss=2.3327, val_acc=0.500, val_f1=0.461
# [seed 257] epoch 361 | train_loss=0.0062, train_acc=1.000, train_f1=1.000 | val_loss=2.3351, val_acc=0.500, val_f1=0.461
# [seed 257] epoch 362 | train_loss=0.0061, train_acc=1.000, train_f1=1.000 | val_loss=2.3522, val_acc=0.550, val_f1=0.506
# [seed 257] epoch 363 | train_loss=0.0100, train_acc=0.994, train_f1=0.996 | val_loss=2.3584, val_acc=0.550, val_f1=0.506
# [seed 257] epoch 364 | train_loss=0.0036, train_acc=1.000, train_f1=1.000 | val_loss=2.3764, val_acc=0.600, val_f1=0.564
# [seed 257] epoch 365 | train_loss=0.0138, train_acc=0.994, train_f1=0.992 | val_loss=2.4078, val_acc=0.600, val_f1=0.564
# [seed 257] epoch 366 | train_loss=0.0119, train_acc=0.994, train_f1=0.996 | val_loss=2.5274, val_acc=0.650, val_f1=0.600
# [seed 257] epoch 367 | train_loss=0.0204, train_acc=0.994, train_f1=0.993 | val_loss=2.5163, val_acc=0.600, val_f1=0.546
# [seed 257] epoch 368 | train_loss=0.0107, train_acc=1.000, train_f1=1.000 | val_loss=2.1883, val_acc=0.600, val_f1=0.546
# [seed 257] epoch 369 | train_loss=0.0175, train_acc=0.994, train_f1=0.996 | val_loss=2.0496, val_acc=0.600, val_f1=0.546
# [seed 257] epoch 370 | train_loss=0.0076, train_acc=1.000, train_f1=1.000 | val_loss=1.8756, val_acc=0.550, val_f1=0.510
# [seed 257] epoch 371 | train_loss=0.0128, train_acc=1.000, train_f1=1.000 | val_loss=1.7673, val_acc=0.600, val_f1=0.570
# [seed 257] epoch 372 | train_loss=0.0103, train_acc=1.000, train_f1=1.000 | val_loss=1.7579, val_acc=0.600, val_f1=0.570
# [seed 257] epoch 373 | train_loss=0.0037, train_acc=1.000, train_f1=1.000 | val_loss=1.8211, val_acc=0.600, val_f1=0.570
# [seed 257] epoch 374 | train_loss=0.0125, train_acc=0.994, train_f1=0.997 | val_loss=1.8362, val_acc=0.550, val_f1=0.506
# [seed 257] epoch 375 | train_loss=0.0060, train_acc=1.000, train_f1=1.000 | val_loss=1.9190, val_acc=0.550, val_f1=0.506
# [seed 257] epoch 376 | train_loss=0.0250, train_acc=0.989, train_f1=0.991 | val_loss=1.9879, val_acc=0.600, val_f1=0.564
# [seed 257] epoch 377 | train_loss=0.0150, train_acc=0.989, train_f1=0.992 | val_loss=2.0080, val_acc=0.600, val_f1=0.564
# [seed 257] epoch 378 | train_loss=0.0170, train_acc=0.989, train_f1=0.992 | val_loss=1.9355, val_acc=0.550, val_f1=0.491
# [seed 257] epoch 379 | train_loss=0.0122, train_acc=1.000, train_f1=1.000 | val_loss=1.9233, val_acc=0.600, val_f1=0.527
# [seed 257] epoch 380 | train_loss=0.0080, train_acc=1.000, train_f1=1.000 | val_loss=1.8339, val_acc=0.600, val_f1=0.542
# [seed 257] epoch 381 | train_loss=0.0085, train_acc=1.000, train_f1=1.000 | val_loss=1.8189, val_acc=0.700, val_f1=0.630
# [seed 257] epoch 382 | train_loss=0.0108, train_acc=1.000, train_f1=1.000 | val_loss=1.8861, val_acc=0.650, val_f1=0.600
# [seed 257] epoch 383 | train_loss=0.0095, train_acc=1.000, train_f1=1.000 | val_loss=1.9312, val_acc=0.650, val_f1=0.600
# [seed 257] epoch 384 | train_loss=0.0125, train_acc=0.994, train_f1=0.996 | val_loss=1.9921, val_acc=0.600, val_f1=0.546
# [seed 257] epoch 385 | train_loss=0.0039, train_acc=1.000, train_f1=1.000 | val_loss=2.0912, val_acc=0.600, val_f1=0.539
# [seed 257] epoch 386 | train_loss=0.0068, train_acc=1.000, train_f1=1.000 | val_loss=2.1529, val_acc=0.600, val_f1=0.539
# [seed 257] epoch 387 | train_loss=0.0035, train_acc=1.000, train_f1=1.000 | val_loss=2.1266, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 388 | train_loss=0.0027, train_acc=1.000, train_f1=1.000 | val_loss=2.1386, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 389 | train_loss=0.0051, train_acc=1.000, train_f1=1.000 | val_loss=2.1553, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 390 | train_loss=0.0063, train_acc=1.000, train_f1=1.000 | val_loss=2.1243, val_acc=0.500, val_f1=0.412
# [seed 257] epoch 391 | train_loss=0.0036, train_acc=1.000, train_f1=1.000 | val_loss=2.1527, val_acc=0.500, val_f1=0.412
# [seed 257] epoch 392 | train_loss=0.0127, train_acc=0.994, train_f1=0.996 | val_loss=2.1233, val_acc=0.500, val_f1=0.412
# [seed 257] epoch 393 | train_loss=0.0108, train_acc=0.994, train_f1=0.994 | val_loss=2.2586, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 394 | train_loss=0.0081, train_acc=1.000, train_f1=1.000 | val_loss=2.3816, val_acc=0.500, val_f1=0.424
# [seed 257] epoch 395 | train_loss=0.0094, train_acc=0.994, train_f1=0.996 | val_loss=2.3565, val_acc=0.450, val_f1=0.355
# [seed 257] epoch 396 | train_loss=0.0095, train_acc=1.000, train_f1=1.000 | val_loss=2.3121, val_acc=0.450, val_f1=0.355
# [seed 257] epoch 397 | train_loss=0.0217, train_acc=0.994, train_f1=0.994 | val_loss=2.3331, val_acc=0.500, val_f1=0.424
# [seed 257] epoch 398 | train_loss=0.0084, train_acc=1.000, train_f1=1.000 | val_loss=2.3389, val_acc=0.500, val_f1=0.424
# [seed 257] epoch 399 | train_loss=0.0072, train_acc=1.000, train_f1=1.000 | val_loss=2.2812, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 400 | train_loss=0.0040, train_acc=1.000, train_f1=1.000 | val_loss=2.3653, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 401 | train_loss=0.0046, train_acc=1.000, train_f1=1.000 | val_loss=2.4065, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 402 | train_loss=0.0028, train_acc=1.000, train_f1=1.000 | val_loss=2.3843, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 403 | train_loss=0.0057, train_acc=1.000, train_f1=1.000 | val_loss=2.3227, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 404 | train_loss=0.0127, train_acc=0.994, train_f1=0.995 | val_loss=2.2160, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 405 | train_loss=0.0048, train_acc=1.000, train_f1=1.000 | val_loss=2.1546, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 406 | train_loss=0.0018, train_acc=1.000, train_f1=1.000 | val_loss=2.1068, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 407 | train_loss=0.0018, train_acc=1.000, train_f1=1.000 | val_loss=2.0967, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 408 | train_loss=0.0044, train_acc=1.000, train_f1=1.000 | val_loss=2.0939, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 409 | train_loss=0.0074, train_acc=0.994, train_f1=0.993 | val_loss=1.9801, val_acc=0.550, val_f1=0.442
# [seed 257] epoch 410 | train_loss=0.0031, train_acc=1.000, train_f1=1.000 | val_loss=1.9342, val_acc=0.550, val_f1=0.442
# [seed 257] epoch 411 | train_loss=0.0104, train_acc=0.994, train_f1=0.994 | val_loss=1.9777, val_acc=0.650, val_f1=0.570
# [seed 257] epoch 412 | train_loss=0.0076, train_acc=0.994, train_f1=0.994 | val_loss=2.1948, val_acc=0.650, val_f1=0.539
# [seed 257] epoch 413 | train_loss=0.0156, train_acc=0.994, train_f1=0.994 | val_loss=1.8915, val_acc=0.650, val_f1=0.558
# [seed 257] epoch 414 | train_loss=0.0031, train_acc=1.000, train_f1=1.000 | val_loss=1.7887, val_acc=0.650, val_f1=0.558
# [seed 257] epoch 415 | train_loss=0.0037, train_acc=1.000, train_f1=1.000 | val_loss=1.7731, val_acc=0.650, val_f1=0.558
# [seed 257] epoch 416 | train_loss=0.0084, train_acc=0.994, train_f1=0.996 | val_loss=1.7353, val_acc=0.650, val_f1=0.558
# [seed 257] epoch 417 | train_loss=0.0112, train_acc=1.000, train_f1=1.000 | val_loss=1.8059, val_acc=0.600, val_f1=0.527
# [seed 257] epoch 418 | train_loss=0.0043, train_acc=1.000, train_f1=1.000 | val_loss=1.8663, val_acc=0.600, val_f1=0.527
# [seed 257] epoch 419 | train_loss=0.0038, train_acc=1.000, train_f1=1.000 | val_loss=1.8776, val_acc=0.650, val_f1=0.600
# [seed 257] epoch 420 | train_loss=0.0050, train_acc=1.000, train_f1=1.000 | val_loss=1.8514, val_acc=0.650, val_f1=0.600
# [seed 257] epoch 421 | train_loss=0.0068, train_acc=1.000, train_f1=1.000 | val_loss=1.8100, val_acc=0.650, val_f1=0.600
# [seed 257] epoch 422 | train_loss=0.0076, train_acc=1.000, train_f1=1.000 | val_loss=1.8856, val_acc=0.650, val_f1=0.600
# [seed 257] epoch 423 | train_loss=0.0030, train_acc=1.000, train_f1=1.000 | val_loss=1.9691, val_acc=0.600, val_f1=0.527
# [seed 257] epoch 424 | train_loss=0.0032, train_acc=1.000, train_f1=1.000 | val_loss=1.9930, val_acc=0.650, val_f1=0.600
# [seed 257] epoch 425 | train_loss=0.0032, train_acc=1.000, train_f1=1.000 | val_loss=2.0379, val_acc=0.600, val_f1=0.542
# [seed 257] epoch 426 | train_loss=0.0041, train_acc=1.000, train_f1=1.000 | val_loss=2.0734, val_acc=0.550, val_f1=0.473
# [seed 257] epoch 427 | train_loss=0.0046, train_acc=1.000, train_f1=1.000 | val_loss=2.1421, val_acc=0.550, val_f1=0.470
# [seed 257] epoch 428 | train_loss=0.0038, train_acc=1.000, train_f1=1.000 | val_loss=2.1522, val_acc=0.550, val_f1=0.470
# [seed 257] epoch 429 | train_loss=0.0046, train_acc=1.000, train_f1=1.000 | val_loss=2.1839, val_acc=0.550, val_f1=0.470
# [seed 257] epoch 430 | train_loss=0.0092, train_acc=1.000, train_f1=1.000 | val_loss=2.0976, val_acc=0.550, val_f1=0.470
# [seed 257] epoch 431 | train_loss=0.0020, train_acc=1.000, train_f1=1.000 | val_loss=2.0426, val_acc=0.550, val_f1=0.470
# [seed 257] epoch 432 | train_loss=0.0027, train_acc=1.000, train_f1=1.000 | val_loss=2.0250, val_acc=0.600, val_f1=0.527
# [seed 257] epoch 433 | train_loss=0.0046, train_acc=1.000, train_f1=1.000 | val_loss=2.0538, val_acc=0.600, val_f1=0.527
# [seed 257] epoch 434 | train_loss=0.0047, train_acc=1.000, train_f1=1.000 | val_loss=2.0379, val_acc=0.600, val_f1=0.527
# [seed 257] epoch 435 | train_loss=0.0031, train_acc=1.000, train_f1=1.000 | val_loss=2.0752, val_acc=0.600, val_f1=0.539
# [seed 257] epoch 436 | train_loss=0.0036, train_acc=1.000, train_f1=1.000 | val_loss=2.1147, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 437 | train_loss=0.0032, train_acc=1.000, train_f1=1.000 | val_loss=2.1030, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 438 | train_loss=0.0019, train_acc=1.000, train_f1=1.000 | val_loss=2.1417, val_acc=0.500, val_f1=0.409
# [seed 257] epoch 439 | train_loss=0.0201, train_acc=0.994, train_f1=0.995 | val_loss=2.1926, val_acc=0.500, val_f1=0.409
# [seed 257] epoch 440 | train_loss=0.0029, train_acc=1.000, train_f1=1.000 | val_loss=2.4361, val_acc=0.450, val_f1=0.355
# [seed 257] epoch 441 | train_loss=0.0192, train_acc=0.994, train_f1=0.995 | val_loss=2.4452, val_acc=0.500, val_f1=0.412
# [seed 257] epoch 442 | train_loss=0.0071, train_acc=1.000, train_f1=1.000 | val_loss=2.4394, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 443 | train_loss=0.0124, train_acc=0.989, train_f1=0.992 | val_loss=2.4015, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 444 | train_loss=0.0041, train_acc=1.000, train_f1=1.000 | val_loss=2.3889, val_acc=0.600, val_f1=0.539
# [seed 257] epoch 445 | train_loss=0.0159, train_acc=0.994, train_f1=0.996 | val_loss=2.5500, val_acc=0.550, val_f1=0.482
# [seed 257] epoch 446 | train_loss=0.0128, train_acc=0.994, train_f1=0.996 | val_loss=2.5922, val_acc=0.450, val_f1=0.376
# [seed 257] epoch 447 | train_loss=0.0146, train_acc=0.994, train_f1=0.997 | val_loss=2.4420, val_acc=0.550, val_f1=0.491
# [seed 257] epoch 448 | train_loss=0.0141, train_acc=0.994, train_f1=0.997 | val_loss=2.3164, val_acc=0.600, val_f1=0.527
# [seed 257] epoch 449 | train_loss=0.0127, train_acc=1.000, train_f1=1.000 | val_loss=2.2971, val_acc=0.600, val_f1=0.542
# [seed 257] epoch 450 | train_loss=0.0068, train_acc=1.000, train_f1=1.000 | val_loss=2.2865, val_acc=0.600, val_f1=0.542
# [seed 257] epoch 451 | train_loss=0.0049, train_acc=1.000, train_f1=1.000 | val_loss=2.2358, val_acc=0.600, val_f1=0.542
# [seed 257] epoch 452 | train_loss=0.0028, train_acc=1.000, train_f1=1.000 | val_loss=2.2171, val_acc=0.650, val_f1=0.600
# [seed 257] epoch 453 | train_loss=0.0065, train_acc=1.000, train_f1=1.000 | val_loss=2.2193, val_acc=0.600, val_f1=0.539
# [seed 257] epoch 454 | train_loss=0.0076, train_acc=0.994, train_f1=0.996 | val_loss=2.2013, val_acc=0.550, val_f1=0.467
# [seed 257] epoch 455 | train_loss=0.0048, train_acc=1.000, train_f1=1.000 | val_loss=2.2007, val_acc=0.550, val_f1=0.467
# [seed 257] epoch 456 | train_loss=0.0043, train_acc=1.000, train_f1=1.000 | val_loss=2.1934, val_acc=0.550, val_f1=0.467
# [seed 257] epoch 457 | train_loss=0.0085, train_acc=0.994, train_f1=0.997 | val_loss=2.2559, val_acc=0.550, val_f1=0.467
# [seed 257] epoch 458 | train_loss=0.0051, train_acc=1.000, train_f1=1.000 | val_loss=2.2775, val_acc=0.550, val_f1=0.467
# [seed 257] epoch 459 | train_loss=0.0186, train_acc=0.989, train_f1=0.991 | val_loss=2.2930, val_acc=0.550, val_f1=0.467
# [seed 257] epoch 460 | train_loss=0.0039, train_acc=1.000, train_f1=1.000 | val_loss=2.4377, val_acc=0.550, val_f1=0.467
# [seed 257] epoch 461 | train_loss=0.0063, train_acc=1.000, train_f1=1.000 | val_loss=2.4928, val_acc=0.550, val_f1=0.467
# [seed 257] epoch 462 | train_loss=0.0136, train_acc=1.000, train_f1=1.000 | val_loss=2.3899, val_acc=0.500, val_f1=0.403
# [seed 257] epoch 463 | train_loss=0.0119, train_acc=0.994, train_f1=0.996 | val_loss=1.9930, val_acc=0.450, val_f1=0.364
# [seed 257] epoch 464 | train_loss=0.0022, train_acc=1.000, train_f1=1.000 | val_loss=1.8867, val_acc=0.450, val_f1=0.406
# [seed 257] epoch 465 | train_loss=0.0247, train_acc=0.989, train_f1=0.992 | val_loss=1.9075, val_acc=0.550, val_f1=0.506
# [seed 257] epoch 466 | train_loss=0.0060, train_acc=1.000, train_f1=1.000 | val_loss=1.9875, val_acc=0.600, val_f1=0.527
# [seed 257] epoch 467 | train_loss=0.0179, train_acc=0.994, train_f1=0.993 | val_loss=2.0759, val_acc=0.600, val_f1=0.527
# [seed 257] epoch 468 | train_loss=0.0066, train_acc=1.000, train_f1=1.000 | val_loss=2.2124, val_acc=0.600, val_f1=0.527
# [seed 257] epoch 469 | train_loss=0.0162, train_acc=0.994, train_f1=0.995 | val_loss=2.3183, val_acc=0.550, val_f1=0.473
# [seed 257] epoch 470 | train_loss=0.0104, train_acc=0.989, train_f1=0.992 | val_loss=2.5380, val_acc=0.550, val_f1=0.485
# [seed 257] epoch 471 | train_loss=0.0050, train_acc=1.000, train_f1=1.000 | val_loss=2.7778, val_acc=0.550, val_f1=0.457
# [seed 257] epoch 472 | train_loss=0.0153, train_acc=0.994, train_f1=0.995 | val_loss=2.8653, val_acc=0.550, val_f1=0.457
# [seed 257] Early stopping at epoch 472
# Val painter acc of each model: [0.6636363636363636, 0.7848484848484848, 0.6757575757575758, 0.7428571428571428, 0.6658008658008658, 0.6787878787878788, 0.6181818181818182, 0.7181818181818183, 0.6303030303030303, 0.7363636363636363, 0.6484848484848486, 0.706060606060606]
# Mean: 0.689105339105339 Std: 0.04746624879522075

# %% [markdown]
# # Training Visualization

# %%
best_idx = int(np.argmax(scores))
best_history = histories[best_idx]
print("Best model index:", best_idx)
# Out:
# Best model index: 1

# %%
import matplotlib.pyplot as plt

def plot_history_one(history, title_suffix=""):
    epochs = range(1, len(history["train_loss"]) + 1)

    # Loss
    plt.figure(figsize=(6, 4))
    plt.plot(epochs, history["train_loss"], label="Train loss")
    plt.plot(epochs, history["val_loss"],   label="Val loss")
    plt.xlabel("Epoch")
    plt.ylabel("Total loss")
    plt.title(f"Loss (multi-task MLP){title_suffix}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    # Painter accuracy
    plt.figure(figsize=(6, 4))
    plt.plot(epochs, history["train_painter_acc"], label="Train painter acc")
    plt.plot(epochs, history["val_painter_acc"],   label="Val painter acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title(f"Painter accuracy (train vs val){title_suffix}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
plot_history_one(histories[8], title_suffix=" (best model)")

# %% [markdown]
# ups, voy a encontrar mejores parametros

# %% [markdown]
# # Validation

# %%
# painter -> genre (take the most frequent genre per painter to be safe)
painter_to_genre = (
    df.groupby("painter")["genre"]
      .agg(lambda s: s.mode().iloc[0])   # mode handles any accidental duplicates
      .to_dict()
)

# optional: genre -> label (again mode-safe)
genre_to_label = (
    df.groupby("genre")["label"]
      .agg(lambda s: s.mode().iloc[0])
      .to_dict()
)

print(painter_to_genre)
print(genre_to_label)
# Out:
# {'Alfred_Sisley': 'Impresionismo', 'Camille_Pissarro': 'Impresionismo', 'Caravaggio': 'Barroco', 'Claude_Monet': 'Impresionismo', 'Jackson_Pollock': 'Expresionismo abstracto', 'Joan_Miro': 'Surrealismo', 'Pablo_Picasso': 'Cubismo', 'Rembrandt': 'Barroco', 'Rene_Magritte': 'Surrealismo', 'Salvador_Dali': 'Surrealismo', 'Vincent_van_Gogh': 'Impresionismo'}
# {'Barroco': 3, 'Cubismo': 1, 'Expresionismo abstracto': 2, 'Impresionismo': 4, 'Surrealismo': 0}

# %% [markdown]
# ## Bagging Ensemble

# %%
import torch
import numpy as np

@torch.no_grad()
def ensemble_predict(models, X_t, device, return_logits=False):
    # accept numpy input
    if isinstance(X_t, np.ndarray):
        X_t = torch.from_numpy(X_t).float()

    X_t = X_t.to(device)

    p_logits_sum = None

    for model in models:
        model.eval()
        p_logits = model(X_t)
        p_logits_sum = p_logits if p_logits_sum is None else p_logits_sum + p_logits

    # average
    p_logits_mean = p_logits_sum / len(models)
    y_p_pred = p_logits_mean.argmax(dim=1).cpu().numpy()

    if return_logits:
        return y_p_pred, p_logits_mean
    return y_p_pred

# %%
# If needed: recompute painter ensemble preds on val
y_p_true = y_p_val_t.numpy()

y_p_pred_ens = ensemble_predict(models, X_val_t, device)  # painter-only ensemble

# %% [markdown]
# ## Translate to labels

# %%
# painter index -> painter name
p_true_names = [idx_to_painter[i] for i in y_p_true]
p_pred_names = [idx_to_painter[i] for i in y_p_pred_ens]

# painter name -> genre
g_true_names = [painter_to_genre[p] for p in p_true_names]
g_pred_names = [painter_to_genre.get(p, "UNKNOWN") for p in p_pred_names]

g_true_names = np.array(g_true_names)
g_pred_names = np.array(g_pred_names)

print("Genres in eval:", sorted(set(g_true_names) | set(g_pred_names)))
# Out:
# Genres in eval: [np.str_('Barroco'), np.str_('Cubismo'), np.str_('Expresionismo abstracto'), np.str_('Impresionismo'), np.str_('Surrealismo')]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

genre_classes = sorted(df["genre"].unique())  # uses your train df
genre_to_idx = {g:i for i,g in enumerate(genre_classes)}

g_true = np.array([genre_to_idx[g] for g in g_true_names])
g_pred = np.array([genre_to_idx[g] for g in g_pred_names])

cm = confusion_matrix(g_true, g_pred, labels=np.arange(len(genre_classes)))

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=genre_classes)
fig, ax = plt.subplots(figsize=(6,6))
disp.plot(cmap="Blues", xticks_rotation=45, ax=ax, colorbar=False)
plt.title("Confusion matrix (validation) — genres mapped from painters")
plt.tight_layout()
plt.grid(False)
plt.show()

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report, balanced_accuracy_score

acc  = accuracy_score(g_true, g_pred)
bacc = balanced_accuracy_score(g_true, g_pred)
f1_macro = f1_score(g_true, g_pred, average="macro")
f1_weighted = f1_score(g_true, g_pred, average="weighted")

print(f"Genre accuracy        : {acc:.3f}")
print(f"Genre balanced acc    : {bacc:.3f}")
print(f"Genre F1 macro        : {f1_macro:.3f}")
print(f"Genre F1 weighted     : {f1_weighted:.3f}\n")

print("Classification report (genres):")
print(classification_report(g_true, g_pred, target_names=genre_classes, digits=3))
# Out:
# Genre accuracy        : 0.950
# Genre balanced acc    : 0.971
# Genre F1 macro        : 0.956
# Genre F1 weighted     : 0.952
#
# Classification report (genres):
#                          precision    recall  f1-score   support
#
#                 Barroco      0.750     1.000     0.857         3
#                 Cubismo      1.000     1.000     1.000         3
# Expresionismo abstracto      1.000     1.000     1.000         2
#           Impresionismo      1.000     0.857     0.923         7
#             Surrealismo      1.000     1.000     1.000         5
#
#                accuracy                          0.950        20
#               macro avg      0.950     0.971     0.956        20
#            weighted avg      0.963     0.950     0.952        20
