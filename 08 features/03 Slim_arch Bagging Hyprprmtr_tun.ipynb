# %% [markdown]
# # MLP feedforward bagging ensemble
#
# En esta notebook se hace bagging! yupi!

# %%
from pathlib import Path
import random
import math

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
)
from sklearn.utils.class_weight import compute_class_weight

from scripts import style
style.mpl_apply()

import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader

# Reproducibility
SEED = 246
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# # Load the data

# %%
DATA_PATH = Path("09 features/redes_local/datos/processed/df.csv")

df = pd.read_csv(DATA_PATH)
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (200, 57)
#       mean_R      mean_G      mean_B      std_R      std_G      std_B  min_R  \
# 0  102.20103  105.277170  106.873116  32.077003  33.305286  33.510914    0.0
# 1  123.62030  136.959850  149.195050  46.771084  43.979904  49.263435    0.0
# 2  118.90262  116.895996  108.091415  48.649280  52.237015  61.140570    0.0
# 3  133.78065  140.773590  146.314380  36.072636  36.483162  50.136950    4.0
# 4  107.30281  108.520706   92.723560  32.748276  32.094944  37.935650    0.0
#
#    min_G  min_B  max_R  ...  pct_bright_block_2_2    H_shannon  \
# 0    0.0    0.0  186.0  ...              0.195138 -1419.565426
# 1    0.0    0.0  255.0  ...              0.098290 -1419.565426
# 2    0.0    0.0  255.0  ...              0.117654 -1419.489874
# 3    4.0    0.0  255.0  ...              0.018207 -1419.565426
# 4    0.0    0.0  229.0  ...              0.020639 -1419.565426
#
#    center_mean_ratio  center_bright_ratio  lum_centroid_x  lum_centroid_y  \
# 0           1.198618             1.749636        0.486834       -0.154286
# 1           1.061136             0.937835        0.502996       -0.188640
# 2           0.852622             1.311007        0.504956       -0.304950
# 3           1.091522             1.702214        0.500399       -0.215292
# 4           1.132043             2.128325        0.506062       -0.137083
#
#                filename        painter          genre  label
# 0   Alfred_Sisley_1.jpg  Alfred_Sisley  Impresionismo      4
# 1  Alfred_Sisley_10.jpg  Alfred_Sisley  Impresionismo      4
# 2  Alfred_Sisley_11.jpg  Alfred_Sisley  Impresionismo      4
# 3  Alfred_Sisley_12.jpg  Alfred_Sisley  Impresionismo      4
# 4  Alfred_Sisley_13.jpg  Alfred_Sisley  Impresionismo      4
#
# [5 rows x 57 columns]

# %%
# Encode painters
painter_names = sorted(df["painter"].unique())
painter_to_idx = {name: i for i, name in enumerate(painter_names)}
idx_to_painter = {i: name for name, i in painter_to_idx.items()}

df["painter_idx"] = df["painter"].map(painter_to_idx)

NUM_PAINTERS = len(painter_names)

# Labels (movement / genre index)
# Assume df["label"] is already integer-coded per genre
NUM_LABELS = df["label"].nunique()

# Derive genre names per label (sorted by label index)
label_to_genre = (
    df.drop_duplicates("label")
      .sort_values("label")
      .set_index("label")["genre"]
      .to_dict()
)
class_names = [label_to_genre[i] for i in range(NUM_LABELS)]

print("Painters:", painter_names)
print("NUM_PAINTERS:", NUM_PAINTERS)
print("NUM_LABELS:", NUM_LABELS)
print("Labels → genres:", label_to_genre)
# Out:
# Painters: ['Alfred_Sisley', 'Camille_Pissarro', 'Caravaggio', 'Claude_Monet', 'Jackson_Pollock', 'Joan_Miro', 'Pablo_Picasso', 'Rembrandt', 'Rene_Magritte', 'Salvador_Dali', 'Vincent_van_Gogh']
# NUM_PAINTERS: 11
# NUM_LABELS: 5
# Labels → genres: {0: 'Surrealismo', 1: 'Cubismo', 2: 'Expresionismo abstracto', 3: 'Barroco', 4: 'Impresionismo'}

# %%
meta_cols = ["filename", "painter", "genre", "label", "painter_idx"]

feature_cols = [c for c in df.columns if c not in meta_cols]

X = df[feature_cols].to_numpy(dtype=np.float32)
y_painter = df["painter_idx"].to_numpy(dtype=np.int64)
y_label   = df["label"].to_numpy(dtype=np.int64)

print("X shape:", X.shape)
print("y_painter shape:", y_painter.shape)
print("y_label shape:", y_label.shape)
print("Painter counts:", np.bincount(y_painter))
print("Label counts:",   np.bincount(y_label))
# Out:
# X shape: (200, 53)
# y_painter shape: (200,)
# y_label shape: (200,)
# Painter counts: [20 10 10 30 15 20 30 20 10 20 15]
# Label counts: [50 30 15 30 75]

# %% [markdown]
# # Train Set and Validation Set

# %%
# === Cell 4: train / validation split (no test split here) ===

X_train, X_val, y_p_train, y_p_val, y_l_train, y_l_val = train_test_split(
    X,
    y_painter,
    y_label,
    test_size=0.1,           # e.g. 80% train / 20% val
    stratify=y_painter,      # stratify by painter (since painter is first task)
    random_state=SEED,
)

print("Train X:", X_train.shape)
print("Val   X:", X_val.shape)
# Out:
# Train X: (180, 53)
# Val   X: (20, 53)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled   = scaler.transform(X_val)

# %%
BATCH_SIZE = 32

X_train_t = torch.from_numpy(X_train_scaled).float()
y_p_train_t = torch.from_numpy(y_p_train).long()
y_l_train_t = torch.from_numpy(y_l_train).long()

X_val_t = torch.from_numpy(X_val_scaled).float()
y_p_val_t = torch.from_numpy(y_p_val).long()
y_l_val_t = torch.from_numpy(y_l_val).long()

train_ds = TensorDataset(X_train_t, y_p_train_t, y_l_train_t)
val_ds   = TensorDataset(X_val_t,   y_p_val_t,   y_l_val_t)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False)

len(train_loader), len(val_loader)
# Out:
# (6, 1)

# %%
# === Cell 7: class weights for imbalance ===

# Painter weights
painter_class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.arange(NUM_PAINTERS),
    y=y_p_train,
)

# Label weights (genre / movement)
label_class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.arange(NUM_LABELS),
    y=y_l_train,
)

print("Painter class weights:", painter_class_weights)
print("Label   class weights:", label_class_weights)

painter_class_weights_t = torch.tensor(painter_class_weights, dtype=torch.float32, device=device)
label_class_weights_t   = torch.tensor(label_class_weights,   dtype=torch.float32, device=device)
# Out:
# Painter class weights: [0.90909091 1.81818182 1.81818182 0.60606061 1.25874126 0.90909091
#  0.60606061 0.90909091 1.81818182 0.90909091 1.16883117]
# Label   class weights: [0.8        1.33333333 2.76923077 1.33333333 0.52941176]

# %% [markdown]
# # Architectures

# %% [markdown]
# ## MLP

# %%
# === Cell 8: multi-task MLP definition ===

class MultiTaskMLP(nn.Module):
    def __init__(
        self,
        input_dim: int,
        hidden_dims=(128, 64),
        num_painters: int = NUM_PAINTERS,
        num_labels: int = NUM_LABELS,
        dropout_p: float = 0.3,
    ):
        super().__init__()
        layers = []
        prev_dim = input_dim

        for h in hidden_dims:
            layers.append(nn.Linear(prev_dim, h))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(dropout_p))
            prev_dim = h

        self.shared = nn.Sequential(*layers)
        self.painter_head = nn.Linear(prev_dim, num_painters)
        self.label_head   = nn.Linear(prev_dim, num_labels)

    def forward(self, x: torch.Tensor):
        z = self.shared(x)
        painter_logits = self.painter_head(z)
        label_logits   = self.label_head(z)
        return painter_logits, label_logits

# %% [markdown]
# ## MLP Slim More dropout

# %%
import torch
import torch.nn as nn

class MultiTaskMLP_Slim(nn.Module):
    def __init__(
        self,
        input_dim: int,
        num_painters: int,
        num_labels: int,
        bottleneck: int = 16,
        hidden_first: int = 32,
        dropout_p: float = 0.5,
    ):
        super().__init__()

        self.trunk = nn.Sequential(
            nn.Linear(input_dim, hidden_first),
            nn.BatchNorm1d(hidden_first),
            nn.ReLU(),
            nn.Dropout(dropout_p),

            nn.Linear(hidden_first, bottleneck),
            nn.Tanh(),
            nn.Dropout(dropout_p),
        )

        self.painter_head = nn.Linear(bottleneck, num_painters)
        self.label_head   = nn.Linear(bottleneck, num_labels)

    def forward(self, x: torch.Tensor):
        h = self.trunk(x)
        painter_logits = self.painter_head(h)
        label_logits   = self.label_head(h)
        return painter_logits, label_logits

# %% [markdown]
# ## RBF

# %%
from sklearn.cluster import KMeans

N_RBF = 32    # number of RBF centers; keep small (10–40)
kmeans = KMeans(n_clusters=N_RBF, random_state=SEED)
kmeans.fit(X_train_scaled)   # shape (n_train, d)

centers = torch.from_numpy(kmeans.cluster_centers_).float().to(device)
# Out:
# c:\Users\herie\miniconda3\envs\dl\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
class RBFLayer(nn.Module):
    def __init__(self, centers: torch.Tensor, gamma: float = 1.0):
        """
        centers: (K, D) tensor (fixed)
        gamma: 1/(2*sigma^2); controls width of RBFs
        """
        super().__init__()
        self.centers = nn.Parameter(centers, requires_grad=False)
        self.gamma = nn.Parameter(torch.tensor(gamma, dtype=torch.float32), requires_grad=False)

    def forward(self, x: torch.Tensor):
        # x: (B, D), centers: (K, D)
        # Compute squared distances: (B, K)
        # ||x - c||^2 = (x^2).sum + (c^2).sum - 2 x·c
        x2 = (x ** 2).sum(dim=1, keepdim=True)              # (B, 1)
        c2 = (self.centers ** 2).sum(dim=1).unsqueeze(0)    # (1, K)
        xc = x @ self.centers.t()                           # (B, K)
        dist2 = x2 + c2 - 2 * xc
        # RBF activations
        phi = torch.exp(-self.gamma * dist2)
        return phi

# %%
class MultiTaskMLP_RBF(nn.Module):
    def __init__(
        self,
        input_dim: int,
        num_painters: int,
        num_labels: int,
        centers: torch.Tensor,
        hidden_first: int = 32,
        dropout_p: float = 0.4,
        gamma: float = 1.0,
    ):
        super().__init__()

        # Linear pre-transform to "RBF space"
        self.pre = nn.Sequential(
            nn.Linear(input_dim, hidden_first),
            nn.ReLU(),
            nn.Dropout(dropout_p),
        )

        self.rbf = RBFLayer(centers, gamma=gamma)  # output dim = N_RBF

        rbf_dim = centers.shape[0]

        self.painter_head = nn.Sequential(
            nn.Linear(rbf_dim, num_painters),
        )
        self.label_head   = nn.Sequential(
            nn.Linear(rbf_dim, num_labels),
        )

    def forward(self, x: torch.Tensor):
        h = self.pre(x)
        phi = self.rbf(h)
        painter_logits = self.painter_head(phi)
        label_logits   = self.label_head(phi)
        return painter_logits, label_logits

# %%
import torch
import torch.nn as nn

class RBFLayerLearnable(nn.Module):
    def __init__(self, in_dim: int, num_centers: int, init_gamma: float = 1.0):
        """
        in_dim:      dimensionality of the input to this RBF layer (e.g. hidden_first)
        num_centers: number of RBF units K
        init_gamma:  initial gamma; effective RBF is exp(-gamma * ||x - c||^2)
        """
        super().__init__()
        self.in_dim = in_dim
        self.num_centers = num_centers

        # Centers are learnable parameters: (K, D)
        self.centers = nn.Parameter(
            0.1 * torch.randn(num_centers, in_dim)  # small random init
        )

        # Learnable log-gamma so that gamma stays > 0
        self.log_gamma = nn.Parameter(
            torch.log(torch.tensor(init_gamma, dtype=torch.float32))
        )

    def forward(self, x: torch.Tensor):
        """
        x: (B, D) where D = in_dim
        returns: (B, K) RBF activations
        """
        # ensure gamma > 0
        gamma = torch.exp(self.log_gamma)

        # x^2: (B, 1)
        x2 = (x ** 2).sum(dim=1, keepdim=True)
        # c^2: (1, K)
        c2 = (self.centers ** 2).sum(dim=1).unsqueeze(0)
        # x·c: (B, K)
        xc = x @ self.centers.t()

        # squared distance: (B, K)
        dist2 = x2 + c2 - 2 * xc

        # RBF features: (B, K)
        phi = torch.exp(-gamma * dist2)
        return phi

# %% [markdown]
# ## RBF Learnable

# %%
class MultiTaskMLP_RBF_Learnable(nn.Module):
    def __init__(
        self,
        input_dim: int,
        num_painters: int,
        num_labels: int,
        hidden_first: int = 32,
        n_rbf: int = 20,
        dropout_p: float = 0.4,
        init_gamma: float = 1.0,
    ):
        super().__init__()

        # Linear + ReLU pre-transform: R^d -> R^{hidden_first}
        self.pre = nn.Sequential(
            nn.Linear(input_dim, hidden_first),
            nn.ReLU(),
            nn.Dropout(dropout_p),
        )

        # RBF layer in this hidden space: centers ∈ R^{n_rbf × hidden_first}
        self.rbf = RBFLayerLearnable(
            in_dim=hidden_first,
            num_centers=n_rbf,
            init_gamma=init_gamma,
        )

        self.dropout = nn.Dropout(dropout_p)

        # Heads see K-dimensional RBF feature vector
        self.painter_head = nn.Linear(n_rbf, num_painters)
        self.label_head   = nn.Linear(n_rbf, num_labels)

    def forward(self, x: torch.Tensor):
        # x: (B, input_dim)
        h = self.pre(x)          # (B, hidden_first)
        phi = self.rbf(h)        # (B, n_rbf)
        phi = self.dropout(phi)  # optional extra regularization

        painter_logits = self.painter_head(phi)  # (B, num_painters)
        label_logits   = self.label_head(phi)    # (B, num_labels)
        return painter_logits, label_logits

# %% [markdown]
# # Training

# %%
EPOCHS = 1000
LR = 1e-3
WEIGHT_DECAY = 1e-4

painter_criterion = nn.CrossEntropyLoss(weight=painter_class_weights_t)
label_criterion   = nn.CrossEntropyLoss(weight=label_class_weights_t)

LAMBDA_P = 1.0   # weight for painter loss
LAMBDA_L = 1.0   # weight for label loss

# %%
K = 5  # number of models in bagging
MAX_EPOCHS = 1000
PATIENCE = 250

# %%
input_dim = X_train_t.shape[1]

def make_slim_model():
    return MultiTaskMLP_Slim(
        input_dim=input_dim,
        num_painters=NUM_PAINTERS,
        num_labels=NUM_LABELS,
        bottleneck=16,
        hidden_first=32,
        dropout_p=0.5,
    ).to(device)

# %%
def train_one_epoch(
    model,
    loader,
    optimizer,
    painter_criterion,
    label_criterion,
    device,
    lambda_p: float = 1.0,
    lambda_l: float = 1.0,
):
    model.train()
    total = 0
    sum_loss = 0.0
    correct_painter = 0
    correct_label = 0

    for X_batch, y_p_batch, y_l_batch in loader:
        X_batch = X_batch.to(device)
        y_p_batch = y_p_batch.to(device)
        y_l_batch = y_l_batch.to(device)

        optimizer.zero_grad()
        painter_logits, label_logits = model(X_batch)

        painter_loss = painter_criterion(painter_logits, y_p_batch)
        label_loss   = label_criterion(label_logits,   y_l_batch)

        loss = lambda_p * painter_loss + lambda_l * label_loss
        loss.backward()
        optimizer.step()

        batch_size = X_batch.size(0)
        sum_loss += loss.item() * batch_size
        total += batch_size

        painter_pred = painter_logits.argmax(dim=1)
        label_pred   = label_logits.argmax(dim=1)

        correct_painter += (painter_pred == y_p_batch).sum().item()
        correct_label   += (label_pred   == y_l_batch).sum().item()

    epoch_loss = sum_loss / total
    painter_acc = correct_painter / total
    label_acc   = correct_label   / total
    return epoch_loss, painter_acc, label_acc


@torch.no_grad()
def evaluate(
    model,
    loader,
    painter_criterion,
    label_criterion,
    device,
    lambda_p: float = 1.0,
    lambda_l: float = 1.0,
):
    model.eval()
    total = 0
    sum_loss = 0.0
    correct_painter = 0
    correct_label = 0

    for X_batch, y_p_batch, y_l_batch in loader:
        X_batch = X_batch.to(device)
        y_p_batch = y_p_batch.to(device)
        y_l_batch = y_l_batch.to(device)

        painter_logits, label_logits = model(X_batch)

        painter_loss = painter_criterion(painter_logits, y_p_batch)
        label_loss   = label_criterion(label_logits,   y_l_batch)

        loss = lambda_p * painter_loss + lambda_l * label_loss

        batch_size = X_batch.size(0)
        sum_loss += loss.item() * batch_size
        total += batch_size

        painter_pred = painter_logits.argmax(dim=1)
        label_pred   = label_logits.argmax(dim=1)

        correct_painter += (painter_pred == y_p_batch).sum().item()
        correct_label   += (label_pred   == y_l_batch).sum().item()

    epoch_loss = sum_loss / total
    painter_acc = correct_painter / total
    label_acc   = correct_label   / total
    return epoch_loss, painter_acc, label_acc

# %%
import numpy as np
import random
import copy

def train_single_model_with_history(
    seed: int,
    max_epochs: int = 40,
    patience: int = 8,
):
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)

    model = make_slim_model()
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)

    history = {
        "train_loss": [],
        "train_painter_acc": [],
        "train_label_acc": [],
        "val_loss": [],
        "val_painter_acc": [],
        "val_label_acc": [],
    }

    best_state = None
    best_val_score = -np.inf
    epochs_no_improve = 0

    for epoch in range(1, max_epochs + 1):
        train_loss, train_p_acc, train_l_acc = train_one_epoch(
            model,
            train_loader,
            optimizer,
            painter_criterion,
            label_criterion,
            device,
            lambda_p=LAMBDA_P,
            lambda_l=LAMBDA_L,
        )

        val_loss, val_p_acc, val_l_acc = evaluate(
            model,
            val_loader,
            painter_criterion,
            label_criterion,
            device,
            lambda_p=LAMBDA_P,
            lambda_l=LAMBDA_L,
        )

        history["train_loss"].append(train_loss)
        history["train_painter_acc"].append(train_p_acc)
        history["train_label_acc"].append(train_l_acc)
        history["val_loss"].append(val_loss)
        history["val_painter_acc"].append(val_p_acc)
        history["val_label_acc"].append(val_l_acc)

        # monitor label acc
        val_score = val_l_acc

        print(
            f"[seed {seed}] epoch {epoch:02d} | "
            f"train_loss={train_loss:.4f}, train_l_acc={train_l_acc:.3f} | "
            f"val_loss={val_loss:.4f}, val_l_acc={val_l_acc:.3f}"
        )

        if val_score > best_val_score + 1e-4:
            best_val_score = val_score
            best_state = copy.deepcopy(model.state_dict())
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"[seed {seed}] Early stopping at epoch {epoch}")
                break

    if best_state is not None:
        model.load_state_dict(best_state)

    return model, history, best_val_score

# %%
models = []
histories = []
scores = []

for k in range(K):
    seed_k = SEED + k  # or any base seed + k
    print(f"\n=== Training model {k+1}/{K} (seed={seed_k}) ===")
    model_k, hist_k, score_k = train_single_model_with_history(seed=seed_k, max_epochs=MAX_EPOCHS, patience=PATIENCE)
    models.append(model_k)
    histories.append(hist_k)
    scores.append(score_k)

print("Val label acc of each model:", scores)
print("Mean:", np.mean(scores), "Std:", np.std(scores))
# Out:
# === Training model 1/5 (seed=246) ===
# [seed 246] epoch 01 | train_loss=4.1835, train_l_acc=0.144 | val_loss=4.0699, val_l_acc=0.100
# [seed 246] epoch 02 | train_loss=4.1298, train_l_acc=0.144 | val_loss=4.0308, val_l_acc=0.150
# [seed 246] epoch 03 | train_loss=4.0243, train_l_acc=0.172 | val_loss=3.9839, val_l_acc=0.200
# [seed 246] epoch 04 | train_loss=3.9741, train_l_acc=0.228 | val_loss=3.9377, val_l_acc=0.300
# [seed 246] epoch 05 | train_loss=3.9781, train_l_acc=0.194 | val_loss=3.8912, val_l_acc=0.300
# [seed 246] epoch 06 | train_loss=3.9569, train_l_acc=0.206 | val_loss=3.8464, val_l_acc=0.300
# [seed 246] epoch 07 | train_loss=3.8807, train_l_acc=0.300 | val_loss=3.8100, val_l_acc=0.300
# [seed 246] epoch 08 | train_loss=3.8698, train_l_acc=0.267 | val_loss=3.7758, val_l_acc=0.350
# [seed 246] epoch 09 | train_loss=3.8294, train_l_acc=0.300 | val_loss=3.7360, val_l_acc=0.400
# [seed 246] epoch 10 | train_loss=3.8009, train_l_acc=0.289 | val_loss=3.6980, val_l_acc=0.400
# [seed 246] epoch 11 | train_loss=3.7626, train_l_acc=0.311 | val_loss=3.6658, val_l_acc=0.400
# [seed 246] epoch 12 | train_loss=3.7417, train_l_acc=0.311 | val_loss=3.6317, val_l_acc=0.400
# [seed 246] epoch 13 | train_loss=3.6761, train_l_acc=0.394 | val_loss=3.6025, val_l_acc=0.400
# [seed 246] epoch 14 | train_loss=3.6394, train_l_acc=0.400 | val_loss=3.5727, val_l_acc=0.450
# [seed 246] epoch 15 | train_loss=3.5964, train_l_acc=0.400 | val_loss=3.5396, val_l_acc=0.500
# [seed 246] epoch 16 | train_loss=3.6470, train_l_acc=0.400 | val_loss=3.5048, val_l_acc=0.500
# [seed 246] epoch 17 | train_loss=3.5411, train_l_acc=0.389 | val_loss=3.4631, val_l_acc=0.550
# [seed 246] epoch 18 | train_loss=3.5213, train_l_acc=0.472 | val_loss=3.4278, val_l_acc=0.550
# [seed 246] epoch 19 | train_loss=3.4475, train_l_acc=0.494 | val_loss=3.3912, val_l_acc=0.550
# [seed 246] epoch 20 | train_loss=3.3984, train_l_acc=0.489 | val_loss=3.3565, val_l_acc=0.550
# [seed 246] epoch 21 | train_loss=3.4413, train_l_acc=0.411 | val_loss=3.3186, val_l_acc=0.500
# [seed 246] epoch 22 | train_loss=3.3758, train_l_acc=0.517 | val_loss=3.2798, val_l_acc=0.500
# [seed 246] epoch 23 | train_loss=3.3620, train_l_acc=0.472 | val_loss=3.2359, val_l_acc=0.500
# [seed 246] epoch 24 | train_loss=3.3526, train_l_acc=0.556 | val_loss=3.2002, val_l_acc=0.500
# [seed 246] epoch 25 | train_loss=3.2796, train_l_acc=0.517 | val_loss=3.1675, val_l_acc=0.550
# [seed 246] epoch 26 | train_loss=3.2492, train_l_acc=0.528 | val_loss=3.1348, val_l_acc=0.550
# [seed 246] epoch 27 | train_loss=3.2313, train_l_acc=0.506 | val_loss=3.1034, val_l_acc=0.500
# [seed 246] epoch 28 | train_loss=3.1150, train_l_acc=0.572 | val_loss=3.0735, val_l_acc=0.450
# [seed 246] epoch 29 | train_loss=3.2838, train_l_acc=0.528 | val_loss=3.0466, val_l_acc=0.500
# [seed 246] epoch 30 | train_loss=3.0632, train_l_acc=0.539 | val_loss=3.0195, val_l_acc=0.500
# [seed 246] epoch 31 | train_loss=3.1161, train_l_acc=0.578 | val_loss=2.9976, val_l_acc=0.600
# [seed 246] epoch 32 | train_loss=3.1515, train_l_acc=0.528 | val_loss=2.9634, val_l_acc=0.650
# [seed 246] epoch 33 | train_loss=3.0852, train_l_acc=0.567 | val_loss=2.9335, val_l_acc=0.600
# [seed 246] epoch 34 | train_loss=3.1428, train_l_acc=0.572 | val_loss=2.9077, val_l_acc=0.550
# [seed 246] epoch 35 | train_loss=3.1218, train_l_acc=0.578 | val_loss=2.8809, val_l_acc=0.650
# [seed 246] epoch 36 | train_loss=2.9665, train_l_acc=0.656 | val_loss=2.8604, val_l_acc=0.600
# [seed 246] epoch 37 | train_loss=2.8987, train_l_acc=0.594 | val_loss=2.8386, val_l_acc=0.700
# [seed 246] epoch 38 | train_loss=2.9355, train_l_acc=0.644 | val_loss=2.8211, val_l_acc=0.750
# [seed 246] epoch 39 | train_loss=2.9609, train_l_acc=0.544 | val_loss=2.7961, val_l_acc=0.700
# [seed 246] epoch 40 | train_loss=2.9155, train_l_acc=0.594 | val_loss=2.7675, val_l_acc=0.750
# [seed 246] epoch 41 | train_loss=2.7853, train_l_acc=0.656 | val_loss=2.7465, val_l_acc=0.750
# [seed 246] epoch 42 | train_loss=2.8933, train_l_acc=0.617 | val_loss=2.7248, val_l_acc=0.750
# [seed 246] epoch 43 | train_loss=2.8000, train_l_acc=0.694 | val_loss=2.6990, val_l_acc=0.750
# [seed 246] epoch 44 | train_loss=2.6986, train_l_acc=0.628 | val_loss=2.6736, val_l_acc=0.750
# [seed 246] epoch 45 | train_loss=2.7162, train_l_acc=0.633 | val_loss=2.6630, val_l_acc=0.750
# [seed 246] epoch 46 | train_loss=2.7987, train_l_acc=0.683 | val_loss=2.6405, val_l_acc=0.750
# [seed 246] epoch 47 | train_loss=2.8392, train_l_acc=0.667 | val_loss=2.6206, val_l_acc=0.750
# [seed 246] epoch 48 | train_loss=2.7025, train_l_acc=0.717 | val_loss=2.6027, val_l_acc=0.700
# [seed 246] epoch 49 | train_loss=2.7790, train_l_acc=0.639 | val_loss=2.5788, val_l_acc=0.700
# [seed 246] epoch 50 | train_loss=2.7034, train_l_acc=0.656 | val_loss=2.5680, val_l_acc=0.700
# [seed 246] epoch 51 | train_loss=2.7083, train_l_acc=0.672 | val_loss=2.5504, val_l_acc=0.700
# [seed 246] epoch 52 | train_loss=2.7079, train_l_acc=0.656 | val_loss=2.5251, val_l_acc=0.700
# [seed 246] epoch 53 | train_loss=2.6690, train_l_acc=0.672 | val_loss=2.4984, val_l_acc=0.700
# [seed 246] epoch 54 | train_loss=2.5848, train_l_acc=0.728 | val_loss=2.4711, val_l_acc=0.700
# [seed 246] epoch 55 | train_loss=2.6896, train_l_acc=0.711 | val_loss=2.4410, val_l_acc=0.700
# [seed 246] epoch 56 | train_loss=2.5608, train_l_acc=0.711 | val_loss=2.4155, val_l_acc=0.700
# [seed 246] epoch 57 | train_loss=2.5934, train_l_acc=0.683 | val_loss=2.3917, val_l_acc=0.700
# [seed 246] epoch 58 | train_loss=2.4862, train_l_acc=0.733 | val_loss=2.3739, val_l_acc=0.700
# [seed 246] epoch 59 | train_loss=2.5010, train_l_acc=0.711 | val_loss=2.3624, val_l_acc=0.700
# [seed 246] epoch 60 | train_loss=2.4476, train_l_acc=0.756 | val_loss=2.3545, val_l_acc=0.700
# [seed 246] epoch 61 | train_loss=2.5812, train_l_acc=0.689 | val_loss=2.3512, val_l_acc=0.700
# [seed 246] epoch 62 | train_loss=2.4548, train_l_acc=0.711 | val_loss=2.3417, val_l_acc=0.750
# [seed 246] epoch 63 | train_loss=2.4940, train_l_acc=0.717 | val_loss=2.3218, val_l_acc=0.750
# [seed 246] epoch 64 | train_loss=2.4861, train_l_acc=0.728 | val_loss=2.2969, val_l_acc=0.750
# [seed 246] epoch 65 | train_loss=2.4161, train_l_acc=0.744 | val_loss=2.2917, val_l_acc=0.750
# [seed 246] epoch 66 | train_loss=2.4109, train_l_acc=0.722 | val_loss=2.2798, val_l_acc=0.750
# [seed 246] epoch 67 | train_loss=2.4872, train_l_acc=0.656 | val_loss=2.2620, val_l_acc=0.750
# [seed 246] epoch 68 | train_loss=2.4474, train_l_acc=0.711 | val_loss=2.2269, val_l_acc=0.800
# [seed 246] epoch 69 | train_loss=2.3141, train_l_acc=0.761 | val_loss=2.2168, val_l_acc=0.800
# [seed 246] epoch 70 | train_loss=2.2436, train_l_acc=0.728 | val_loss=2.1981, val_l_acc=0.800
# [seed 246] epoch 71 | train_loss=2.4233, train_l_acc=0.750 | val_loss=2.1775, val_l_acc=0.800
# [seed 246] epoch 72 | train_loss=2.2604, train_l_acc=0.756 | val_loss=2.1639, val_l_acc=0.800
# [seed 246] epoch 73 | train_loss=2.2389, train_l_acc=0.778 | val_loss=2.1489, val_l_acc=0.800
# [seed 246] epoch 74 | train_loss=2.2680, train_l_acc=0.756 | val_loss=2.1471, val_l_acc=0.750
# [seed 246] epoch 75 | train_loss=2.2451, train_l_acc=0.733 | val_loss=2.1404, val_l_acc=0.750
# [seed 246] epoch 76 | train_loss=2.2511, train_l_acc=0.794 | val_loss=2.1528, val_l_acc=0.750
# [seed 246] epoch 77 | train_loss=2.1227, train_l_acc=0.767 | val_loss=2.1466, val_l_acc=0.750
# [seed 246] epoch 78 | train_loss=2.2992, train_l_acc=0.756 | val_loss=2.1455, val_l_acc=0.750
# [seed 246] epoch 79 | train_loss=2.2652, train_l_acc=0.767 | val_loss=2.1292, val_l_acc=0.750
# [seed 246] epoch 80 | train_loss=2.2510, train_l_acc=0.772 | val_loss=2.1161, val_l_acc=0.750
# [seed 246] epoch 81 | train_loss=2.2818, train_l_acc=0.767 | val_loss=2.1033, val_l_acc=0.800
# [seed 246] epoch 82 | train_loss=2.2284, train_l_acc=0.739 | val_loss=2.0784, val_l_acc=0.800
# [seed 246] epoch 83 | train_loss=2.0873, train_l_acc=0.772 | val_loss=2.0660, val_l_acc=0.800
# [seed 246] epoch 84 | train_loss=2.0183, train_l_acc=0.817 | val_loss=2.0586, val_l_acc=0.800
# [seed 246] epoch 85 | train_loss=2.0347, train_l_acc=0.789 | val_loss=2.0544, val_l_acc=0.800
# [seed 246] epoch 86 | train_loss=2.1556, train_l_acc=0.783 | val_loss=2.0387, val_l_acc=0.800
# [seed 246] epoch 87 | train_loss=2.1015, train_l_acc=0.750 | val_loss=2.0280, val_l_acc=0.800
# [seed 246] epoch 88 | train_loss=2.1698, train_l_acc=0.778 | val_loss=2.0030, val_l_acc=0.800
# [seed 246] epoch 89 | train_loss=2.2279, train_l_acc=0.767 | val_loss=1.9962, val_l_acc=0.800
# [seed 246] epoch 90 | train_loss=2.1451, train_l_acc=0.728 | val_loss=1.9792, val_l_acc=0.800
# [seed 246] epoch 91 | train_loss=2.1395, train_l_acc=0.789 | val_loss=1.9554, val_l_acc=0.800
# [seed 246] epoch 92 | train_loss=1.9761, train_l_acc=0.767 | val_loss=1.9491, val_l_acc=0.800
# [seed 246] epoch 93 | train_loss=2.0856, train_l_acc=0.822 | val_loss=1.9417, val_l_acc=0.800
# [seed 246] epoch 94 | train_loss=1.9884, train_l_acc=0.822 | val_loss=1.9341, val_l_acc=0.800
# [seed 246] epoch 95 | train_loss=2.1755, train_l_acc=0.767 | val_loss=1.9257, val_l_acc=0.800
# [seed 246] epoch 96 | train_loss=2.0683, train_l_acc=0.794 | val_loss=1.9126, val_l_acc=0.800
# [seed 246] epoch 97 | train_loss=1.9556, train_l_acc=0.811 | val_loss=1.9097, val_l_acc=0.800
# [seed 246] epoch 98 | train_loss=2.1573, train_l_acc=0.811 | val_loss=1.9252, val_l_acc=0.850
# [seed 246] epoch 99 | train_loss=2.1072, train_l_acc=0.800 | val_loss=1.9173, val_l_acc=0.850
# [seed 246] epoch 100 | train_loss=2.0075, train_l_acc=0.828 | val_loss=1.8939, val_l_acc=0.850
# [seed 246] epoch 101 | train_loss=1.9027, train_l_acc=0.828 | val_loss=1.8790, val_l_acc=0.800
# [seed 246] epoch 102 | train_loss=2.0647, train_l_acc=0.806 | val_loss=1.8658, val_l_acc=0.800
# [seed 246] epoch 103 | train_loss=1.9488, train_l_acc=0.800 | val_loss=1.8605, val_l_acc=0.800
# [seed 246] epoch 104 | train_loss=1.9053, train_l_acc=0.833 | val_loss=1.8591, val_l_acc=0.800
# [seed 246] epoch 105 | train_loss=2.0929, train_l_acc=0.789 | val_loss=1.8754, val_l_acc=0.850
# [seed 246] epoch 106 | train_loss=1.8230, train_l_acc=0.817 | val_loss=1.8997, val_l_acc=0.850
# [seed 246] epoch 107 | train_loss=1.8657, train_l_acc=0.839 | val_loss=1.9177, val_l_acc=0.850
# [seed 246] epoch 108 | train_loss=1.9051, train_l_acc=0.806 | val_loss=1.9163, val_l_acc=0.850
# [seed 246] epoch 109 | train_loss=1.9745, train_l_acc=0.828 | val_loss=1.9155, val_l_acc=0.850
# [seed 246] epoch 110 | train_loss=1.9776, train_l_acc=0.828 | val_loss=1.9179, val_l_acc=0.850
# [seed 246] epoch 111 | train_loss=1.9020, train_l_acc=0.806 | val_loss=1.9250, val_l_acc=0.850
# [seed 246] epoch 112 | train_loss=1.9981, train_l_acc=0.822 | val_loss=1.8910, val_l_acc=0.850
# [seed 246] epoch 113 | train_loss=1.8700, train_l_acc=0.811 | val_loss=1.8683, val_l_acc=0.850
# [seed 246] epoch 114 | train_loss=1.9398, train_l_acc=0.800 | val_loss=1.8502, val_l_acc=0.850
# [seed 246] epoch 115 | train_loss=1.8720, train_l_acc=0.833 | val_loss=1.8464, val_l_acc=0.850
# [seed 246] epoch 116 | train_loss=1.8494, train_l_acc=0.811 | val_loss=1.8350, val_l_acc=0.850
# [seed 246] epoch 117 | train_loss=1.8657, train_l_acc=0.783 | val_loss=1.8232, val_l_acc=0.800
# [seed 246] epoch 118 | train_loss=1.9016, train_l_acc=0.833 | val_loss=1.8290, val_l_acc=0.800
# [seed 246] epoch 119 | train_loss=1.7362, train_l_acc=0.861 | val_loss=1.8353, val_l_acc=0.800
# [seed 246] epoch 120 | train_loss=2.0574, train_l_acc=0.783 | val_loss=1.8344, val_l_acc=0.800
# [seed 246] epoch 121 | train_loss=1.8676, train_l_acc=0.794 | val_loss=1.8174, val_l_acc=0.800
# [seed 246] epoch 122 | train_loss=1.8956, train_l_acc=0.806 | val_loss=1.8084, val_l_acc=0.800
# [seed 246] epoch 123 | train_loss=1.8072, train_l_acc=0.833 | val_loss=1.8053, val_l_acc=0.800
# [seed 246] epoch 124 | train_loss=1.8810, train_l_acc=0.783 | val_loss=1.8002, val_l_acc=0.800
# [seed 246] epoch 125 | train_loss=1.7433, train_l_acc=0.833 | val_loss=1.7742, val_l_acc=0.800
# [seed 246] epoch 126 | train_loss=1.9732, train_l_acc=0.833 | val_loss=1.7784, val_l_acc=0.800
# [seed 246] epoch 127 | train_loss=1.8679, train_l_acc=0.822 | val_loss=1.7753, val_l_acc=0.800
# [seed 246] epoch 128 | train_loss=1.7567, train_l_acc=0.839 | val_loss=1.7726, val_l_acc=0.850
# [seed 246] epoch 129 | train_loss=2.0738, train_l_acc=0.783 | val_loss=1.7735, val_l_acc=0.850
# [seed 246] epoch 130 | train_loss=1.8129, train_l_acc=0.839 | val_loss=1.7633, val_l_acc=0.850
# [seed 246] epoch 131 | train_loss=1.7596, train_l_acc=0.828 | val_loss=1.7707, val_l_acc=0.850
# [seed 246] epoch 132 | train_loss=1.7134, train_l_acc=0.839 | val_loss=1.7717, val_l_acc=0.850
# [seed 246] epoch 133 | train_loss=1.8040, train_l_acc=0.850 | val_loss=1.7900, val_l_acc=0.800
# [seed 246] epoch 134 | train_loss=1.8595, train_l_acc=0.789 | val_loss=1.7968, val_l_acc=0.800
# [seed 246] epoch 135 | train_loss=1.9063, train_l_acc=0.833 | val_loss=1.7784, val_l_acc=0.850
# [seed 246] epoch 136 | train_loss=1.8931, train_l_acc=0.817 | val_loss=1.7644, val_l_acc=0.850
# [seed 246] epoch 137 | train_loss=1.7416, train_l_acc=0.861 | val_loss=1.7835, val_l_acc=0.850
# [seed 246] epoch 138 | train_loss=1.7631, train_l_acc=0.817 | val_loss=1.7695, val_l_acc=0.850
# [seed 246] epoch 139 | train_loss=1.7540, train_l_acc=0.839 | val_loss=1.7607, val_l_acc=0.850
# [seed 246] epoch 140 | train_loss=1.7235, train_l_acc=0.822 | val_loss=1.7564, val_l_acc=0.850
# [seed 246] epoch 141 | train_loss=1.9230, train_l_acc=0.772 | val_loss=1.7375, val_l_acc=0.900
# [seed 246] epoch 142 | train_loss=1.6651, train_l_acc=0.844 | val_loss=1.7282, val_l_acc=0.900
# [seed 246] epoch 143 | train_loss=1.7934, train_l_acc=0.817 | val_loss=1.7198, val_l_acc=0.900
# [seed 246] epoch 144 | train_loss=1.8378, train_l_acc=0.800 | val_loss=1.7151, val_l_acc=0.900
# [seed 246] epoch 145 | train_loss=1.8061, train_l_acc=0.839 | val_loss=1.7237, val_l_acc=0.900
# [seed 246] epoch 146 | train_loss=1.7151, train_l_acc=0.844 | val_loss=1.7120, val_l_acc=0.850
# [seed 246] epoch 147 | train_loss=1.6841, train_l_acc=0.822 | val_loss=1.7171, val_l_acc=0.850
# [seed 246] epoch 148 | train_loss=1.7394, train_l_acc=0.833 | val_loss=1.7095, val_l_acc=0.850
# [seed 246] epoch 149 | train_loss=1.7177, train_l_acc=0.861 | val_loss=1.7264, val_l_acc=0.850
# [seed 246] epoch 150 | train_loss=1.7972, train_l_acc=0.828 | val_loss=1.7270, val_l_acc=0.850
# [seed 246] epoch 151 | train_loss=1.7311, train_l_acc=0.861 | val_loss=1.7161, val_l_acc=0.850
# [seed 246] epoch 152 | train_loss=1.8126, train_l_acc=0.811 | val_loss=1.6853, val_l_acc=0.850
# [seed 246] epoch 153 | train_loss=1.7235, train_l_acc=0.839 | val_loss=1.6818, val_l_acc=0.850
# [seed 246] epoch 154 | train_loss=1.6960, train_l_acc=0.861 | val_loss=1.6945, val_l_acc=0.850
# [seed 246] epoch 155 | train_loss=1.8206, train_l_acc=0.789 | val_loss=1.6990, val_l_acc=0.850
# [seed 246] epoch 156 | train_loss=1.6652, train_l_acc=0.856 | val_loss=1.6889, val_l_acc=0.900
# [seed 246] epoch 157 | train_loss=1.8145, train_l_acc=0.828 | val_loss=1.6904, val_l_acc=0.850
# [seed 246] epoch 158 | train_loss=1.7092, train_l_acc=0.817 | val_loss=1.6985, val_l_acc=0.900
# [seed 246] epoch 159 | train_loss=1.7892, train_l_acc=0.817 | val_loss=1.7195, val_l_acc=0.900
# [seed 246] epoch 160 | train_loss=1.5927, train_l_acc=0.861 | val_loss=1.7111, val_l_acc=0.900
# [seed 246] epoch 161 | train_loss=1.6567, train_l_acc=0.844 | val_loss=1.7239, val_l_acc=0.850
# [seed 246] epoch 162 | train_loss=1.7671, train_l_acc=0.833 | val_loss=1.6985, val_l_acc=0.900
# [seed 246] epoch 163 | train_loss=1.7850, train_l_acc=0.789 | val_loss=1.6773, val_l_acc=0.850
# [seed 246] epoch 164 | train_loss=1.6905, train_l_acc=0.867 | val_loss=1.6761, val_l_acc=0.850
# [seed 246] epoch 165 | train_loss=1.6958, train_l_acc=0.894 | val_loss=1.6633, val_l_acc=0.900
# [seed 246] epoch 166 | train_loss=1.6843, train_l_acc=0.839 | val_loss=1.6564, val_l_acc=0.850
# [seed 246] epoch 167 | train_loss=1.8200, train_l_acc=0.806 | val_loss=1.6652, val_l_acc=0.850
# [seed 246] epoch 168 | train_loss=1.7656, train_l_acc=0.817 | val_loss=1.6671, val_l_acc=0.850
# [seed 246] epoch 169 | train_loss=1.6184, train_l_acc=0.828 | val_loss=1.6701, val_l_acc=0.900
# [seed 246] epoch 170 | train_loss=1.6627, train_l_acc=0.850 | val_loss=1.6836, val_l_acc=0.900
# [seed 246] epoch 171 | train_loss=1.6778, train_l_acc=0.828 | val_loss=1.7088, val_l_acc=0.850
# [seed 246] epoch 172 | train_loss=1.6994, train_l_acc=0.822 | val_loss=1.7309, val_l_acc=0.850
# [seed 246] epoch 173 | train_loss=1.5604, train_l_acc=0.844 | val_loss=1.7574, val_l_acc=0.850
# [seed 246] epoch 174 | train_loss=1.6809, train_l_acc=0.856 | val_loss=1.7413, val_l_acc=0.850
# [seed 246] epoch 175 | train_loss=1.6157, train_l_acc=0.861 | val_loss=1.7263, val_l_acc=0.850
# [seed 246] epoch 176 | train_loss=1.7016, train_l_acc=0.850 | val_loss=1.7166, val_l_acc=0.850
# [seed 246] epoch 177 | train_loss=1.6100, train_l_acc=0.844 | val_loss=1.7029, val_l_acc=0.850
# [seed 246] epoch 178 | train_loss=1.4392, train_l_acc=0.872 | val_loss=1.6988, val_l_acc=0.850
# [seed 246] epoch 179 | train_loss=1.6352, train_l_acc=0.883 | val_loss=1.6931, val_l_acc=0.850
# [seed 246] epoch 180 | train_loss=1.7849, train_l_acc=0.772 | val_loss=1.7017, val_l_acc=0.850
# [seed 246] epoch 181 | train_loss=1.6899, train_l_acc=0.844 | val_loss=1.6939, val_l_acc=0.850
# [seed 246] epoch 182 | train_loss=1.5966, train_l_acc=0.861 | val_loss=1.6944, val_l_acc=0.850
# [seed 246] epoch 183 | train_loss=1.6090, train_l_acc=0.883 | val_loss=1.6826, val_l_acc=0.850
# [seed 246] epoch 184 | train_loss=1.6025, train_l_acc=0.856 | val_loss=1.6962, val_l_acc=0.850
# [seed 246] epoch 185 | train_loss=1.6373, train_l_acc=0.861 | val_loss=1.6791, val_l_acc=0.850
# [seed 246] epoch 186 | train_loss=1.8712, train_l_acc=0.783 | val_loss=1.7008, val_l_acc=0.850
# [seed 246] epoch 187 | train_loss=1.6022, train_l_acc=0.850 | val_loss=1.6977, val_l_acc=0.850
# [seed 246] epoch 188 | train_loss=1.5444, train_l_acc=0.856 | val_loss=1.7100, val_l_acc=0.850
# [seed 246] epoch 189 | train_loss=1.5635, train_l_acc=0.861 | val_loss=1.6944, val_l_acc=0.850
# [seed 246] epoch 190 | train_loss=1.5907, train_l_acc=0.844 | val_loss=1.7048, val_l_acc=0.850
# [seed 246] epoch 191 | train_loss=1.7413, train_l_acc=0.822 | val_loss=1.7181, val_l_acc=0.850
# [seed 246] epoch 192 | train_loss=1.5738, train_l_acc=0.861 | val_loss=1.7102, val_l_acc=0.850
# [seed 246] epoch 193 | train_loss=1.6571, train_l_acc=0.850 | val_loss=1.6892, val_l_acc=0.850
# [seed 246] epoch 194 | train_loss=1.5147, train_l_acc=0.883 | val_loss=1.6600, val_l_acc=0.850
# [seed 246] epoch 195 | train_loss=1.6731, train_l_acc=0.867 | val_loss=1.6659, val_l_acc=0.850
# [seed 246] epoch 196 | train_loss=1.5380, train_l_acc=0.828 | val_loss=1.6698, val_l_acc=0.850
# [seed 246] epoch 197 | train_loss=1.5524, train_l_acc=0.839 | val_loss=1.6833, val_l_acc=0.850
# [seed 246] epoch 198 | train_loss=1.4853, train_l_acc=0.844 | val_loss=1.6793, val_l_acc=0.850
# [seed 246] epoch 199 | train_loss=1.5839, train_l_acc=0.850 | val_loss=1.6932, val_l_acc=0.850
# [seed 246] epoch 200 | train_loss=1.5931, train_l_acc=0.822 | val_loss=1.7012, val_l_acc=0.850
# [seed 246] epoch 201 | train_loss=1.6279, train_l_acc=0.839 | val_loss=1.7213, val_l_acc=0.850
# [seed 246] epoch 202 | train_loss=1.6269, train_l_acc=0.850 | val_loss=1.7084, val_l_acc=0.850
# [seed 246] epoch 203 | train_loss=1.6265, train_l_acc=0.856 | val_loss=1.6925, val_l_acc=0.850
# [seed 246] epoch 204 | train_loss=1.5512, train_l_acc=0.878 | val_loss=1.6817, val_l_acc=0.850
# [seed 246] epoch 205 | train_loss=1.4889, train_l_acc=0.856 | val_loss=1.6640, val_l_acc=0.850
# [seed 246] epoch 206 | train_loss=1.7143, train_l_acc=0.794 | val_loss=1.6659, val_l_acc=0.850
# [seed 246] epoch 207 | train_loss=1.6241, train_l_acc=0.833 | val_loss=1.6666, val_l_acc=0.850
# [seed 246] epoch 208 | train_loss=1.7820, train_l_acc=0.822 | val_loss=1.6779, val_l_acc=0.850
# [seed 246] epoch 209 | train_loss=1.5879, train_l_acc=0.889 | val_loss=1.6729, val_l_acc=0.850
# [seed 246] epoch 210 | train_loss=1.3332, train_l_acc=0.939 | val_loss=1.6743, val_l_acc=0.850
# [seed 246] epoch 211 | train_loss=1.6324, train_l_acc=0.856 | val_loss=1.6776, val_l_acc=0.850
# [seed 246] epoch 212 | train_loss=1.8275, train_l_acc=0.806 | val_loss=1.6689, val_l_acc=0.850
# [seed 246] epoch 213 | train_loss=1.5489, train_l_acc=0.889 | val_loss=1.7044, val_l_acc=0.850
# [seed 246] epoch 214 | train_loss=1.5293, train_l_acc=0.878 | val_loss=1.7019, val_l_acc=0.850
# [seed 246] epoch 215 | train_loss=1.6612, train_l_acc=0.844 | val_loss=1.6858, val_l_acc=0.850
# [seed 246] epoch 216 | train_loss=1.5936, train_l_acc=0.850 | val_loss=1.6763, val_l_acc=0.850
# [seed 246] epoch 217 | train_loss=1.5585, train_l_acc=0.856 | val_loss=1.6724, val_l_acc=0.850
# [seed 246] epoch 218 | train_loss=1.5248, train_l_acc=0.856 | val_loss=1.6734, val_l_acc=0.850
# [seed 246] epoch 219 | train_loss=1.6163, train_l_acc=0.828 | val_loss=1.6804, val_l_acc=0.850
# [seed 246] epoch 220 | train_loss=1.5784, train_l_acc=0.817 | val_loss=1.6879, val_l_acc=0.850
# [seed 246] epoch 221 | train_loss=1.4986, train_l_acc=0.906 | val_loss=1.6739, val_l_acc=0.850
# [seed 246] epoch 222 | train_loss=1.6512, train_l_acc=0.833 | val_loss=1.6789, val_l_acc=0.850
# [seed 246] epoch 223 | train_loss=1.4555, train_l_acc=0.867 | val_loss=1.6821, val_l_acc=0.850
# [seed 246] epoch 224 | train_loss=1.5014, train_l_acc=0.872 | val_loss=1.6840, val_l_acc=0.850
# [seed 246] epoch 225 | train_loss=1.6159, train_l_acc=0.850 | val_loss=1.6868, val_l_acc=0.850
# [seed 246] epoch 226 | train_loss=1.5251, train_l_acc=0.883 | val_loss=1.6840, val_l_acc=0.850
# [seed 246] epoch 227 | train_loss=1.5365, train_l_acc=0.839 | val_loss=1.6781, val_l_acc=0.850
# [seed 246] epoch 228 | train_loss=1.5880, train_l_acc=0.833 | val_loss=1.6760, val_l_acc=0.850
# [seed 246] epoch 229 | train_loss=1.6632, train_l_acc=0.850 | val_loss=1.6724, val_l_acc=0.850
# [seed 246] epoch 230 | train_loss=1.4970, train_l_acc=0.878 | val_loss=1.6801, val_l_acc=0.850
# [seed 246] epoch 231 | train_loss=1.6033, train_l_acc=0.828 | val_loss=1.6820, val_l_acc=0.850
# [seed 246] epoch 232 | train_loss=1.5764, train_l_acc=0.844 | val_loss=1.6918, val_l_acc=0.850
# [seed 246] epoch 233 | train_loss=1.4867, train_l_acc=0.889 | val_loss=1.6824, val_l_acc=0.850
# [seed 246] epoch 234 | train_loss=1.6810, train_l_acc=0.867 | val_loss=1.6577, val_l_acc=0.850
# [seed 246] epoch 235 | train_loss=1.4740, train_l_acc=0.867 | val_loss=1.6436, val_l_acc=0.850
# [seed 246] epoch 236 | train_loss=1.6397, train_l_acc=0.844 | val_loss=1.6270, val_l_acc=0.850
# [seed 246] epoch 237 | train_loss=1.4093, train_l_acc=0.889 | val_loss=1.6368, val_l_acc=0.850
# [seed 246] epoch 238 | train_loss=1.3811, train_l_acc=0.894 | val_loss=1.6351, val_l_acc=0.850
# [seed 246] epoch 239 | train_loss=1.4648, train_l_acc=0.878 | val_loss=1.6445, val_l_acc=0.850
# [seed 246] epoch 240 | train_loss=1.6291, train_l_acc=0.828 | val_loss=1.6543, val_l_acc=0.850
# [seed 246] epoch 241 | train_loss=1.4965, train_l_acc=0.900 | val_loss=1.6433, val_l_acc=0.850
# [seed 246] epoch 242 | train_loss=1.5298, train_l_acc=0.856 | val_loss=1.6557, val_l_acc=0.850
# [seed 246] epoch 243 | train_loss=1.6200, train_l_acc=0.872 | val_loss=1.6648, val_l_acc=0.850
# [seed 246] epoch 244 | train_loss=1.4522, train_l_acc=0.900 | val_loss=1.6785, val_l_acc=0.800
# [seed 246] epoch 245 | train_loss=1.5380, train_l_acc=0.856 | val_loss=1.6762, val_l_acc=0.800
# [seed 246] epoch 246 | train_loss=1.3867, train_l_acc=0.883 | val_loss=1.6669, val_l_acc=0.850
# [seed 246] epoch 247 | train_loss=1.5637, train_l_acc=0.856 | val_loss=1.6397, val_l_acc=0.900
# [seed 246] epoch 248 | train_loss=1.6784, train_l_acc=0.833 | val_loss=1.6395, val_l_acc=0.850
# [seed 246] epoch 249 | train_loss=1.4113, train_l_acc=0.872 | val_loss=1.6362, val_l_acc=0.850
# [seed 246] epoch 250 | train_loss=1.4945, train_l_acc=0.833 | val_loss=1.6349, val_l_acc=0.850
# [seed 246] epoch 251 | train_loss=1.5031, train_l_acc=0.894 | val_loss=1.6318, val_l_acc=0.850
# [seed 246] epoch 252 | train_loss=1.4693, train_l_acc=0.894 | val_loss=1.6460, val_l_acc=0.900
# [seed 246] epoch 253 | train_loss=1.6531, train_l_acc=0.828 | val_loss=1.6629, val_l_acc=0.900
# [seed 246] epoch 254 | train_loss=1.4418, train_l_acc=0.878 | val_loss=1.6712, val_l_acc=0.850
# [seed 246] epoch 255 | train_loss=1.5112, train_l_acc=0.872 | val_loss=1.6713, val_l_acc=0.850
# [seed 246] epoch 256 | train_loss=1.4890, train_l_acc=0.889 | val_loss=1.6600, val_l_acc=0.850
# [seed 246] epoch 257 | train_loss=1.5203, train_l_acc=0.878 | val_loss=1.6457, val_l_acc=0.850
# [seed 246] epoch 258 | train_loss=1.5244, train_l_acc=0.883 | val_loss=1.6587, val_l_acc=0.850
# [seed 246] epoch 259 | train_loss=1.4304, train_l_acc=0.883 | val_loss=1.6420, val_l_acc=0.850
# [seed 246] epoch 260 | train_loss=1.5392, train_l_acc=0.861 | val_loss=1.6393, val_l_acc=0.850
# [seed 246] epoch 261 | train_loss=1.3944, train_l_acc=0.872 | val_loss=1.6589, val_l_acc=0.850
# [seed 246] epoch 262 | train_loss=1.4295, train_l_acc=0.883 | val_loss=1.6707, val_l_acc=0.850
# [seed 246] epoch 263 | train_loss=1.4757, train_l_acc=0.861 | val_loss=1.6792, val_l_acc=0.850
# [seed 246] epoch 264 | train_loss=1.3495, train_l_acc=0.900 | val_loss=1.6925, val_l_acc=0.850
# [seed 246] epoch 265 | train_loss=1.6948, train_l_acc=0.839 | val_loss=1.6767, val_l_acc=0.850
# [seed 246] epoch 266 | train_loss=1.4140, train_l_acc=0.872 | val_loss=1.6735, val_l_acc=0.850
# [seed 246] epoch 267 | train_loss=1.2755, train_l_acc=0.911 | val_loss=1.6642, val_l_acc=0.850
# [seed 246] epoch 268 | train_loss=1.3440, train_l_acc=0.900 | val_loss=1.6533, val_l_acc=0.850
# [seed 246] epoch 269 | train_loss=1.4081, train_l_acc=0.878 | val_loss=1.6550, val_l_acc=0.850
# [seed 246] epoch 270 | train_loss=1.4253, train_l_acc=0.856 | val_loss=1.6752, val_l_acc=0.850
# [seed 246] epoch 271 | train_loss=1.4273, train_l_acc=0.839 | val_loss=1.6868, val_l_acc=0.800
# [seed 246] epoch 272 | train_loss=1.5332, train_l_acc=0.861 | val_loss=1.7031, val_l_acc=0.800
# [seed 246] epoch 273 | train_loss=1.4983, train_l_acc=0.872 | val_loss=1.7135, val_l_acc=0.850
# [seed 246] epoch 274 | train_loss=1.6517, train_l_acc=0.822 | val_loss=1.6945, val_l_acc=0.850
# [seed 246] epoch 275 | train_loss=1.3524, train_l_acc=0.900 | val_loss=1.6753, val_l_acc=0.850
# [seed 246] epoch 276 | train_loss=1.3874, train_l_acc=0.867 | val_loss=1.6792, val_l_acc=0.850
# [seed 246] epoch 277 | train_loss=1.5056, train_l_acc=0.883 | val_loss=1.6753, val_l_acc=0.850
# [seed 246] epoch 278 | train_loss=1.2803, train_l_acc=0.906 | val_loss=1.6943, val_l_acc=0.850
# [seed 246] epoch 279 | train_loss=1.5380, train_l_acc=0.872 | val_loss=1.7130, val_l_acc=0.850
# [seed 246] epoch 280 | train_loss=1.4454, train_l_acc=0.872 | val_loss=1.7254, val_l_acc=0.850
# [seed 246] epoch 281 | train_loss=1.5227, train_l_acc=0.878 | val_loss=1.7221, val_l_acc=0.850
# [seed 246] epoch 282 | train_loss=1.5139, train_l_acc=0.878 | val_loss=1.7222, val_l_acc=0.850
# [seed 246] epoch 283 | train_loss=1.3920, train_l_acc=0.883 | val_loss=1.7161, val_l_acc=0.850
# [seed 246] epoch 284 | train_loss=1.4103, train_l_acc=0.906 | val_loss=1.7142, val_l_acc=0.850
# [seed 246] epoch 285 | train_loss=1.4429, train_l_acc=0.883 | val_loss=1.7271, val_l_acc=0.850
# [seed 246] epoch 286 | train_loss=1.3168, train_l_acc=0.917 | val_loss=1.7305, val_l_acc=0.850
# [seed 246] epoch 287 | train_loss=1.5181, train_l_acc=0.844 | val_loss=1.7214, val_l_acc=0.850
# [seed 246] epoch 288 | train_loss=1.5186, train_l_acc=0.817 | val_loss=1.7315, val_l_acc=0.850
# [seed 246] epoch 289 | train_loss=1.3562, train_l_acc=0.883 | val_loss=1.7467, val_l_acc=0.850
# [seed 246] epoch 290 | train_loss=1.3539, train_l_acc=0.894 | val_loss=1.7469, val_l_acc=0.850
# [seed 246] epoch 291 | train_loss=1.4894, train_l_acc=0.878 | val_loss=1.7394, val_l_acc=0.850
# [seed 246] epoch 292 | train_loss=1.3999, train_l_acc=0.883 | val_loss=1.7546, val_l_acc=0.850
# [seed 246] epoch 293 | train_loss=1.3995, train_l_acc=0.894 | val_loss=1.7541, val_l_acc=0.850
# [seed 246] epoch 294 | train_loss=1.3518, train_l_acc=0.900 | val_loss=1.7582, val_l_acc=0.850
# [seed 246] epoch 295 | train_loss=1.4677, train_l_acc=0.844 | val_loss=1.7368, val_l_acc=0.850
# [seed 246] epoch 296 | train_loss=1.4215, train_l_acc=0.900 | val_loss=1.7034, val_l_acc=0.850
# [seed 246] epoch 297 | train_loss=1.5591, train_l_acc=0.839 | val_loss=1.7256, val_l_acc=0.850
# [seed 246] epoch 298 | train_loss=1.4845, train_l_acc=0.883 | val_loss=1.7548, val_l_acc=0.850
# [seed 246] epoch 299 | train_loss=1.5322, train_l_acc=0.817 | val_loss=1.7670, val_l_acc=0.850
# [seed 246] epoch 300 | train_loss=1.4170, train_l_acc=0.883 | val_loss=1.7776, val_l_acc=0.850
# [seed 246] epoch 301 | train_loss=1.3861, train_l_acc=0.878 | val_loss=1.7447, val_l_acc=0.850
# [seed 246] epoch 302 | train_loss=1.2416, train_l_acc=0.917 | val_loss=1.7126, val_l_acc=0.850
# [seed 246] epoch 303 | train_loss=1.4423, train_l_acc=0.878 | val_loss=1.6967, val_l_acc=0.850
# [seed 246] epoch 304 | train_loss=1.4325, train_l_acc=0.889 | val_loss=1.7094, val_l_acc=0.850
# [seed 246] epoch 305 | train_loss=1.3559, train_l_acc=0.894 | val_loss=1.7261, val_l_acc=0.850
# [seed 246] epoch 306 | train_loss=1.4276, train_l_acc=0.850 | val_loss=1.7403, val_l_acc=0.850
# [seed 246] epoch 307 | train_loss=1.3653, train_l_acc=0.872 | val_loss=1.7323, val_l_acc=0.850
# [seed 246] epoch 308 | train_loss=1.2951, train_l_acc=0.861 | val_loss=1.7386, val_l_acc=0.850
# [seed 246] epoch 309 | train_loss=1.3984, train_l_acc=0.856 | val_loss=1.7167, val_l_acc=0.850
# [seed 246] epoch 310 | train_loss=1.5626, train_l_acc=0.828 | val_loss=1.7234, val_l_acc=0.850
# [seed 246] epoch 311 | train_loss=1.4724, train_l_acc=0.878 | val_loss=1.7340, val_l_acc=0.850
# [seed 246] epoch 312 | train_loss=1.4244, train_l_acc=0.917 | val_loss=1.7527, val_l_acc=0.850
# [seed 246] epoch 313 | train_loss=1.3244, train_l_acc=0.889 | val_loss=1.7377, val_l_acc=0.850
# [seed 246] epoch 314 | train_loss=1.5031, train_l_acc=0.856 | val_loss=1.7491, val_l_acc=0.850
# [seed 246] epoch 315 | train_loss=1.4570, train_l_acc=0.872 | val_loss=1.7409, val_l_acc=0.850
# [seed 246] epoch 316 | train_loss=1.3968, train_l_acc=0.906 | val_loss=1.7406, val_l_acc=0.900
# [seed 246] epoch 317 | train_loss=1.3094, train_l_acc=0.917 | val_loss=1.7556, val_l_acc=0.900
# [seed 246] epoch 318 | train_loss=1.5171, train_l_acc=0.861 | val_loss=1.7756, val_l_acc=0.850
# [seed 246] epoch 319 | train_loss=1.3559, train_l_acc=0.856 | val_loss=1.7812, val_l_acc=0.850
# [seed 246] epoch 320 | train_loss=1.4257, train_l_acc=0.878 | val_loss=1.7957, val_l_acc=0.850
# [seed 246] epoch 321 | train_loss=1.4049, train_l_acc=0.883 | val_loss=1.7893, val_l_acc=0.850
# [seed 246] epoch 322 | train_loss=1.4347, train_l_acc=0.889 | val_loss=1.7808, val_l_acc=0.850
# [seed 246] epoch 323 | train_loss=1.4075, train_l_acc=0.900 | val_loss=1.7672, val_l_acc=0.850
# [seed 246] epoch 324 | train_loss=1.4248, train_l_acc=0.900 | val_loss=1.7796, val_l_acc=0.850
# [seed 246] epoch 325 | train_loss=1.3648, train_l_acc=0.911 | val_loss=1.7855, val_l_acc=0.850
# [seed 246] epoch 326 | train_loss=1.2583, train_l_acc=0.906 | val_loss=1.7787, val_l_acc=0.850
# [seed 246] epoch 327 | train_loss=1.3938, train_l_acc=0.856 | val_loss=1.7743, val_l_acc=0.850
# [seed 246] epoch 328 | train_loss=1.3853, train_l_acc=0.900 | val_loss=1.7645, val_l_acc=0.850
# [seed 246] epoch 329 | train_loss=1.3446, train_l_acc=0.894 | val_loss=1.7747, val_l_acc=0.850
# [seed 246] epoch 330 | train_loss=1.4732, train_l_acc=0.889 | val_loss=1.7797, val_l_acc=0.850
# [seed 246] epoch 331 | train_loss=1.2296, train_l_acc=0.911 | val_loss=1.7903, val_l_acc=0.850
# [seed 246] epoch 332 | train_loss=1.4992, train_l_acc=0.850 | val_loss=1.7783, val_l_acc=0.850
# [seed 246] epoch 333 | train_loss=1.2119, train_l_acc=0.911 | val_loss=1.7861, val_l_acc=0.850
# [seed 246] epoch 334 | train_loss=1.5131, train_l_acc=0.867 | val_loss=1.7909, val_l_acc=0.850
# [seed 246] epoch 335 | train_loss=1.6046, train_l_acc=0.850 | val_loss=1.7883, val_l_acc=0.850
# [seed 246] epoch 336 | train_loss=1.3840, train_l_acc=0.906 | val_loss=1.7773, val_l_acc=0.850
# [seed 246] epoch 337 | train_loss=1.5240, train_l_acc=0.844 | val_loss=1.7993, val_l_acc=0.850
# [seed 246] epoch 338 | train_loss=1.3316, train_l_acc=0.928 | val_loss=1.7814, val_l_acc=0.850
# [seed 246] epoch 339 | train_loss=1.3451, train_l_acc=0.922 | val_loss=1.7635, val_l_acc=0.850
# [seed 246] epoch 340 | train_loss=1.5112, train_l_acc=0.850 | val_loss=1.7480, val_l_acc=0.850
# [seed 246] epoch 341 | train_loss=1.2767, train_l_acc=0.906 | val_loss=1.7484, val_l_acc=0.850
# [seed 246] epoch 342 | train_loss=1.3663, train_l_acc=0.906 | val_loss=1.7495, val_l_acc=0.850
# [seed 246] epoch 343 | train_loss=1.4056, train_l_acc=0.906 | val_loss=1.7538, val_l_acc=0.850
# [seed 246] epoch 344 | train_loss=1.5540, train_l_acc=0.828 | val_loss=1.7584, val_l_acc=0.850
# [seed 246] epoch 345 | train_loss=1.4093, train_l_acc=0.894 | val_loss=1.7609, val_l_acc=0.850
# [seed 246] epoch 346 | train_loss=1.3440, train_l_acc=0.861 | val_loss=1.7727, val_l_acc=0.850
# [seed 246] epoch 347 | train_loss=1.2299, train_l_acc=0.922 | val_loss=1.7697, val_l_acc=0.850
# [seed 246] epoch 348 | train_loss=1.2660, train_l_acc=0.928 | val_loss=1.7887, val_l_acc=0.850
# [seed 246] epoch 349 | train_loss=1.4687, train_l_acc=0.883 | val_loss=1.7898, val_l_acc=0.850
# [seed 246] epoch 350 | train_loss=1.3485, train_l_acc=0.900 | val_loss=1.7831, val_l_acc=0.900
# [seed 246] epoch 351 | train_loss=1.4128, train_l_acc=0.861 | val_loss=1.7633, val_l_acc=0.900
# [seed 246] epoch 352 | train_loss=1.4374, train_l_acc=0.872 | val_loss=1.7502, val_l_acc=0.900
# [seed 246] epoch 353 | train_loss=1.2854, train_l_acc=0.906 | val_loss=1.7720, val_l_acc=0.850
# [seed 246] epoch 354 | train_loss=1.4830, train_l_acc=0.894 | val_loss=1.7880, val_l_acc=0.900
# [seed 246] epoch 355 | train_loss=1.2239, train_l_acc=0.933 | val_loss=1.7931, val_l_acc=0.900
# [seed 246] epoch 356 | train_loss=1.2802, train_l_acc=0.911 | val_loss=1.7929, val_l_acc=0.850
# [seed 246] epoch 357 | train_loss=1.3488, train_l_acc=0.878 | val_loss=1.7847, val_l_acc=0.900
# [seed 246] epoch 358 | train_loss=1.4895, train_l_acc=0.839 | val_loss=1.7728, val_l_acc=0.900
# [seed 246] epoch 359 | train_loss=1.1946, train_l_acc=0.900 | val_loss=1.7536, val_l_acc=0.900
# [seed 246] epoch 360 | train_loss=1.4687, train_l_acc=0.872 | val_loss=1.7537, val_l_acc=0.900
# [seed 246] epoch 361 | train_loss=1.4126, train_l_acc=0.900 | val_loss=1.7420, val_l_acc=0.900
# [seed 246] epoch 362 | train_loss=1.3155, train_l_acc=0.883 | val_loss=1.7637, val_l_acc=0.900
# [seed 246] epoch 363 | train_loss=1.4415, train_l_acc=0.889 | val_loss=1.8090, val_l_acc=0.900
# [seed 246] epoch 364 | train_loss=1.2349, train_l_acc=0.906 | val_loss=1.8323, val_l_acc=0.900
# [seed 246] epoch 365 | train_loss=1.4163, train_l_acc=0.878 | val_loss=1.8324, val_l_acc=0.900
# [seed 246] epoch 366 | train_loss=1.1970, train_l_acc=0.928 | val_loss=1.8213, val_l_acc=0.900
# [seed 246] epoch 367 | train_loss=1.1792, train_l_acc=0.928 | val_loss=1.8055, val_l_acc=0.900
# [seed 246] epoch 368 | train_loss=1.3443, train_l_acc=0.894 | val_loss=1.7876, val_l_acc=0.850
# [seed 246] epoch 369 | train_loss=1.4126, train_l_acc=0.872 | val_loss=1.8077, val_l_acc=0.850
# [seed 246] epoch 370 | train_loss=1.3301, train_l_acc=0.922 | val_loss=1.8288, val_l_acc=0.850
# [seed 246] epoch 371 | train_loss=1.2396, train_l_acc=0.928 | val_loss=1.8544, val_l_acc=0.800
# [seed 246] epoch 372 | train_loss=1.3139, train_l_acc=0.911 | val_loss=1.8979, val_l_acc=0.850
# [seed 246] epoch 373 | train_loss=1.3034, train_l_acc=0.872 | val_loss=1.8950, val_l_acc=0.850
# [seed 246] epoch 374 | train_loss=1.2366, train_l_acc=0.900 | val_loss=1.8825, val_l_acc=0.850
# [seed 246] epoch 375 | train_loss=1.3197, train_l_acc=0.872 | val_loss=1.8770, val_l_acc=0.800
# [seed 246] epoch 376 | train_loss=1.2811, train_l_acc=0.878 | val_loss=1.8692, val_l_acc=0.800
# [seed 246] epoch 377 | train_loss=1.4812, train_l_acc=0.872 | val_loss=1.8496, val_l_acc=0.800
# [seed 246] epoch 378 | train_loss=1.2341, train_l_acc=0.878 | val_loss=1.8242, val_l_acc=0.800
# [seed 246] epoch 379 | train_loss=1.3943, train_l_acc=0.872 | val_loss=1.8264, val_l_acc=0.800
# [seed 246] epoch 380 | train_loss=1.3721, train_l_acc=0.883 | val_loss=1.8163, val_l_acc=0.800
# [seed 246] epoch 381 | train_loss=1.3990, train_l_acc=0.878 | val_loss=1.8163, val_l_acc=0.850
# [seed 246] epoch 382 | train_loss=1.2328, train_l_acc=0.917 | val_loss=1.8076, val_l_acc=0.850
# [seed 246] epoch 383 | train_loss=1.2314, train_l_acc=0.894 | val_loss=1.7960, val_l_acc=0.850
# [seed 246] epoch 384 | train_loss=1.2149, train_l_acc=0.917 | val_loss=1.8081, val_l_acc=0.850
# [seed 246] epoch 385 | train_loss=1.3437, train_l_acc=0.894 | val_loss=1.8186, val_l_acc=0.850
# [seed 246] epoch 386 | train_loss=1.2586, train_l_acc=0.917 | val_loss=1.8308, val_l_acc=0.850
# [seed 246] epoch 387 | train_loss=1.2797, train_l_acc=0.894 | val_loss=1.8450, val_l_acc=0.850
# [seed 246] epoch 388 | train_loss=1.3996, train_l_acc=0.894 | val_loss=1.8292, val_l_acc=0.850
# [seed 246] epoch 389 | train_loss=1.2105, train_l_acc=0.906 | val_loss=1.8112, val_l_acc=0.850
# [seed 246] epoch 390 | train_loss=1.2421, train_l_acc=0.928 | val_loss=1.8017, val_l_acc=0.850
# [seed 246] epoch 391 | train_loss=1.2884, train_l_acc=0.889 | val_loss=1.8092, val_l_acc=0.850
# [seed 246] Early stopping at epoch 391
#
# === Training model 2/5 (seed=247) ===
# [seed 247] epoch 01 | train_loss=4.0401, train_l_acc=0.283 | val_loss=3.9870, val_l_acc=0.150
# [seed 247] epoch 02 | train_loss=4.1355, train_l_acc=0.189 | val_loss=3.9429, val_l_acc=0.200
# [seed 247] epoch 03 | train_loss=3.9772, train_l_acc=0.256 | val_loss=3.8999, val_l_acc=0.200
# [seed 247] epoch 04 | train_loss=3.8667, train_l_acc=0.328 | val_loss=3.8558, val_l_acc=0.350
# [seed 247] epoch 05 | train_loss=3.8599, train_l_acc=0.317 | val_loss=3.8135, val_l_acc=0.450
# [seed 247] epoch 06 | train_loss=3.8339, train_l_acc=0.422 | val_loss=3.7716, val_l_acc=0.450
# [seed 247] epoch 07 | train_loss=3.8004, train_l_acc=0.428 | val_loss=3.7351, val_l_acc=0.450
# [seed 247] epoch 08 | train_loss=3.7469, train_l_acc=0.411 | val_loss=3.6942, val_l_acc=0.400
# [seed 247] epoch 09 | train_loss=3.7459, train_l_acc=0.461 | val_loss=3.6510, val_l_acc=0.400
# [seed 247] epoch 10 | train_loss=3.7263, train_l_acc=0.406 | val_loss=3.6143, val_l_acc=0.450
# [seed 247] epoch 11 | train_loss=3.6526, train_l_acc=0.456 | val_loss=3.5718, val_l_acc=0.450
# [seed 247] epoch 12 | train_loss=3.6046, train_l_acc=0.428 | val_loss=3.5304, val_l_acc=0.500
# [seed 247] epoch 13 | train_loss=3.6624, train_l_acc=0.417 | val_loss=3.4896, val_l_acc=0.500
# [seed 247] epoch 14 | train_loss=3.4982, train_l_acc=0.472 | val_loss=3.4479, val_l_acc=0.500
# [seed 247] epoch 15 | train_loss=3.4985, train_l_acc=0.467 | val_loss=3.4099, val_l_acc=0.500
# [seed 247] epoch 16 | train_loss=3.5174, train_l_acc=0.467 | val_loss=3.3759, val_l_acc=0.500
# [seed 247] epoch 17 | train_loss=3.4132, train_l_acc=0.567 | val_loss=3.3373, val_l_acc=0.500
# [seed 247] epoch 18 | train_loss=3.4217, train_l_acc=0.500 | val_loss=3.2944, val_l_acc=0.550
# [seed 247] epoch 19 | train_loss=3.3284, train_l_acc=0.617 | val_loss=3.2494, val_l_acc=0.550
# [seed 247] epoch 20 | train_loss=3.3494, train_l_acc=0.583 | val_loss=3.2031, val_l_acc=0.550
# [seed 247] epoch 21 | train_loss=3.2570, train_l_acc=0.567 | val_loss=3.1637, val_l_acc=0.550
# [seed 247] epoch 22 | train_loss=3.3051, train_l_acc=0.606 | val_loss=3.1224, val_l_acc=0.550
# [seed 247] epoch 23 | train_loss=3.2793, train_l_acc=0.556 | val_loss=3.0831, val_l_acc=0.550
# [seed 247] epoch 24 | train_loss=3.2469, train_l_acc=0.556 | val_loss=3.0413, val_l_acc=0.550
# [seed 247] epoch 25 | train_loss=3.2108, train_l_acc=0.583 | val_loss=3.0018, val_l_acc=0.550
# [seed 247] epoch 26 | train_loss=3.1734, train_l_acc=0.594 | val_loss=2.9711, val_l_acc=0.550
# [seed 247] epoch 27 | train_loss=3.0498, train_l_acc=0.583 | val_loss=2.9338, val_l_acc=0.550
# [seed 247] epoch 28 | train_loss=3.0180, train_l_acc=0.656 | val_loss=2.9019, val_l_acc=0.550
# [seed 247] epoch 29 | train_loss=3.1335, train_l_acc=0.583 | val_loss=2.8692, val_l_acc=0.600
# [seed 247] epoch 30 | train_loss=3.0202, train_l_acc=0.611 | val_loss=2.8343, val_l_acc=0.600
# [seed 247] epoch 31 | train_loss=3.0316, train_l_acc=0.678 | val_loss=2.8009, val_l_acc=0.650
# [seed 247] epoch 32 | train_loss=2.8917, train_l_acc=0.633 | val_loss=2.7693, val_l_acc=0.650
# [seed 247] epoch 33 | train_loss=2.9344, train_l_acc=0.689 | val_loss=2.7478, val_l_acc=0.650
# [seed 247] epoch 34 | train_loss=2.9927, train_l_acc=0.622 | val_loss=2.7237, val_l_acc=0.650
# [seed 247] epoch 35 | train_loss=2.9188, train_l_acc=0.650 | val_loss=2.7016, val_l_acc=0.650
# [seed 247] epoch 36 | train_loss=2.8495, train_l_acc=0.683 | val_loss=2.6802, val_l_acc=0.650
# [seed 247] epoch 37 | train_loss=2.8144, train_l_acc=0.661 | val_loss=2.6519, val_l_acc=0.650
# [seed 247] epoch 38 | train_loss=2.7906, train_l_acc=0.678 | val_loss=2.6179, val_l_acc=0.700
# [seed 247] epoch 39 | train_loss=2.9518, train_l_acc=0.678 | val_loss=2.5957, val_l_acc=0.700
# [seed 247] epoch 40 | train_loss=2.7787, train_l_acc=0.694 | val_loss=2.5711, val_l_acc=0.700
# [seed 247] epoch 41 | train_loss=2.8536, train_l_acc=0.644 | val_loss=2.5444, val_l_acc=0.700
# [seed 247] epoch 42 | train_loss=2.7800, train_l_acc=0.644 | val_loss=2.5188, val_l_acc=0.700
# [seed 247] epoch 43 | train_loss=2.7041, train_l_acc=0.694 | val_loss=2.5030, val_l_acc=0.700
# [seed 247] epoch 44 | train_loss=2.6761, train_l_acc=0.683 | val_loss=2.4753, val_l_acc=0.750
# [seed 247] epoch 45 | train_loss=2.5478, train_l_acc=0.717 | val_loss=2.4473, val_l_acc=0.750
# [seed 247] epoch 46 | train_loss=2.6416, train_l_acc=0.672 | val_loss=2.4216, val_l_acc=0.750
# [seed 247] epoch 47 | train_loss=2.7714, train_l_acc=0.667 | val_loss=2.4011, val_l_acc=0.750
# [seed 247] epoch 48 | train_loss=2.6266, train_l_acc=0.689 | val_loss=2.3784, val_l_acc=0.750
# [seed 247] epoch 49 | train_loss=2.5519, train_l_acc=0.728 | val_loss=2.3563, val_l_acc=0.750
# [seed 247] epoch 50 | train_loss=2.5390, train_l_acc=0.761 | val_loss=2.3312, val_l_acc=0.750
# [seed 247] epoch 51 | train_loss=2.5705, train_l_acc=0.739 | val_loss=2.3062, val_l_acc=0.750
# [seed 247] epoch 52 | train_loss=2.4757, train_l_acc=0.700 | val_loss=2.2869, val_l_acc=0.750
# [seed 247] epoch 53 | train_loss=2.5670, train_l_acc=0.694 | val_loss=2.2456, val_l_acc=0.800
# [seed 247] epoch 54 | train_loss=2.4760, train_l_acc=0.778 | val_loss=2.2203, val_l_acc=0.800
# [seed 247] epoch 55 | train_loss=2.5491, train_l_acc=0.661 | val_loss=2.2020, val_l_acc=0.850
# [seed 247] epoch 56 | train_loss=2.4118, train_l_acc=0.756 | val_loss=2.2005, val_l_acc=0.850
# [seed 247] epoch 57 | train_loss=2.4441, train_l_acc=0.728 | val_loss=2.1792, val_l_acc=0.850
# [seed 247] epoch 58 | train_loss=2.4191, train_l_acc=0.722 | val_loss=2.1675, val_l_acc=0.850
# [seed 247] epoch 59 | train_loss=2.3213, train_l_acc=0.728 | val_loss=2.1443, val_l_acc=0.850
# [seed 247] epoch 60 | train_loss=2.3098, train_l_acc=0.783 | val_loss=2.1273, val_l_acc=0.800
# [seed 247] epoch 61 | train_loss=2.3774, train_l_acc=0.706 | val_loss=2.1106, val_l_acc=0.800
# [seed 247] epoch 62 | train_loss=2.3184, train_l_acc=0.767 | val_loss=2.0829, val_l_acc=0.850
# [seed 247] epoch 63 | train_loss=2.3749, train_l_acc=0.756 | val_loss=2.0773, val_l_acc=0.850
# [seed 247] epoch 64 | train_loss=2.2346, train_l_acc=0.767 | val_loss=2.0602, val_l_acc=0.850
# [seed 247] epoch 65 | train_loss=2.2873, train_l_acc=0.778 | val_loss=2.0479, val_l_acc=0.850
# [seed 247] epoch 66 | train_loss=2.3395, train_l_acc=0.750 | val_loss=2.0235, val_l_acc=0.850
# [seed 247] epoch 67 | train_loss=2.3659, train_l_acc=0.767 | val_loss=2.0206, val_l_acc=0.850
# [seed 247] epoch 68 | train_loss=2.2002, train_l_acc=0.778 | val_loss=2.0295, val_l_acc=0.850
# [seed 247] epoch 69 | train_loss=2.1644, train_l_acc=0.783 | val_loss=2.0260, val_l_acc=0.850
# [seed 247] epoch 70 | train_loss=2.2939, train_l_acc=0.783 | val_loss=2.0065, val_l_acc=0.850
# [seed 247] epoch 71 | train_loss=2.2734, train_l_acc=0.772 | val_loss=1.9776, val_l_acc=0.850
# [seed 247] epoch 72 | train_loss=2.1778, train_l_acc=0.806 | val_loss=1.9690, val_l_acc=0.850
# [seed 247] epoch 73 | train_loss=2.3057, train_l_acc=0.744 | val_loss=1.9698, val_l_acc=0.850
# [seed 247] epoch 74 | train_loss=2.0715, train_l_acc=0.778 | val_loss=1.9533, val_l_acc=0.850
# [seed 247] epoch 75 | train_loss=2.2063, train_l_acc=0.783 | val_loss=1.9388, val_l_acc=0.850
# [seed 247] epoch 76 | train_loss=2.2313, train_l_acc=0.778 | val_loss=1.9171, val_l_acc=0.850
# [seed 247] epoch 77 | train_loss=2.1612, train_l_acc=0.756 | val_loss=1.9033, val_l_acc=0.850
# [seed 247] epoch 78 | train_loss=2.1123, train_l_acc=0.811 | val_loss=1.8867, val_l_acc=0.850
# [seed 247] epoch 79 | train_loss=2.0551, train_l_acc=0.789 | val_loss=1.8904, val_l_acc=0.850
# [seed 247] epoch 80 | train_loss=2.1466, train_l_acc=0.756 | val_loss=1.9099, val_l_acc=0.850
# [seed 247] epoch 81 | train_loss=2.0217, train_l_acc=0.817 | val_loss=1.9110, val_l_acc=0.850
# [seed 247] epoch 82 | train_loss=2.1356, train_l_acc=0.789 | val_loss=1.9020, val_l_acc=0.850
# [seed 247] epoch 83 | train_loss=2.0313, train_l_acc=0.800 | val_loss=1.8708, val_l_acc=0.850
# [seed 247] epoch 84 | train_loss=2.0647, train_l_acc=0.794 | val_loss=1.8581, val_l_acc=0.850
# [seed 247] epoch 85 | train_loss=2.1259, train_l_acc=0.761 | val_loss=1.8472, val_l_acc=0.850
# [seed 247] epoch 86 | train_loss=2.0808, train_l_acc=0.778 | val_loss=1.8593, val_l_acc=0.850
# [seed 247] epoch 87 | train_loss=2.1402, train_l_acc=0.778 | val_loss=1.8459, val_l_acc=0.850
# [seed 247] epoch 88 | train_loss=1.9291, train_l_acc=0.833 | val_loss=1.8429, val_l_acc=0.850
# [seed 247] epoch 89 | train_loss=2.1923, train_l_acc=0.800 | val_loss=1.8394, val_l_acc=0.850
# [seed 247] epoch 90 | train_loss=1.9107, train_l_acc=0.806 | val_loss=1.8434, val_l_acc=0.850
# [seed 247] epoch 91 | train_loss=1.9432, train_l_acc=0.850 | val_loss=1.8329, val_l_acc=0.850
# [seed 247] epoch 92 | train_loss=1.9856, train_l_acc=0.822 | val_loss=1.8264, val_l_acc=0.850
# [seed 247] epoch 93 | train_loss=2.1460, train_l_acc=0.778 | val_loss=1.8202, val_l_acc=0.850
# [seed 247] epoch 94 | train_loss=1.8378, train_l_acc=0.833 | val_loss=1.8058, val_l_acc=0.850
# [seed 247] epoch 95 | train_loss=2.1258, train_l_acc=0.733 | val_loss=1.7811, val_l_acc=0.850
# [seed 247] epoch 96 | train_loss=1.8774, train_l_acc=0.839 | val_loss=1.7532, val_l_acc=0.850
# [seed 247] epoch 97 | train_loss=1.9797, train_l_acc=0.817 | val_loss=1.7292, val_l_acc=0.850
# [seed 247] epoch 98 | train_loss=1.9022, train_l_acc=0.817 | val_loss=1.7107, val_l_acc=0.850
# [seed 247] epoch 99 | train_loss=1.9770, train_l_acc=0.800 | val_loss=1.7162, val_l_acc=0.850
# [seed 247] epoch 100 | train_loss=2.0371, train_l_acc=0.811 | val_loss=1.7132, val_l_acc=0.850
# [seed 247] epoch 101 | train_loss=2.1667, train_l_acc=0.789 | val_loss=1.6874, val_l_acc=0.850
# [seed 247] epoch 102 | train_loss=1.9669, train_l_acc=0.822 | val_loss=1.6649, val_l_acc=0.900
# [seed 247] epoch 103 | train_loss=1.9492, train_l_acc=0.783 | val_loss=1.6510, val_l_acc=0.850
# [seed 247] epoch 104 | train_loss=1.8998, train_l_acc=0.772 | val_loss=1.6565, val_l_acc=0.850
# [seed 247] epoch 105 | train_loss=1.9636, train_l_acc=0.794 | val_loss=1.6623, val_l_acc=0.850
# [seed 247] epoch 106 | train_loss=1.9350, train_l_acc=0.817 | val_loss=1.6665, val_l_acc=0.850
# [seed 247] epoch 107 | train_loss=1.8469, train_l_acc=0.822 | val_loss=1.6619, val_l_acc=0.900
# [seed 247] epoch 108 | train_loss=1.9840, train_l_acc=0.806 | val_loss=1.6570, val_l_acc=0.900
# [seed 247] epoch 109 | train_loss=1.8694, train_l_acc=0.806 | val_loss=1.6623, val_l_acc=0.900
# [seed 247] epoch 110 | train_loss=1.8337, train_l_acc=0.850 | val_loss=1.6787, val_l_acc=0.850
# [seed 247] epoch 111 | train_loss=1.8347, train_l_acc=0.811 | val_loss=1.6908, val_l_acc=0.850
# [seed 247] epoch 112 | train_loss=1.9866, train_l_acc=0.817 | val_loss=1.7050, val_l_acc=0.850
# [seed 247] epoch 113 | train_loss=1.7699, train_l_acc=0.833 | val_loss=1.7155, val_l_acc=0.850
# [seed 247] epoch 114 | train_loss=2.0289, train_l_acc=0.761 | val_loss=1.7211, val_l_acc=0.850
# [seed 247] epoch 115 | train_loss=1.8005, train_l_acc=0.850 | val_loss=1.7134, val_l_acc=0.850
# ...
# [seed 250] epoch 203 | train_loss=1.7343, train_l_acc=0.833 | val_loss=1.6772, val_l_acc=0.850
# [seed 250] epoch 204 | train_loss=1.4880, train_l_acc=0.867 | val_loss=1.6896, val_l_acc=0.800
# [seed 250] epoch 205 | train_loss=1.5978, train_l_acc=0.828 | val_loss=1.7035, val_l_acc=0.850
# [seed 250] epoch 206 | train_loss=1.6159, train_l_acc=0.900 | val_loss=1.7049, val_l_acc=0.800
# [seed 250] epoch 207 | train_loss=1.5410, train_l_acc=0.839 | val_loss=1.7007, val_l_acc=0.800
# [seed 250] epoch 208 | train_loss=1.6096, train_l_acc=0.806 | val_loss=1.6881, val_l_acc=0.800
# [seed 250] epoch 209 | train_loss=1.4076, train_l_acc=0.889 | val_loss=1.6814, val_l_acc=0.900
# [seed 250] epoch 210 | train_loss=1.6118, train_l_acc=0.811 | val_loss=1.6843, val_l_acc=0.900
# [seed 250] epoch 211 | train_loss=1.4144, train_l_acc=0.872 | val_loss=1.6909, val_l_acc=0.900
# [seed 250] epoch 212 | train_loss=1.5446, train_l_acc=0.878 | val_loss=1.6959, val_l_acc=0.900
# [seed 250] epoch 213 | train_loss=1.5040, train_l_acc=0.850 | val_loss=1.7090, val_l_acc=0.900
# [seed 250] epoch 214 | train_loss=1.4322, train_l_acc=0.906 | val_loss=1.7093, val_l_acc=0.900
# [seed 250] epoch 215 | train_loss=1.5680, train_l_acc=0.828 | val_loss=1.7047, val_l_acc=0.900
# [seed 250] epoch 216 | train_loss=1.5297, train_l_acc=0.861 | val_loss=1.7005, val_l_acc=0.900
# [seed 250] epoch 217 | train_loss=1.3896, train_l_acc=0.894 | val_loss=1.6899, val_l_acc=0.850
# [seed 250] epoch 218 | train_loss=1.5682, train_l_acc=0.850 | val_loss=1.6946, val_l_acc=0.850
# [seed 250] epoch 219 | train_loss=1.4164, train_l_acc=0.856 | val_loss=1.6868, val_l_acc=0.800
# [seed 250] epoch 220 | train_loss=1.5401, train_l_acc=0.883 | val_loss=1.7012, val_l_acc=0.800
# [seed 250] epoch 221 | train_loss=1.5974, train_l_acc=0.828 | val_loss=1.7152, val_l_acc=0.800
# [seed 250] epoch 222 | train_loss=1.6665, train_l_acc=0.817 | val_loss=1.7252, val_l_acc=0.800
# [seed 250] epoch 223 | train_loss=1.4131, train_l_acc=0.872 | val_loss=1.7180, val_l_acc=0.850
# [seed 250] epoch 224 | train_loss=1.4817, train_l_acc=0.856 | val_loss=1.7157, val_l_acc=0.850
# [seed 250] epoch 225 | train_loss=1.6773, train_l_acc=0.844 | val_loss=1.7022, val_l_acc=0.850
# [seed 250] epoch 226 | train_loss=1.4792, train_l_acc=0.856 | val_loss=1.6986, val_l_acc=0.800
# [seed 250] epoch 227 | train_loss=1.4742, train_l_acc=0.856 | val_loss=1.7115, val_l_acc=0.800
# [seed 250] epoch 228 | train_loss=1.4847, train_l_acc=0.867 | val_loss=1.7318, val_l_acc=0.800
# [seed 250] epoch 229 | train_loss=1.5835, train_l_acc=0.883 | val_loss=1.7472, val_l_acc=0.850
# [seed 250] epoch 230 | train_loss=1.5577, train_l_acc=0.867 | val_loss=1.7476, val_l_acc=0.850
# [seed 250] epoch 231 | train_loss=1.4938, train_l_acc=0.889 | val_loss=1.7399, val_l_acc=0.850
# [seed 250] epoch 232 | train_loss=1.3866, train_l_acc=0.878 | val_loss=1.7599, val_l_acc=0.850
# [seed 250] epoch 233 | train_loss=1.5067, train_l_acc=0.878 | val_loss=1.7587, val_l_acc=0.850
# [seed 250] epoch 234 | train_loss=1.4100, train_l_acc=0.883 | val_loss=1.7553, val_l_acc=0.850
# [seed 250] epoch 235 | train_loss=1.5653, train_l_acc=0.844 | val_loss=1.7185, val_l_acc=0.850
# [seed 250] epoch 236 | train_loss=1.4842, train_l_acc=0.872 | val_loss=1.6997, val_l_acc=0.850
# [seed 250] epoch 237 | train_loss=1.4104, train_l_acc=0.867 | val_loss=1.6786, val_l_acc=0.850
# [seed 250] epoch 238 | train_loss=1.6069, train_l_acc=0.783 | val_loss=1.6757, val_l_acc=0.850
# [seed 250] epoch 239 | train_loss=1.5104, train_l_acc=0.872 | val_loss=1.6916, val_l_acc=0.850
# [seed 250] epoch 240 | train_loss=1.4697, train_l_acc=0.872 | val_loss=1.7040, val_l_acc=0.850
# [seed 250] epoch 241 | train_loss=1.4885, train_l_acc=0.867 | val_loss=1.7055, val_l_acc=0.800
# [seed 250] epoch 242 | train_loss=1.3735, train_l_acc=0.889 | val_loss=1.6863, val_l_acc=0.750
# [seed 250] epoch 243 | train_loss=1.3299, train_l_acc=0.883 | val_loss=1.6746, val_l_acc=0.800
# [seed 250] epoch 244 | train_loss=1.4173, train_l_acc=0.867 | val_loss=1.6537, val_l_acc=0.850
# [seed 250] epoch 245 | train_loss=1.5805, train_l_acc=0.844 | val_loss=1.6506, val_l_acc=0.850
# [seed 250] epoch 246 | train_loss=1.3910, train_l_acc=0.856 | val_loss=1.6491, val_l_acc=0.850
# [seed 250] epoch 247 | train_loss=1.5106, train_l_acc=0.850 | val_loss=1.6471, val_l_acc=0.850
# [seed 250] epoch 248 | train_loss=1.5086, train_l_acc=0.856 | val_loss=1.6744, val_l_acc=0.800
# [seed 250] epoch 249 | train_loss=1.5573, train_l_acc=0.861 | val_loss=1.6968, val_l_acc=0.800
# [seed 250] epoch 250 | train_loss=1.3067, train_l_acc=0.922 | val_loss=1.7188, val_l_acc=0.850
# [seed 250] epoch 251 | train_loss=1.5333, train_l_acc=0.856 | val_loss=1.7261, val_l_acc=0.800
# [seed 250] epoch 252 | train_loss=1.5050, train_l_acc=0.839 | val_loss=1.7376, val_l_acc=0.800
# [seed 250] epoch 253 | train_loss=1.4382, train_l_acc=0.867 | val_loss=1.7382, val_l_acc=0.850
# [seed 250] epoch 254 | train_loss=1.3147, train_l_acc=0.900 | val_loss=1.7486, val_l_acc=0.850
# [seed 250] epoch 255 | train_loss=1.4270, train_l_acc=0.889 | val_loss=1.7551, val_l_acc=0.850
# [seed 250] epoch 256 | train_loss=1.4535, train_l_acc=0.872 | val_loss=1.7478, val_l_acc=0.850
# [seed 250] epoch 257 | train_loss=1.5282, train_l_acc=0.872 | val_loss=1.7504, val_l_acc=0.850
# [seed 250] epoch 258 | train_loss=1.3660, train_l_acc=0.878 | val_loss=1.7309, val_l_acc=0.850
# [seed 250] epoch 259 | train_loss=1.4308, train_l_acc=0.856 | val_loss=1.7425, val_l_acc=0.850
# [seed 250] epoch 260 | train_loss=1.5724, train_l_acc=0.850 | val_loss=1.7317, val_l_acc=0.850
# [seed 250] epoch 261 | train_loss=1.5424, train_l_acc=0.856 | val_loss=1.7138, val_l_acc=0.850
# [seed 250] epoch 262 | train_loss=1.4295, train_l_acc=0.906 | val_loss=1.7018, val_l_acc=0.850
# [seed 250] epoch 263 | train_loss=1.4619, train_l_acc=0.883 | val_loss=1.6956, val_l_acc=0.900
# [seed 250] epoch 264 | train_loss=1.4696, train_l_acc=0.839 | val_loss=1.6963, val_l_acc=0.850
# [seed 250] epoch 265 | train_loss=1.4662, train_l_acc=0.883 | val_loss=1.6913, val_l_acc=0.850
# [seed 250] epoch 266 | train_loss=1.4250, train_l_acc=0.867 | val_loss=1.6893, val_l_acc=0.850
# [seed 250] epoch 267 | train_loss=1.3787, train_l_acc=0.900 | val_loss=1.6862, val_l_acc=0.850
# [seed 250] epoch 268 | train_loss=1.6173, train_l_acc=0.806 | val_loss=1.6943, val_l_acc=0.850
# [seed 250] epoch 269 | train_loss=1.5906, train_l_acc=0.867 | val_loss=1.6928, val_l_acc=0.850
# [seed 250] epoch 270 | train_loss=1.3876, train_l_acc=0.911 | val_loss=1.6736, val_l_acc=0.850
# [seed 250] epoch 271 | train_loss=1.3569, train_l_acc=0.878 | val_loss=1.6581, val_l_acc=0.850
# [seed 250] epoch 272 | train_loss=1.5028, train_l_acc=0.872 | val_loss=1.6445, val_l_acc=0.850
# [seed 250] epoch 273 | train_loss=1.5154, train_l_acc=0.861 | val_loss=1.6455, val_l_acc=0.900
# [seed 250] epoch 274 | train_loss=1.4463, train_l_acc=0.850 | val_loss=1.6529, val_l_acc=0.900
# [seed 250] epoch 275 | train_loss=1.1899, train_l_acc=0.922 | val_loss=1.6543, val_l_acc=0.900
# [seed 250] epoch 276 | train_loss=1.5054, train_l_acc=0.833 | val_loss=1.6673, val_l_acc=0.900
# [seed 250] epoch 277 | train_loss=1.3667, train_l_acc=0.872 | val_loss=1.6603, val_l_acc=0.900
# [seed 250] epoch 278 | train_loss=1.5240, train_l_acc=0.856 | val_loss=1.6818, val_l_acc=0.900
# [seed 250] epoch 279 | train_loss=1.4206, train_l_acc=0.889 | val_loss=1.6931, val_l_acc=0.900
# [seed 250] epoch 280 | train_loss=1.6778, train_l_acc=0.811 | val_loss=1.6735, val_l_acc=0.850
# [seed 250] epoch 281 | train_loss=1.4872, train_l_acc=0.850 | val_loss=1.6792, val_l_acc=0.850
# [seed 250] epoch 282 | train_loss=1.3681, train_l_acc=0.872 | val_loss=1.6718, val_l_acc=0.850
# [seed 250] epoch 283 | train_loss=1.4141, train_l_acc=0.878 | val_loss=1.6642, val_l_acc=0.850
# [seed 250] epoch 284 | train_loss=1.5308, train_l_acc=0.856 | val_loss=1.6586, val_l_acc=0.850
# [seed 250] epoch 285 | train_loss=1.5656, train_l_acc=0.839 | val_loss=1.6620, val_l_acc=0.850
# [seed 250] epoch 286 | train_loss=1.4421, train_l_acc=0.894 | val_loss=1.6663, val_l_acc=0.900
# [seed 250] epoch 287 | train_loss=1.5664, train_l_acc=0.839 | val_loss=1.6744, val_l_acc=0.850
# [seed 250] epoch 288 | train_loss=1.4899, train_l_acc=0.839 | val_loss=1.6775, val_l_acc=0.900
# [seed 250] epoch 289 | train_loss=1.3390, train_l_acc=0.878 | val_loss=1.6673, val_l_acc=0.900
# [seed 250] epoch 290 | train_loss=1.4333, train_l_acc=0.872 | val_loss=1.6603, val_l_acc=0.900
# [seed 250] epoch 291 | train_loss=1.6309, train_l_acc=0.872 | val_loss=1.6684, val_l_acc=0.900
# [seed 250] epoch 292 | train_loss=1.4040, train_l_acc=0.856 | val_loss=1.6948, val_l_acc=0.850
# [seed 250] epoch 293 | train_loss=1.3534, train_l_acc=0.894 | val_loss=1.7239, val_l_acc=0.850
# [seed 250] epoch 294 | train_loss=1.3517, train_l_acc=0.894 | val_loss=1.7309, val_l_acc=0.850
# [seed 250] epoch 295 | train_loss=1.5985, train_l_acc=0.806 | val_loss=1.7435, val_l_acc=0.850
# [seed 250] epoch 296 | train_loss=1.3435, train_l_acc=0.894 | val_loss=1.7256, val_l_acc=0.850
# [seed 250] epoch 297 | train_loss=1.2868, train_l_acc=0.900 | val_loss=1.7064, val_l_acc=0.850
# [seed 250] epoch 298 | train_loss=1.3016, train_l_acc=0.922 | val_loss=1.7046, val_l_acc=0.850
# [seed 250] epoch 299 | train_loss=1.3413, train_l_acc=0.894 | val_loss=1.7179, val_l_acc=0.800
# [seed 250] epoch 300 | train_loss=1.4069, train_l_acc=0.867 | val_loss=1.7163, val_l_acc=0.800
# [seed 250] epoch 301 | train_loss=1.3904, train_l_acc=0.900 | val_loss=1.7082, val_l_acc=0.800
# [seed 250] epoch 302 | train_loss=1.3108, train_l_acc=0.911 | val_loss=1.6890, val_l_acc=0.800
# [seed 250] epoch 303 | train_loss=1.5216, train_l_acc=0.856 | val_loss=1.6804, val_l_acc=0.850
# [seed 250] epoch 304 | train_loss=1.3745, train_l_acc=0.872 | val_loss=1.6818, val_l_acc=0.850
# [seed 250] epoch 305 | train_loss=1.5464, train_l_acc=0.844 | val_loss=1.6824, val_l_acc=0.850
# [seed 250] epoch 306 | train_loss=1.3859, train_l_acc=0.889 | val_loss=1.6764, val_l_acc=0.850
# [seed 250] epoch 307 | train_loss=1.3900, train_l_acc=0.883 | val_loss=1.6768, val_l_acc=0.850
# [seed 250] epoch 308 | train_loss=1.2419, train_l_acc=0.911 | val_loss=1.6969, val_l_acc=0.850
# [seed 250] epoch 309 | train_loss=1.2907, train_l_acc=0.906 | val_loss=1.6991, val_l_acc=0.900
# [seed 250] epoch 310 | train_loss=1.3008, train_l_acc=0.861 | val_loss=1.6963, val_l_acc=0.900
# [seed 250] epoch 311 | train_loss=1.3512, train_l_acc=0.872 | val_loss=1.7109, val_l_acc=0.900
# [seed 250] epoch 312 | train_loss=1.5848, train_l_acc=0.839 | val_loss=1.7502, val_l_acc=0.900
# [seed 250] epoch 313 | train_loss=1.3801, train_l_acc=0.872 | val_loss=1.7392, val_l_acc=0.850
# [seed 250] epoch 314 | train_loss=1.4351, train_l_acc=0.867 | val_loss=1.7483, val_l_acc=0.850
# [seed 250] epoch 315 | train_loss=1.3367, train_l_acc=0.883 | val_loss=1.7361, val_l_acc=0.850
# [seed 250] epoch 316 | train_loss=1.4801, train_l_acc=0.883 | val_loss=1.7173, val_l_acc=0.850
# [seed 250] epoch 317 | train_loss=1.3290, train_l_acc=0.883 | val_loss=1.6991, val_l_acc=0.850
# [seed 250] epoch 318 | train_loss=1.4261, train_l_acc=0.861 | val_loss=1.6876, val_l_acc=0.850
# [seed 250] epoch 319 | train_loss=1.1794, train_l_acc=0.928 | val_loss=1.6933, val_l_acc=0.850
# [seed 250] epoch 320 | train_loss=1.1821, train_l_acc=0.917 | val_loss=1.7087, val_l_acc=0.850
# [seed 250] epoch 321 | train_loss=1.4532, train_l_acc=0.872 | val_loss=1.7383, val_l_acc=0.850
# [seed 250] epoch 322 | train_loss=1.3202, train_l_acc=0.922 | val_loss=1.7802, val_l_acc=0.850
# [seed 250] epoch 323 | train_loss=1.3625, train_l_acc=0.867 | val_loss=1.7880, val_l_acc=0.900
# [seed 250] epoch 324 | train_loss=1.4607, train_l_acc=0.867 | val_loss=1.7888, val_l_acc=0.900
# [seed 250] epoch 325 | train_loss=1.5507, train_l_acc=0.844 | val_loss=1.7837, val_l_acc=0.900
# [seed 250] epoch 326 | train_loss=1.2181, train_l_acc=0.911 | val_loss=1.7717, val_l_acc=0.850
# [seed 250] epoch 327 | train_loss=1.6191, train_l_acc=0.822 | val_loss=1.7542, val_l_acc=0.850
# [seed 250] epoch 328 | train_loss=1.3368, train_l_acc=0.917 | val_loss=1.7499, val_l_acc=0.850
# [seed 250] epoch 329 | train_loss=1.2226, train_l_acc=0.911 | val_loss=1.7677, val_l_acc=0.850
# [seed 250] epoch 330 | train_loss=1.3790, train_l_acc=0.878 | val_loss=1.7570, val_l_acc=0.850
# [seed 250] epoch 331 | train_loss=1.3960, train_l_acc=0.894 | val_loss=1.7266, val_l_acc=0.850
# [seed 250] epoch 332 | train_loss=1.4255, train_l_acc=0.867 | val_loss=1.7272, val_l_acc=0.750
# [seed 250] epoch 333 | train_loss=1.4004, train_l_acc=0.867 | val_loss=1.7343, val_l_acc=0.750
# [seed 250] epoch 334 | train_loss=1.5265, train_l_acc=0.828 | val_loss=1.7169, val_l_acc=0.800
# [seed 250] epoch 335 | train_loss=1.4139, train_l_acc=0.833 | val_loss=1.7103, val_l_acc=0.850
# [seed 250] epoch 336 | train_loss=1.2555, train_l_acc=0.889 | val_loss=1.7079, val_l_acc=0.850
# [seed 250] epoch 337 | train_loss=1.3262, train_l_acc=0.878 | val_loss=1.7320, val_l_acc=0.850
# [seed 250] epoch 338 | train_loss=1.4039, train_l_acc=0.861 | val_loss=1.7523, val_l_acc=0.850
# [seed 250] epoch 339 | train_loss=1.4286, train_l_acc=0.883 | val_loss=1.7461, val_l_acc=0.850
# [seed 250] epoch 340 | train_loss=1.3412, train_l_acc=0.900 | val_loss=1.7088, val_l_acc=0.850
# [seed 250] epoch 341 | train_loss=1.3327, train_l_acc=0.900 | val_loss=1.7202, val_l_acc=0.850
# [seed 250] epoch 342 | train_loss=1.4085, train_l_acc=0.861 | val_loss=1.7243, val_l_acc=0.850
# [seed 250] epoch 343 | train_loss=1.3164, train_l_acc=0.878 | val_loss=1.7072, val_l_acc=0.850
# [seed 250] epoch 344 | train_loss=1.4419, train_l_acc=0.872 | val_loss=1.6928, val_l_acc=0.850
# [seed 250] epoch 345 | train_loss=1.4192, train_l_acc=0.867 | val_loss=1.6912, val_l_acc=0.850
# [seed 250] epoch 346 | train_loss=1.2457, train_l_acc=0.894 | val_loss=1.6942, val_l_acc=0.900
# [seed 250] epoch 347 | train_loss=1.2528, train_l_acc=0.933 | val_loss=1.6897, val_l_acc=0.900
# [seed 250] epoch 348 | train_loss=1.2529, train_l_acc=0.889 | val_loss=1.6902, val_l_acc=0.900
# [seed 250] epoch 349 | train_loss=1.4041, train_l_acc=0.883 | val_loss=1.6859, val_l_acc=0.900
# [seed 250] epoch 350 | train_loss=1.1540, train_l_acc=0.911 | val_loss=1.6968, val_l_acc=0.900
# [seed 250] epoch 351 | train_loss=1.5269, train_l_acc=0.850 | val_loss=1.7070, val_l_acc=0.850
# [seed 250] epoch 352 | train_loss=1.3052, train_l_acc=0.900 | val_loss=1.7030, val_l_acc=0.850
# [seed 250] epoch 353 | train_loss=1.3053, train_l_acc=0.917 | val_loss=1.7055, val_l_acc=0.850
# [seed 250] epoch 354 | train_loss=1.3940, train_l_acc=0.872 | val_loss=1.7197, val_l_acc=0.850
# [seed 250] epoch 355 | train_loss=1.2945, train_l_acc=0.911 | val_loss=1.7251, val_l_acc=0.900
# [seed 250] epoch 356 | train_loss=1.2215, train_l_acc=0.933 | val_loss=1.7513, val_l_acc=0.850
# [seed 250] epoch 357 | train_loss=1.3096, train_l_acc=0.900 | val_loss=1.7688, val_l_acc=0.850
# [seed 250] epoch 358 | train_loss=1.4451, train_l_acc=0.878 | val_loss=1.7552, val_l_acc=0.800
# [seed 250] epoch 359 | train_loss=1.2529, train_l_acc=0.900 | val_loss=1.7232, val_l_acc=0.850
# [seed 250] epoch 360 | train_loss=1.2610, train_l_acc=0.872 | val_loss=1.6897, val_l_acc=0.900
# [seed 250] epoch 361 | train_loss=1.2604, train_l_acc=0.922 | val_loss=1.6689, val_l_acc=0.850
# [seed 250] epoch 362 | train_loss=1.2925, train_l_acc=0.922 | val_loss=1.6465, val_l_acc=0.850
# [seed 250] epoch 363 | train_loss=1.2657, train_l_acc=0.883 | val_loss=1.6465, val_l_acc=0.850
# [seed 250] epoch 364 | train_loss=1.3578, train_l_acc=0.861 | val_loss=1.6697, val_l_acc=0.850
# [seed 250] epoch 365 | train_loss=1.2802, train_l_acc=0.911 | val_loss=1.6774, val_l_acc=0.900
# [seed 250] epoch 366 | train_loss=1.4023, train_l_acc=0.883 | val_loss=1.6686, val_l_acc=0.900
# [seed 250] epoch 367 | train_loss=1.2672, train_l_acc=0.850 | val_loss=1.6949, val_l_acc=0.850
# [seed 250] epoch 368 | train_loss=1.2594, train_l_acc=0.889 | val_loss=1.7081, val_l_acc=0.850
# [seed 250] Early stopping at epoch 368
# Val label acc of each model: [0.9, 0.95, 0.9, 0.9, 0.9]
# Mean: 0.9099999999999999 Std: 0.019999999999999973

# %% [markdown]
# # Training Visualization

# %%
best_idx = int(np.argmax(scores))
best_history = histories[best_idx]
print("Best model index:", best_idx)
# Out:
# Best model index: 1

# %%
import matplotlib.pyplot as plt

def plot_history_one(history, title_suffix=""):
    epochs = range(1, len(history["train_loss"]) + 1)

    # Loss
    plt.figure(figsize=(6, 4))
    plt.plot(epochs, history["train_loss"], label="Train loss")
    plt.plot(epochs, history["val_loss"],   label="Val loss")
    plt.xlabel("Epoch")
    plt.ylabel("Total loss")
    plt.title(f"Loss (multi-task MLP){title_suffix}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    # Painter accuracy
    plt.figure(figsize=(6, 4))
    plt.plot(epochs, history["train_painter_acc"], label="Train painter acc")
    plt.plot(epochs, history["val_painter_acc"],   label="Val painter acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title(f"Painter accuracy (train vs val){title_suffix}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    # Label accuracy
    plt.figure(figsize=(6, 4))
    plt.plot(epochs, history["train_label_acc"], label="Train label acc")
    plt.plot(epochs, history["val_label_acc"],   label="Val label acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title(f"Label accuracy (train vs val){title_suffix}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

plot_history_one(best_history, title_suffix=" (best model)")

# %%
plt.figure(figsize=(6, 4))
for i, h in enumerate(histories):
    epochs = range(1, len(h["val_label_acc"]) + 1)
    plt.plot(epochs, h["val_label_acc"], alpha=0.5, label=f"model {i}" if i < 6 else None)
plt.xlabel("Epoch")
plt.ylabel("Val label accuracy")
plt.title("Val label accuracy for all bagged models")
plt.grid(True, alpha=0.3)
# If K small, show legend; otherwise remove
if K <= 6:
    plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Validation

# %%
@torch.no_grad()
def ensemble_predict(models, X_t: torch.Tensor, device):
    X_t = X_t.to(device)

    p_logits_sum = None
    l_logits_sum = None

    for model in models:
        model.eval()
        p_logits, l_logits = model(X_t)
        if p_logits_sum is None:
            p_logits_sum = p_logits
            l_logits_sum = l_logits
        else:
            p_logits_sum += p_logits
            l_logits_sum += l_logits

    p_logits_mean = p_logits_sum / len(models)
    l_logits_mean = l_logits_sum / len(models)

    y_p_pred = p_logits_mean.argmax(dim=1).cpu().numpy()
    y_l_pred = l_logits_mean.argmax(dim=1).cpu().numpy()
    return y_p_pred, y_l_pred

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

y_p_true = y_p_val_t.numpy()
y_l_true = y_l_val_t.numpy()

y_p_pred_ens, y_l_pred_ens = ensemble_predict(models, X_val_t, device)

print("Best single model val label acc:", np.max(scores))
print("Ensemble val label acc:", accuracy_score(y_l_true, y_l_pred_ens))
print("Ensemble val painter acc:", accuracy_score(y_p_true, y_p_pred_ens))
# Out:
# Best single model val label acc: 0.95
# Ensemble val label acc: 0.9
# Ensemble val painter acc: 0.75

# %%
cm_label = confusion_matrix(y_l_true, y_l_pred_ens)

disp = ConfusionMatrixDisplay(confusion_matrix=cm_label, display_labels=class_names)
fig, ax = plt.subplots(figsize=(6, 6))
disp.plot(cmap="Blues", xticks_rotation=90, ax=ax, colorbar=False)
plt.title("Confusion matrix (validation) - ensemble labels")
plt.tight_layout()
plt.grid(False)
plt.show()

# %%
from sklearn.metrics import f1_score

f1_per_label = f1_score(
    y_l_true,
    y_l_pred_ens,
    average=None,
    labels=np.arange(NUM_LABELS),
)

plt.figure(figsize=(6, 4))
plt.bar(range(NUM_LABELS), f1_per_label)
plt.xticks(range(NUM_LABELS), class_names, rotation=45, ha="right")
plt.ylim(0, 1.0)
plt.ylabel("F1 score")
plt.title("Per-label F1 (validation, ensemble)")
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

for name, f1_val in zip(class_names, f1_per_label):
    print(f"{name:30s}: F1 = {f1_val:.3f}")
# Out:
# Surrealismo                   : F1 = 0.909
# Cubismo                       : F1 = 0.800
# Expresionismo abstracto       : F1 = 1.000
# Barroco                       : F1 = 0.857
# Impresionismo                 : F1 = 0.923

# %% [markdown]
# # Test

# %%
TEST_PATH = Path("09 features/redes_local/datos/processed/df_test.csv")

# %%
# === Cell 18: load test df and predict (when df_test is available) ===

TEST_PATH = Path("09 features/redes_local/datos/processed/df_bb.csv")
df_test = pd.read_csv(TEST_PATH)

# Map painters with the *training* mapping
df_test["painter_idx"] = df_test["painter"].map(painter_to_idx)

# Optionally handle unknown painters
mask_unknown = df_test["painter_idx"].isna()
if mask_unknown.any():
    print("Warning: unknown painters in test:", df_test.loc[mask_unknown, "painter"].unique())
    df_test = df_test.loc[~mask_unknown].copy()

X_test = df_test[feature_cols].to_numpy(dtype=np.float32)
X_test_scaled = scaler.transform(X_test)

X_test_t = torch.from_numpy(X_test_scaled).float().to(device)

with torch.no_grad():
    for model in models:
        p_logits_test, l_logits_test = model(X_test_t)
        y_p_pred_test = p_logits_test.argmax(dim=1).cpu().numpy()
        y_l_pred_test = l_logits_test.argmax(dim=1).cpu().numpy()

df_test["painter_pred"] = [idx_to_painter[i] for i in y_p_pred_test]
df_test["label_pred"]   = y_l_pred_test
df_test["genre_pred"]   = [class_names[i] for i in y_l_pred_test]

df_test.head()
# Out:
#        mean_R      mean_G     mean_B      std_R      std_G      std_B  min_R  \
# 0  113.894936  127.379160  103.34666  53.270428  70.752464  75.454780    0.0
# 1  100.800140   91.574240   75.35645  76.134636  75.270805  72.747894    5.0
# 2  129.785230  116.044860   89.18722  47.168243  54.259525  42.555046   49.0
# 3  119.764275  126.478325  115.54521  55.139767  62.966022  80.313644   10.0
# 4  143.549220  138.841380  130.06557  87.223040  88.330170  91.912506    3.0
#
#    min_G  min_B  max_R  ...  lum_centroid_x  lum_centroid_y  \
# 0    2.0    0.0  255.0  ...        0.553279       -0.467646
# 1    8.0    0.0  255.0  ...        0.525715       -0.609516
# 2   28.0   20.0  255.0  ...        0.483567       -0.700687
# 3    1.0    0.0  255.0  ...        0.492189       -0.565718
# 4    7.0    0.0  255.0  ...        0.511623       -0.144344
#
#                 filename        painter          genre  label  painter_idx  \
# 0  Alfred_Sisley_001.jpg  Alfred_Sisley  Impresionismo      4            0
# 1  Alfred_Sisley_002.jpg  Alfred_Sisley  Impresionismo      4            0
# 2  Alfred_Sisley_003.jpg  Alfred_Sisley  Impresionismo      4            0
# 3  Alfred_Sisley_004.jpg  Alfred_Sisley  Impresionismo      4            0
# 4  Alfred_Sisley_005.jpg  Alfred_Sisley  Impresionismo      4            0
#
#    painter_pred  label_pred     genre_pred
# 0  Claude_Monet           4  Impresionismo
# 1    Caravaggio           3        Barroco
# 2    Caravaggio           3        Barroco
# 3  Claude_Monet           4  Impresionismo
# 4    Caravaggio           3        Barroco
#
# [5 rows x 61 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
X_test = df_test[feature_cols].to_numpy(dtype=np.float32)
y_painter_test = df_test["painter_idx"].to_numpy(dtype=np.int64)
y_label_test = df_test["label"].to_numpy(dtype=np.int64)

print("X_test shape:", X_test.shape)
print("y_painter_test shape:", y_painter_test.shape)
print("y_label_test shape:", y_label_test.shape)
print("Painter counts:", np.bincount(y_painter_test))
print("Label counts:",   np.bincount(y_label_test))
# Out:
# X_test shape: (750, 53)
# y_painter_test shape: (750,)
# y_label_test shape: (750,)
# Painter counts: [70 60 60 80 65 70 80 70 60 70 65]
# Label counts: [200  80  65 130 275]

# %%
X_test_scaled = scaler.transform(X_test)

# %%
X_test_t = torch.from_numpy(X_test_scaled).float()
y_p_test_t = torch.from_numpy(y_painter_test).long()
y_l_test_t = torch.from_numpy(y_label_test).long()

test_ds = TensorDataset(X_test_t, y_p_test_t, y_l_test_t)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

# %%
y_p_true, y_l_true, y_p_pred, y_l_pred = predict_loader(model, test_loader, device)

# Painters
painter_acc = accuracy_score(y_p_true, y_p_pred)
print(f"Val painter accuracy: {painter_acc:.3f}")
print("\nPainter classification report (val):")
print(classification_report(y_p_true, y_p_pred, target_names=painter_names, digits=3))

# Labels (genres)
label_acc = accuracy_score(y_l_true, y_l_pred)
print(f"\nVal label accuracy: {label_acc:.3f}")
print("\nLabel (genre) classification report (val):")
print(classification_report(y_l_true, y_l_pred, target_names=class_names, digits=3))
# Out:
# Val painter accuracy: 0.387
#
# Painter classification report (val):
#                   precision    recall  f1-score   support
#
#    Alfred_Sisley      0.273     0.214     0.240        70
# Camille_Pissarro      0.289     0.650     0.400        60
#       Caravaggio      0.521     0.417     0.463        60
#     Claude_Monet      0.280     0.575     0.377        80
#  Jackson_Pollock      0.935     0.446     0.604        65
#        Joan_Miro      0.688     0.314     0.431        70
#    Pablo_Picasso      0.400     0.350     0.373        80
#        Rembrandt      0.464     0.457     0.460        70
#    Rene_Magritte      0.344     0.183     0.239        60
#    Salvador_Dali      0.585     0.343     0.432        70
# Vincent_van_Gogh      0.260     0.292     0.275        65
#
#         accuracy                          0.387       750
#        macro avg      0.458     0.386     0.391       750
#     weighted avg      0.456     0.387     0.390       750
#
#
# Val label accuracy: 0.608
#
# Label (genre) classification report (val):
#                          precision    recall  f1-score   support
#
#             Surrealismo      0.670     0.345     0.455       200
#                 Cubismo      0.394     0.350     0.371        80
# Expresionismo abstracto      0.933     0.431     0.589        65
#                 Barroco      0.713     0.631     0.669       130
#           Impresionismo      0.578     0.905     0.705       275
#
#                accuracy                          0.608       750
#               macro avg      0.658     0.532     0.558       750
#            weighted avg      0.637     0.608     0.587       750

# %%
# === Cell 16: confusion matrix for labels (val) ===

cm_label = confusion_matrix(y_l_true, y_l_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm_label, display_labels=class_names)
fig, ax = plt.subplots(figsize=(6, 6))
disp.plot(cmap="Blues", xticks_rotation=90, ax=ax, colorbar=False)
plt.title("Confusion matrix (validation) - labels (genres)")
plt.tight_layout()
plt.grid(False)
plt.show()

# %%
# === Cell 17: per-class F1 for labels ===

f1_per_label = f1_score(
    y_l_true,
    y_l_pred,
    average=None,
    labels=np.arange(NUM_LABELS),
)

plt.figure(figsize=(6, 4))
plt.bar(range(NUM_LABELS), f1_per_label)
plt.xticks(range(NUM_LABELS), class_names, rotation=45, ha="right")
plt.ylim(0, 1.0)
plt.ylabel("F1 score")
plt.title("Per-label F1 (validation)")
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

for name, f1_val in zip(class_names, f1_per_label):
    print(f"{name:30s}: F1 = {f1_val:.3f}")
# Out:
# Surrealismo                   : F1 = 0.455
# Cubismo                       : F1 = 0.371
# Expresionismo abstracto       : F1 = 0.589
# Barroco                       : F1 = 0.669
# Impresionismo                 : F1 = 0.705
